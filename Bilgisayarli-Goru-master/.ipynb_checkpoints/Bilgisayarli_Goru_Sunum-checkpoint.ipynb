# %%
# 03.04.2018
# Mustafa UĞUR tarafından yazılmıştır.

# Sarıyer Akademi Yapay Zeka II kursu için hazırlanmıştır.
# Bilgisayarlı görü çalışmaları hakkında bilgi vermek içindir.
# Python kod örnekleri verilmiştir.

# Kodlar Opencv Python rehberinden alınmıştır.

# %%
# Anaconda Navigotor ile kurulum için 
        # Eğer Windows kullanıyorsanız
        # Conda komut satırını açınız 
        # "conda install -c conda-forge opencv "
        # "conda install -c conda-forge/label/broken opencv "
        
        # Eğer bir Linux dağıtımı kullanıyorsanız
        # direkt olarak komut satırına giriniz 
        # "conda install -c conda-forge opencv "
        # "conda install -c conda-forge/label/broken opencv "

# %%
# görüntüyü işleyip, yazma
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('messi5.jpg',0)
plt.imshow(img,'gray')
k = cv2.waitKey(0)
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv2.imwrite('messigray.png',img)
    cv2.destroyAllWindows()

# %%
img = cv2.imread('cristiano_ronaldo.jpg',-1)
plt.imshow(img)
k = cv2.waitKey(0)
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv2.imwrite('ronaldo_white_black.png',img)
    cv2.destroyAllWindows()

# %%
img = cv2.imread("messi5.jpg")

# %%
px = img[100,100]
px
# Out:
# array([57, 63, 68], dtype=uint8)

# %%
blue = img[100,100,0]
green = img[100,100,1]
red = img[100,100,2]

# %%
blue
# Out:
# 57

# %%
red
# Out:
# 68

# %%
green
# Out:
# 63

# %%
img1 = cv2.imread('WindowsLogo.jpg')
img2 = cv2.imread('LinuxLogo.jpg')

dst = cv2.addWeighted(img1,0.7,img2,0.3,0)

plt.imshow(dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('sudoku.jpg',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('LinuxLogo.jpg')

kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)

plt.subplot(211),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(212),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('messi5.jpg',0)
edges = cv2.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
# Yaralı Linkler
# https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_tutorials.html
# https://www.youtube.com/user/sentdex
# Computer Vision : Algotihms and Application
# https://www.youtube.com/watch?v=ihXE1Iu5E3o 
# https://www.youtube.com/watch?v=fmVWLr0X1Sk
