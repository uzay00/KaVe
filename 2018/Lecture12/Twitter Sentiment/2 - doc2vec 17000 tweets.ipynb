# %% [markdown]
# ## Turkish NLP Zemberek

# %%
import jpype
# JVM başlat
jpype.startJVM(jpype.getDefaultJVMPath(),
         "-Djava.class.path=/Users/uzaycetin/Documents/driver/zemberek-tum-2.0.jar", "-ea")

# Türkiye Türkçesine göre çözümlemek için gerekli sınıfı hazırla
Tr = jpype.JClass("net.zemberek.tr.yapi.TurkiyeTurkcesi")
# tr nesnesini oluştur
tr = Tr()
# Zemberek sınıfını yükle
Zemberek = jpype.JClass("net.zemberek.erisim.Zemberek")
# zemberek nesnesini oluştur
zemberek = Zemberek(tr)

# %%
def kokbul(word = 'karasal'):
    kok = word
    ornSonuc = zemberek.kelimeCozumle(kok)
    try:
        kok = ornSonuc[0].kok().icerik()
    except:
        pass
    return kok

# %%
txt = 'gezinti gelsene'
[kokbul(w) for w in txt.split()]
# Out:
# ['gezinti', 'gel']

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import re
import pickle 
import nltk
from nltk.corpus import stopwords
from sklearn.datasets import load_files
nltk.download('stopwords')

# stopwordsleri sil
from nltk.corpus import stopwords
stop = stopwords.words('Turkish')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/uzaycetin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Get twitter 17000 Data

# %%
# Turkish Stopwords
with open('17bintweet/turkce-stop-words.txt') as file:  
    stw = file.read() 
stw = stw.split()
stw = [s.lower() for s in stw] 
stop += stw

# %%
def preprocessing(text):
    text = text.lower()
    # get rid of non-alphanumerical characters
    text = re.sub(r'\W', ' ', text) 
    # get rid of spaces
    text = re.sub(r'\s+', ' ', text) 
    # Correct mistakes 
    # zemberek!!
    
    # and do the stemming
    kelimeler = [kokbul(w) for w in text.split()]
    return " ".join([word for word in kelimeler if word not in stop])

# %%
preprocessing(txt)
# Out:
# 'gezinti gel'

# %%
test_data = pd.read_excel('17bintweet/test_tweets.xlsx', header=None)
test_data.head(3)
# Out:
#                                                    0        1
# 0  Turkcell'e kızgınım. Ve bu kızgınlık sanırım a...  olumsuz
# 1                 turkcell kadar şerefsiz misiniz ya  olumsuz
# 2  Burdan Turkcell'e sesleniyorum o 3 tl haram olsun  olumsuz

# %%
train_data = pd.read_excel('17bintweet/train_tweets.xlsx', header=None)
train_data.head(3)
# Out:
#                                                    0        1
# 0  Ulan Wifi'ye bağlıyım ben. Ona bağlıyken Turkc...  olumsuz
# 1  20 dk 1 GB internet 500 mb sadece kaşar turkce...  olumsuz
# 2  Ayrıca turkcell superonline reklamı kadar da k...  olumsuz

# %%
test_data[0] = test_data[0].apply(preprocessing)
train_data[0] = train_data[0].apply(preprocessing)

train_data.head(3)
# Out:
#                                                    0        1
# 0  ulan wifi bağ bağ turkcell internet paket bit ...  olumsuz
# 1  20 dk 1 gb internet 500 mb sadece kaşar turkce...  olumsuz
# 2        turkcell superonline reklam kötü reklam gör  olumsuz

# %% [markdown]
# ## Doc2Vec starts

# %%
#Import all the dependencies
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

# %% [markdown]
# ## Label documents

# %%
# Creating the corpus for train_data
train_tagged_data = []
for i in range(len(train_data)):
    train_tagged_data.append(TaggedDocument(word_tokenize(train_data.iloc[i,0]), tags=[train_data.iloc[i,1]]))

# %%
# Creating the corpus for test_data
test_tagged_data = []
for i in range(len(test_data)):
    test_tagged_data.append(TaggedDocument(word_tokenize(test_data.iloc[i,0]), tags=[test_data.iloc[i,1]]))

# %%
train_tagged_data[:3]
# Out:
# [TaggedDocument(words=['ulan', 'wifi', 'bağ', 'bağ', 'turkcell', 'internet', 'paket', 'bit', 'mesaj', 'at', 'öde'], tags=['olumsuz']),
#  TaggedDocument(words=['20', 'dk', '1', 'gb', 'internet', '500', 'mb', 'sadece', 'kaşar', 'turkcell', 'düş', 'oç', 'çocuk'], tags=['olumsuz']),
#  TaggedDocument(words=['turkcell', 'superonline', 'reklam', 'kötü', 'reklam', 'gör'], tags=['olumsuz'])]

# %%
test_tagged_data[:3]
# Out:
# [TaggedDocument(words=['turkcell', 'kızgın', 'kızgın', 'san', 'ayrıl', 'sonlanıcak', 'gel', 'fark', 'operatör', '30', 'fazla', 'fiyat', 'teklif', 'et'], tags=['olumsuz']),
#  TaggedDocument(words=['turkcell', 'şeref', 'mis'], tags=['olumsuz']),
#  TaggedDocument(words=['burdan', 'turkcell', 'sesle', '3', 'tl', 'haram', 'ol'], tags=['olumsuz'])]

# %%
len(test_tagged_data), len(train_tagged_data)
# Out:
# (3457, 13832)

# %%
train_tagged_data[0].words
# Out:
# ['ulan',
#  'wifi',
#  'bağ',
#  'bağ',
#  'turkcell',
#  'internet',
#  'paket',
#  'bit',
#  'mesaj',
#  'at',
#  'öde']

# %% [markdown]
# ## Train doc2vec dm=1 ‘distributed memory’ (PV-DM)

# %%
max_epochs = 40
model = Doc2Vec(dm_mean=1, 
                vector_size=300, 
                negative=5, 
                workers=3,
                window=5,
                alpha=0.065, 
                min_alpha=0.065,
                min_count=2,
                dm =1)
  
model.build_vocab(train_tagged_data)

for epoch in range(max_epochs):
    if epoch% (max_epochs/5) == 0: print('iteration {0}/{1}'.format(epoch, max_epochs))
        
    model.train(train_tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    
    # decrease the learning rate
    model.alpha -= 0.002
    
    # fix the learning rate, no decay
    model.min_alpha = model.alpha

#model.save("d2vz.model")
print("Model Saved")
# Out:
# iteration 0/40
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# iteration 8/40
# iteration 16/40
# iteration 24/40
# iteration 32/40
# Model Saved

# %%
len(model.wv.vocab)
# Out:
# 7131

# %%
len(model.docvecs) # The number of trained document tags is available from:
# Out:
# 3

# %%
model.wv.vocab
# Out:
# {'ulan': <gensim.models.keyedvectors.Vocab at 0x63b5843c8>,
#  'wifi': <gensim.models.keyedvectors.Vocab at 0x63b5845f8>,
#  'bağ': <gensim.models.keyedvectors.Vocab at 0x63b584630>,
#  'turkcell': <gensim.models.keyedvectors.Vocab at 0x63b584400>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x63b5845c0>,
#  'paket': <gensim.models.keyedvectors.Vocab at 0x63b584668>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x63b584588>,
#  'mesaj': <gensim.models.keyedvectors.Vocab at 0x63b5846a0>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x63b5846d8>,
#  'öde': <gensim.models.keyedvectors.Vocab at 0x63b584710>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x63b584748>,
#  'dk': <gensim.models.keyedvectors.Vocab at 0x63b584780>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x63b5847b8>,
#  'gb': <gensim.models.keyedvectors.Vocab at 0x63b5847f0>,
#  '500': <gensim.models.keyedvectors.Vocab at 0x63b584828>,
#  'mb': <gensim.models.keyedvectors.Vocab at 0x63b584860>,
#  'sadece': <gensim.models.keyedvectors.Vocab at 0x63b584898>,
#  'kaşar': <gensim.models.keyedvectors.Vocab at 0x63b5848d0>,
#  'düş': <gensim.models.keyedvectors.Vocab at 0x63b584908>,
#  'oç': <gensim.models.keyedvectors.Vocab at 0x63b584940>,
#  'çocuk': <gensim.models.keyedvectors.Vocab at 0x63b584978>,
#  'superonline': <gensim.models.keyedvectors.Vocab at 0x63b5849b0>,
#  'reklam': <gensim.models.keyedvectors.Vocab at 0x63b5849e8>,
#  'kötü': <gensim.models.keyedvectors.Vocab at 0x63b584a20>,
#  'gör': <gensim.models.keyedvectors.Vocab at 0x63b584a58>,
#  'pahalı': <gensim.models.keyedvectors.Vocab at 0x63b584a90>,
#  'internetin': <gensim.models.keyedvectors.Vocab at 0x63b584ac8>,
#  'cekmiyor': <gensim.models.keyedvectors.Vocab at 0x63b584b00>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x63b584b38>,
#  'allah': <gensim.models.keyedvectors.Vocab at 0x63b584b70>,
#  'bela': <gensim.models.keyedvectors.Vocab at 0x63b584ba8>,
#  'ver': <gensim.models.keyedvectors.Vocab at 0x63b584be0>,
#  'iste': <gensim.models.keyedvectors.Vocab at 0x63b584c18>,
#  'yürek': <gensim.models.keyedvectors.Vocab at 0x63b584c50>,
#  'şiş': <gensim.models.keyedvectors.Vocab at 0x63b584c88>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x63b584cc0>,
#  'cehennem': <gensim.models.keyedvectors.Vocab at 0x63b584cf8>,
#  'yönetim': <gensim.models.keyedvectors.Vocab at 0x63b584d30>,
#  'el': <gensim.models.keyedvectors.Vocab at 0x63b584d68>,
#  'geçir': <gensim.models.keyedvectors.Vocab at 0x63b584da0>,
#  'akp': <gensim.models.keyedvectors.Vocab at 0x63b584dd8>,
#  'abone': <gensim.models.keyedvectors.Vocab at 0x63b584e10>,
#  'seçim': <gensim.models.keyedvectors.Vocab at 0x63b584e48>,
#  'gönder': <gensim.models.keyedvectors.Vocab at 0x63b584e80>,
#  'şeref': <gensim.models.keyedvectors.Vocab at 0x63b584eb8>,
#  'aksi': <gensim.models.keyedvectors.Vocab at 0x63b584ef0>,
#  'iddia': <gensim.models.keyedvectors.Vocab at 0x63b584f28>,
#  'ede': <gensim.models.keyedvectors.Vocab at 0x63b584f60>,
#  'elim': <gensim.models.keyedvectors.Vocab at 0x63b584f98>,
#  'ayak': <gensim.models.keyedvectors.Vocab at 0x63b584fd0>,
#  'çek': <gensim.models.keyedvectors.Vocab at 0x63b5a7048>,
#  'iyi': <gensim.models.keyedvectors.Vocab at 0x63b5a7080>,
#  'ol': <gensim.models.keyedvectors.Vocab at 0x63b5a70b8>,
#  'bayram': <gensim.models.keyedvectors.Vocab at 0x63b5a70f0>,
#  'vodafone': <gensim.models.keyedvectors.Vocab at 0x63b5a7128>,
#  'geç': <gensim.models.keyedvectors.Vocab at 0x63b5a7160>,
#  'kazık': <gensim.models.keyedvectors.Vocab at 0x63b5a7198>,
#  'amk': <gensim.models.keyedvectors.Vocab at 0x63b5a71d0>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x63b5a7208>,
#  'evin': <gensim.models.keyedvectors.Vocab at 0x63b5a7240>,
#  'köşe': <gensim.models.keyedvectors.Vocab at 0x63b5a7278>,
#  'kazıkla': <gensim.models.keyedvectors.Vocab at 0x63b5a72b0>,
#  'kal': <gensim.models.keyedvectors.Vocab at 0x63b5a72e8>,
#  'internetleri': <gensim.models.keyedvectors.Vocab at 0x63b5a7320>,
#  'düşük': <gensim.models.keyedvectors.Vocab at 0x63b5a7358>,
#  'hızlı': <gensim.models.keyedvectors.Vocab at 0x63b5a7390>,
#  'hay': <gensim.models.keyedvectors.Vocab at 0x63b5a73c8>,
#  'çekim': <gensim.models.keyedvectors.Vocab at 0x63b5a7400>,
#  'gücün': <gensim.models.keyedvectors.Vocab at 0x63b5a7438>,
#  'nalet': <gensim.models.keyedvectors.Vocab at 0x63b5a7470>,
#  'şehir': <gensim.models.keyedvectors.Vocab at 0x63b5a74a8>,
#  'dış': <gensim.models.keyedvectors.Vocab at 0x63b5a74e0>,
#  'bura': <gensim.models.keyedvectors.Vocab at 0x63b5a7518>,
#  'bide': <gensim.models.keyedvectors.Vocab at 0x63b5a7550>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x63b5a7588>,
#  'dakika': <gensim.models.keyedvectors.Vocab at 0x63b5a75c0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x63b5a75f8>,
#  'izle': <gensim.models.keyedvectors.Vocab at 0x63b5a7630>,
#  'icin': <gensim.models.keyedvectors.Vocab at 0x63b5a7668>,
#  'yarım': <gensim.models.keyedvectors.Vocab at 0x63b5a76a0>,
#  'saat': <gensim.models.keyedvectors.Vocab at 0x63b5a76d8>,
#  'dolma': <gensim.models.keyedvectors.Vocab at 0x63b5a7710>,
#  'bekle': <gensim.models.keyedvectors.Vocab at 0x63b5a7748>,
#  'bağla': <gensim.models.keyedvectors.Vocab at 0x63b5a7780>,
#  'git': <gensim.models.keyedvectors.Vocab at 0x63b5a77b8>,
#  'zor': <gensim.models.keyedvectors.Vocab at 0x63b5a77f0>,
#  'su': <gensim.models.keyedvectors.Vocab at 0x63b5a7828>,
#  'dur': <gensim.models.keyedvectors.Vocab at 0x63b5a7860>,
#  'yer': <gensim.models.keyedvectors.Vocab at 0x63b5a7898>,
#  'kac': <gensim.models.keyedvectors.Vocab at 0x63b5a78d0>,
#  'lirami': <gensim.models.keyedvectors.Vocab at 0x63b5a7908>,
#  'kafasina': <gensim.models.keyedvectors.Vocab at 0x63b5a7940>,
#  'gore': <gensim.models.keyedvectors.Vocab at 0x63b5a7978>,
#  'parala': <gensim.models.keyedvectors.Vocab at 0x63b5a79b0>,
#  'cekiyo': <gensim.models.keyedvectors.Vocab at 0x63b5a79e8>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x63b5a7a20>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x63b5a7a58>,
#  'ara': <gensim.models.keyedvectors.Vocab at 0x63b5a7a90>,
#  'ayıp': <gensim.models.keyedvectors.Vocab at 0x63b5a7ac8>,
#  'saçmala': <gensim.models.keyedvectors.Vocab at 0x63b5a7b00>,
#  'başla': <gensim.models.keyedvectors.Vocab at 0x63b5a7b38>,
#  'kurtar': <gensim.models.keyedvectors.Vocab at 0x63b5a7b70>,
#  'sevin': <gensim.models.keyedvectors.Vocab at 0x63b5a7ba8>,
#  'kurum': <gensim.models.keyedvectors.Vocab at 0x63b5a7be0>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x63b5a7c18>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x63b5a7c50>,
#  'digiturk': <gensim.models.keyedvectors.Vocab at 0x63b5a7c88>,
#  'garanti': <gensim.models.keyedvectors.Vocab at 0x63b5a7cc0>,
#  'interneti': <gensim.models.keyedvectors.Vocab at 0x63b5a7cf8>,
#  'rezil': <gensim.models.keyedvectors.Vocab at 0x63b5a7d30>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x63b5a7d68>,
#  'köy': <gensim.models.keyedvectors.Vocab at 0x63b5a7da0>,
#  'hiçbi': <gensim.models.keyedvectors.Vocab at 0x63b5a7dd8>,
#  'çekme': <gensim.models.keyedvectors.Vocab at 0x63b5a7e10>,
#  'sürekli': <gensim.models.keyedvectors.Vocab at 0x63b5a7e48>,
#  'yerel': <gensim.models.keyedvectors.Vocab at 0x63b5a7e80>,
#  'değer': <gensim.models.keyedvectors.Vocab at 0x63b5a7eb8>,
#  'kullan': <gensim.models.keyedvectors.Vocab at 0x63b5a7ef0>,
#  'ayar': <gensim.models.keyedvectors.Vocab at 0x63b5a7f28>,
#  'yayla': <gensim.models.keyedvectors.Vocab at 0x63b5a7f60>,
#  'telefon': <gensim.models.keyedvectors.Vocab at 0x63b5a7f98>,
#  'sözde': <gensim.models.keyedvectors.Vocab at 0x63b5a7fd0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x63b5aa048>,
#  'göbek': <gensim.models.keyedvectors.Vocab at 0x63b5aa080>,
#  'tek': <gensim.models.keyedvectors.Vocab at 0x63b5aa0b8>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x63b5aa0f0>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x63b5aa128>,
#  'geçmiş': <gensim.models.keyedvectors.Vocab at 0x63b5aa160>,
#  'yüksel': <gensim.models.keyedvectors.Vocab at 0x63b5aa198>,
#  'kolay': <gensim.models.keyedvectors.Vocab at 0x63b5aa1d0>,
#  'geri': <gensim.models.keyedvectors.Vocab at 0x63b5aa208>,
#  'zeka': <gensim.models.keyedvectors.Vocab at 0x63b5aa240>,
#  'nterneti': <gensim.models.keyedvectors.Vocab at 0x63b5aa278>,
#  '23': <gensim.models.keyedvectors.Vocab at 0x63b5aa2b0>,
#  'lira': <gensim.models.keyedvectors.Vocab at 0x63b5aa2e8>,
#  '35': <gensim.models.keyedvectors.Vocab at 0x63b5aa320>,
#  'vere': <gensim.models.keyedvectors.Vocab at 0x63b5aa358>,
#  'salak': <gensim.models.keyedvectors.Vocab at 0x63b5aa390>,
#  'türk': <gensim.models.keyedvectors.Vocab at 0x63b5aa3c8>,
#  'operatör': <gensim.models.keyedvectors.Vocab at 0x63b5aa400>,
#  'tıpkı': <gensim.models.keyedvectors.Vocab at 0x63b5aa438>,
#  'ab': <gensim.models.keyedvectors.Vocab at 0x63b5aa470>,
#  'dek': <gensim.models.keyedvectors.Vocab at 0x63b5aa4a8>,
#  'halka': <gensim.models.keyedvectors.Vocab at 0x63b5aa4e0>,
#  'hediye': <gensim.models.keyedvectors.Vocab at 0x63b5aa518>,
#  'ürün': <gensim.models.keyedvectors.Vocab at 0x63b5aa550>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x63b5aa588>,
#  'yılla': <gensim.models.keyedvectors.Vocab at 0x63b5aa5c0>,
#  'halk': <gensim.models.keyedvectors.Vocab at 0x63b5aa5f8>,
#  'sömür': <gensim.models.keyedvectors.Vocab at 0x63b5aa630>,
#  'yap': <gensim.models.keyedvectors.Vocab at 0x63b5aa668>,
#  'müşteri': <gensim.models.keyedvectors.Vocab at 0x63b5aa6a0>,
#  'hizmet': <gensim.models.keyedvectors.Vocab at 0x63b5aa6d8>,
#  'kalite': <gensim.models.keyedvectors.Vocab at 0x63b5aa710>,
#  'felaket': <gensim.models.keyedvectors.Vocab at 0x63b5aa748>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x63b5aa780>,
#  'hesap': <gensim.models.keyedvectors.Vocab at 0x63b5aa7b8>,
#  'aynı': <gensim.models.keyedvectors.Vocab at 0x63b5aa7f0>,
#  'yazı': <gensim.models.keyedvectors.Vocab at 0x63b5aa828>,
#  'arkadaş': <gensim.models.keyedvectors.Vocab at 0x63b5aa860>,
#  'paylaş': <gensim.models.keyedvectors.Vocab at 0x63b5aa898>,
#  'yaa': <gensim.models.keyedvectors.Vocab at 0x63b5aa8d0>,
#  'ağız': <gensim.models.keyedvectors.Vocab at 0x63b5aa908>,
#  'et': <gensim.models.keyedvectors.Vocab at 0x63b5aa940>,
#  'düzel': <gensim.models.keyedvectors.Vocab at 0x63b5aa978>,
#  'fotoğraf': <gensim.models.keyedvectors.Vocab at 0x63b5aa9b0>,
#  'aç': <gensim.models.keyedvectors.Vocab at 0x63b5aa9e8>,
#  'sürü': <gensim.models.keyedvectors.Vocab at 0x63b5aaa20>,
#  'heryerde': <gensim.models.keyedvectors.Vocab at 0x63b5aaa58>,
#  'hat': <gensim.models.keyedvectors.Vocab at 0x63b5aaa90>,
#  'üst': <gensim.models.keyedvectors.Vocab at 0x63b5aaac8>,
#  'deyil': <gensim.models.keyedvectors.Vocab at 0x63b5aab00>,
#  'bık': <gensim.models.keyedvectors.Vocab at 0x63b5aab38>,
#  'baba': <gensim.models.keyedvectors.Vocab at 0x63b5aab70>,
#  'duy': <gensim.models.keyedvectors.Vocab at 0x63b5aaba8>,
#  'ses': <gensim.models.keyedvectors.Vocab at 0x63b5aabe0>,
#  'dir': <gensim.models.keyedvectors.Vocab at 0x63b5aac18>,
#  'idda': <gensim.models.keyedvectors.Vocab at 0x63b5aac50>,
#  'bi': <gensim.models.keyedvectors.Vocab at 0x63b5aac88>,
#  'yok': <gensim.models.keyedvectors.Vocab at 0x63b5aacc0>,
#  'cekiyor': <gensim.models.keyedvectors.Vocab at 0x63b5aacf8>,
#  'aq': <gensim.models.keyedvectors.Vocab at 0x63b5aad30>,
#  'numara': <gensim.models.keyedvectors.Vocab at 0x63b5aad68>,
#  'değiş': <gensim.models.keyedvectors.Vocab at 0x63b5aada0>,
#  'yeter': <gensim.models.keyedvectors.Vocab at 0x63b5aadd8>,
#  'para': <gensim.models.keyedvectors.Vocab at 0x63b5aae10>,
#  'fatura': <gensim.models.keyedvectors.Vocab at 0x63b5aae48>,
#  'söv': <gensim.models.keyedvectors.Vocab at 0x63b5aae80>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x63b5aaeb8>,
#  'sınırsız': <gensim.models.keyedvectors.Vocab at 0x63b5aaef0>,
#  'san': <gensim.models.keyedvectors.Vocab at 0x63b5aaf28>,
#  'kek': <gensim.models.keyedvectors.Vocab at 0x63b5aaf60>,
#  'yavaş': <gensim.models.keyedvectors.Vocab at 0x63b5aaf98>,
#  'öl': <gensim.models.keyedvectors.Vocab at 0x63b5aafd0>,
#  'adet': <gensim.models.keyedvectors.Vocab at 0x63b5ad048>,
#  'çekmiyooo': <gensim.models.keyedvectors.Vocab at 0x63b5ad080>,
#  'kahret': <gensim.models.keyedvectors.Vocab at 0x63b5ad0b8>,
#  'bildik': <gensim.models.keyedvectors.Vocab at 0x63b5ad0f0>,
#  'ilk': <gensim.models.keyedvectors.Vocab at 0x63b5ad128>,
#  'beddua': <gensim.models.keyedvectors.Vocab at 0x63b5ad160>,
#  'yalan': <gensim.models.keyedvectors.Vocab at 0x63b5ad198>,
#  'söyle': <gensim.models.keyedvectors.Vocab at 0x63b5ad1d0>,
#  'sigorta': <gensim.models.keyedvectors.Vocab at 0x63b5ad208>,
#  'kapsam': <gensim.models.keyedvectors.Vocab at 0x63b5ad240>,
#  'çevir': <gensim.models.keyedvectors.Vocab at 0x63b5ad278>,
#  'seda': <gensim.models.keyedvectors.Vocab at 0x63b5ad2b0>,
#  'ev': <gensim.models.keyedvectors.Vocab at 0x63b5ad2e8>,
#  'gel': <gensim.models.keyedvectors.Vocab at 0x63b5ad320>,
#  'adam': <gensim.models.keyedvectors.Vocab at 0x63b5ad358>,
#  'sinir': <gensim.models.keyedvectors.Vocab at 0x63b5ad390>,
#  'çeker': <gensim.models.keyedvectors.Vocab at 0x63b5ad3c8>,
#  'orta': <gensim.models.keyedvectors.Vocab at 0x63b5ad400>,
#  'şahin': <gensim.models.keyedvectors.Vocab at 0x63b5ad438>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x63b5ad470>,
#  'gectigim': <gensim.models.keyedvectors.Vocab at 0x63b5ad4a8>,
#  'pismanim': <gensim.models.keyedvectors.Vocab at 0x63b5ad4e0>,
#  'allahin': <gensim.models.keyedvectors.Vocab at 0x63b5ad518>,
#  'nternet': <gensim.models.keyedvectors.Vocab at 0x63b5ad550>,
#  'allahsız': <gensim.models.keyedvectors.Vocab at 0x63b5ad588>,
#  'turkcelle': <gensim.models.keyedvectors.Vocab at 0x63b5ad5c0>,
#  'çekmiyo': <gensim.models.keyedvectors.Vocab at 0x63b5ad5f8>,
#  'biçim': <gensim.models.keyedvectors.Vocab at 0x63b5ad630>,
#  'sin': <gensim.models.keyedvectors.Vocab at 0x63b5ad668>,
#  'edge': <gensim.models.keyedvectors.Vocab at 0x63b5ad6a0>,
#  'sacmalik': <gensim.models.keyedvectors.Vocab at 0x63b5ad6d8>,
#  'abv': <gensim.models.keyedvectors.Vocab at 0x63b5ad710>,
#  'oda': <gensim.models.keyedvectors.Vocab at 0x63b5ad748>,
#  'gerçek': <gensim.models.keyedvectors.Vocab at 0x63b5ad780>,
#  'bok': <gensim.models.keyedvectors.Vocab at 0x63b5ad7b8>,
#  'ur': <gensim.models.keyedvectors.Vocab at 0x63b5ad7f0>,
#  'kullanirsam': <gensim.models.keyedvectors.Vocab at 0x63b5ad828>,
#  'adi': <gensim.models.keyedvectors.Vocab at 0x63b5ad860>,
#  'inan': <gensim.models.keyedvectors.Vocab at 0x63b5ad898>,
#  'yaşa': <gensim.models.keyedvectors.Vocab at 0x63b5ad8d0>,
#  'oparetör': <gensim.models.keyedvectors.Vocab at 0x63b5ad908>,
#  'dürüst': <gensim.models.keyedvectors.Vocab at 0x63b5ad940>,
#  'aş': <gensim.models.keyedvectors.Vocab at 0x63b5ad978>,
#  '13': <gensim.models.keyedvectors.Vocab at 0x63b5ad9b0>,
#  'tl': <gensim.models.keyedvectors.Vocab at 0x63b5ad9e8>,
#  'kit': <gensim.models.keyedvectors.Vocab at 0x63b5ada20>,
#  'otamatik': <gensim.models.keyedvectors.Vocab at 0x63b5ada58>,
#  'duracakdı': <gensim.models.keyedvectors.Vocab at 0x63b5ada90>,
#  'sahtekar': <gensim.models.keyedvectors.Vocab at 0x63b5adac8>,
#  'gerizekalı': <gensim.models.keyedvectors.Vocab at 0x63b5adb00>,
#  'kardeş': <gensim.models.keyedvectors.Vocab at 0x63b5adb38>,
#  'dair': <gensim.models.keyedvectors.Vocab at 0x63b5adb70>,
#  'yolla': <gensim.models.keyedvectors.Vocab at 0x63b5adba8>,
#  'ömür': <gensim.models.keyedvectors.Vocab at 0x63b5adbe0>,
#  'tövbe': <gensim.models.keyedvectors.Vocab at 0x63b5adc18>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x63b5adc50>,
#  'zaman': <gensim.models.keyedvectors.Vocab at 0x63b5adc88>,
#  'hız': <gensim.models.keyedvectors.Vocab at 0x63b5adcc0>,
#  'rezalet': <gensim.models.keyedvectors.Vocab at 0x63b5adcf8>,
#  'kontrat': <gensim.models.keyedvectors.Vocab at 0x63b5add30>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x63b5add68>,
#  'ay': <gensim.models.keyedvectors.Vocab at 0x63b5adda0>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x63b5addd8>,
#  'yükle': <gensim.models.keyedvectors.Vocab at 0x63b5ade10>,
#  'gelin': <gensim.models.keyedvectors.Vocab at 0x63b5ade48>,
#  'elde': <gensim.models.keyedvectors.Vocab at 0x63b5ade80>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x63b5adeb8>,
#  'uyanık': <gensim.models.keyedvectors.Vocab at 0x63b5adef0>,
#  'bugün': <gensim.models.keyedvectors.Vocab at 0x63b5adf28>,
#  'mutlu': <gensim.models.keyedvectors.Vocab at 0x63b5adf60>,
#  'şua': <gensim.models.keyedvectors.Vocab at 0x63b5adf98>,
#  'internetim': <gensim.models.keyedvectors.Vocab at 0x63b5adfd0>,
#  'hafta': <gensim.models.keyedvectors.Vocab at 0x63b5b0048>,
#  'yıl': <gensim.models.keyedvectors.Vocab at 0x63b5b0080>,
#  'vallaha': <gensim.models.keyedvectors.Vocab at 0x63b5b00b8>,
#  'bağlantı': <gensim.models.keyedvectors.Vocab at 0x63b5b00f0>,
#  'açık': <gensim.models.keyedvectors.Vocab at 0x63b5b0128>,
#  'sınıf': <gensim.models.keyedvectors.Vocab at 0x63b5b0160>,
#  'yazık': <gensim.models.keyedvectors.Vocab at 0x63b5b0198>,
#  'eziyet': <gensim.models.keyedvectors.Vocab at 0x63b5b01d0>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x63b5b0208>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x63b5b0240>,
#  'sene': <gensim.models.keyedvectors.Vocab at 0x63b5b0278>,
#  'belani': <gensim.models.keyedvectors.Vocab at 0x63b5b02b0>,
#  'haram': <gensim.models.keyedvectors.Vocab at 0x63b5b02e8>,
#  'zıkkım': <gensim.models.keyedvectors.Vocab at 0x63b5b0320>,
#  'samsun': <gensim.models.keyedvectors.Vocab at 0x63b5b0358>,
#  'çekiyo': <gensim.models.keyedvectors.Vocab at 0x63b5b0390>,
#  'ada': <gensim.models.keyedvectors.Vocab at 0x63b5b03c8>,
#  'bırak': <gensim.models.keyedvectors.Vocab at 0x63b5b0400>,
#  'beeee': <gensim.models.keyedvectors.Vocab at 0x63b5b0438>,
#  'galiba': <gensim.models.keyedvectors.Vocab at 0x63b5b0470>,
#  'yavaşla': <gensim.models.keyedvectors.Vocab at 0x63b5b04a8>,
#  'metro': <gensim.models.keyedvectors.Vocab at 0x63b5b04e0>,
#  'konuş': <gensim.models.keyedvectors.Vocab at 0x63b5b0518>,
#  'açıkla': <gensim.models.keyedvectors.Vocab at 0x63b5b0550>,
#  'firma': <gensim.models.keyedvectors.Vocab at 0x63b5b0588>,
#  'odedigim': <gensim.models.keyedvectors.Vocab at 0x63b5b05c0>,
#  'faturala': <gensim.models.keyedvectors.Vocab at 0x63b5b05f8>,
#  'bol': <gensim.models.keyedvectors.Vocab at 0x63b5b0630>,
#  'net': <gensim.models.keyedvectors.Vocab at 0x63b5b0668>,
#  'yemin': <gensim.models.keyedvectors.Vocab at 0x63b5b06a0>,
#  'eder': <gensim.models.keyedvectors.Vocab at 0x63b5b06d8>,
#  'ton': <gensim.models.keyedvectors.Vocab at 0x63b5b0710>,
#  'dolu': <gensim.models.keyedvectors.Vocab at 0x63b5b0748>,
#  'embesil': <gensim.models.keyedvectors.Vocab at 0x63b5b0780>,
#  'üstüste': <gensim.models.keyedvectors.Vocab at 0x63b5b07b8>,
#  'tut': <gensim.models.keyedvectors.Vocab at 0x63b5b07f0>,
#  'gayrettepe': <gensim.models.keyedvectors.Vocab at 0x63b5b0828>,
#  '3g': <gensim.models.keyedvectors.Vocab at 0x63b5b0860>,
#  'eriş': <gensim.models.keyedvectors.Vocab at 0x63b5b0898>,
#  'ney': <gensim.models.keyedvectors.Vocab at 0x63b5b08d0>,
#  'kandırmacası': <gensim.models.keyedvectors.Vocab at 0x63b5b0908>,
#  'avea': <gensim.models.keyedvectors.Vocab at 0x63b5b0940>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x63b5b0978>,
#  'işe': <gensim.models.keyedvectors.Vocab at 0x63b5b09b0>,
#  'resmen': <gensim.models.keyedvectors.Vocab at 0x63b5b09e8>,
#  'tekrar': <gensim.models.keyedvectors.Vocab at 0x63b5b0a20>,
#  'sefer': <gensim.models.keyedvectors.Vocab at 0x63b5b0a58>,
#  'dene': <gensim.models.keyedvectors.Vocab at 0x63b5b0a90>,
#  'kafa': <gensim.models.keyedvectors.Vocab at 0x63b5b0ac8>,
#  'deli': <gensim.models.keyedvectors.Vocab at 0x63b5b0b00>,
#  'soru': <gensim.models.keyedvectors.Vocab at 0x63b5b0b38>,
#  'ayricaliklari': <gensim.models.keyedvectors.Vocab at 0x63b5b0b70>,
#  'neymis': <gensim.models.keyedvectors.Vocab at 0x63b5b0ba8>,
#  'bak': <gensim.models.keyedvectors.Vocab at 0x63b5b0be0>,
#  'hattina': <gensim.models.keyedvectors.Vocab at 0x63b5b0c18>,
#  'evet': <gensim.models.keyedvectors.Vocab at 0x63b5b0c50>,
#  'dort': <gensim.models.keyedvectors.Vocab at 0x63b5b0c88>,
#  'ceker': <gensim.models.keyedvectors.Vocab at 0x63b5b0cc0>,
#  'olayi': <gensim.models.keyedvectors.Vocab at 0x63b5b0cf8>,
#  'kadın': <gensim.models.keyedvectors.Vocab at 0x63b5b0d30>,
#  'gül': <gensim.models.keyedvectors.Vocab at 0x63b5b0d68>,
#  'kucak': <gensim.models.keyedvectors.Vocab at 0x63b5b0da0>,
#  'kız': <gensim.models.keyedvectors.Vocab at 0x63b5b0dd8>,
#  'telekom': <gensim.models.keyedvectors.Vocab at 0x63b5b0e10>,
#  'arena': <gensim.models.keyedvectors.Vocab at 0x63b5b0e48>,
#  'kağnı': <gensim.models.keyedvectors.Vocab at 0x63b5b0e80>,
#  'kandır': <gensim.models.keyedvectors.Vocab at 0x63b5b0eb8>,
#  'yarın': <gensim.models.keyedvectors.Vocab at 0x63b5b0ef0>,
#  'karar': <gensim.models.keyedvectors.Vocab at 0x63b5b0f28>,
#  'dd': <gensim.models.keyedvectors.Vocab at 0x63b5b0f60>,
#  'mekan': <gensim.models.keyedvectors.Vocab at 0x63b5b0f98>,
#  'sıcak': <gensim.models.keyedvectors.Vocab at 0x63b5b0fd0>,
#  'şebeke': <gensim.models.keyedvectors.Vocab at 0x63b5b3048>,
#  'geccem': <gensim.models.keyedvectors.Vocab at 0x63b5b3080>,
#  'kesin': <gensim.models.keyedvectors.Vocab at 0x63b5b30b8>,
#  'önem': <gensim.models.keyedvectors.Vocab at 0x63b5b30f0>,
#  'şahıs': <gensim.models.keyedvectors.Vocab at 0x63b5b3128>,
#  'çat': <gensim.models.keyedvectors.Vocab at 0x63b5b3160>,
#  'mesj': <gensim.models.keyedvectors.Vocab at 0x63b5b3198>,
#  'gelir': <gensim.models.keyedvectors.Vocab at 0x63b5b31d0>,
#  'heyecan': <gensim.models.keyedvectors.Vocab at 0x63b5b3208>,
#  'görün': <gensim.models.keyedvectors.Vocab at 0x63b5b3240>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x63b5b3278>,
#  'taşı': <gensim.models.keyedvectors.Vocab at 0x63b5b32b0>,
#  'insan': <gensim.models.keyedvectors.Vocab at 0x63b5b32e8>,
#  'ücret': <gensim.models.keyedvectors.Vocab at 0x63b5b3320>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x63b5b3358>,
#  'sayılı': <gensim.models.keyedvectors.Vocab at 0x63b5b3390>,
#  'gün': <gensim.models.keyedvectors.Vocab at 0x63b5b33c8>,
#  'atıyo': <gensim.models.keyedvectors.Vocab at 0x63b5b3400>,
#  'çıldır': <gensim.models.keyedvectors.Vocab at 0x63b5b3438>,
#  'geçer': <gensim.models.keyedvectors.Vocab at 0x63b5b3470>,
#  'dağ': <gensim.models.keyedvectors.Vocab at 0x63b5b34a8>,
#  'tepe': <gensim.models.keyedvectors.Vocab at 0x63b5b34e0>,
#  'veda': <gensim.models.keyedvectors.Vocab at 0x63b5b3518>,
#  'devir': <gensim.models.keyedvectors.Vocab at 0x63b5b3550>,
#  'müthiş': <gensim.models.keyedvectors.Vocab at 0x63b5b3588>,
#  'fikri': <gensim.models.keyedvectors.Vocab at 0x63b5b35c0>,
#  'parlak': <gensim.models.keyedvectors.Vocab at 0x63b5b35f8>,
#  'prodüksiyon': <gensim.models.keyedvectors.Vocab at 0x63b5b3630>,
#  'başarı': <gensim.models.keyedvectors.Vocab at 0x63b5b3668>,
#  'bıktır': <gensim.models.keyedvectors.Vocab at 0x63b5b36a0>,
#  'aday': <gensim.models.keyedvectors.Vocab at 0x63b5b36d8>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x63b5b3710>,
#  'gece': <gensim.models.keyedvectors.Vocab at 0x63b5b3748>,
#  'gündüz': <gensim.models.keyedvectors.Vocab at 0x63b5b3780>,
#  'yağ': <gensim.models.keyedvectors.Vocab at 0x63b5b37b8>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x63b5b37f0>,
#  'kazan': <gensim.models.keyedvectors.Vocab at 0x63b5b3828>,
#  'yandaş': <gensim.models.keyedvectors.Vocab at 0x63b5b3860>,
#  'yalaka': <gensim.models.keyedvectors.Vocab at 0x63b5b3898>,
#  'hale': <gensim.models.keyedvectors.Vocab at 0x63b5b38d0>,
#  'tavsiye': <gensim.models.keyedvectors.Vocab at 0x63b5b3908>,
#  'sifir': <gensim.models.keyedvectors.Vocab at 0x63b5b3940>,
#  'ttnet': <gensim.models.keyedvectors.Vocab at 0x63b5b3978>,
#  'yol': <gensim.models.keyedvectors.Vocab at 0x63b5b39b0>,
#  'basladin': <gensim.models.keyedvectors.Vocab at 0x63b5b39e8>,
#  'belasini': <gensim.models.keyedvectors.Vocab at 0x63b5b3a20>,
#  'anca': <gensim.models.keyedvectors.Vocab at 0x63b5b3a58>,
#  'sem': <gensim.models.keyedvectors.Vocab at 0x63b5b3a90>,
#  'lanet': <gensim.models.keyedvectors.Vocab at 0x63b5b3ac8>,
#  'yaaa': <gensim.models.keyedvectors.Vocab at 0x63b5b3b00>,
#  'felç': <gensim.models.keyedvectors.Vocab at 0x63b5b3b38>,
#  'hak': <gensim.models.keyedvectors.Vocab at 0x63b5b3b70>,
#  'veri': <gensim.models.keyedvectors.Vocab at 0x63b5b3ba8>,
#  'limit': <gensim.models.keyedvectors.Vocab at 0x63b5b3be0>,
#  'düşür': <gensim.models.keyedvectors.Vocab at 0x63b5b3c18>,
#  'dolandır': <gensim.models.keyedvectors.Vocab at 0x63b5b3c50>,
#  'sabah': <gensim.models.keyedvectors.Vocab at 0x63b5b3c88>,
#  'yaptim': <gensim.models.keyedvectors.Vocab at 0x63b5b3cc0>,
#  'hal': <gensim.models.keyedvectors.Vocab at 0x63b5b3cf8>,
#  'internetimi': <gensim.models.keyedvectors.Vocab at 0x63b5b3d30>,
#  'kullanmadim': <gensim.models.keyedvectors.Vocab at 0x63b5b3d68>,
#  'boşuna': <gensim.models.keyedvectors.Vocab at 0x63b5b3da0>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x63b5b3dd8>,
#  'fatih': <gensim.models.keyedvectors.Vocab at 0x63b5b3e10>,
#  'fedai': <gensim.models.keyedvectors.Vocab at 0x63b5b3e48>,
#  'kara': <gensim.models.keyedvectors.Vocab at 0x63b5b3e80>,
#  'murat': <gensim.models.keyedvectors.Vocab at 0x63b5b3eb8>,
#  'uğraş': <gensim.models.keyedvectors.Vocab at 0x63b5b3ef0>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x63b5b3f28>,
#  'küfür': <gensim.models.keyedvectors.Vocab at 0x63b5b3f60>,
#  'bedel': <gensim.models.keyedvectors.Vocab at 0x63b5b3f98>,
#  'sinirli': <gensim.models.keyedvectors.Vocab at 0x63b5b3fd0>,
#  'bitir': <gensim.models.keyedvectors.Vocab at 0x63b5b7048>,
#  'sosyal': <gensim.models.keyedvectors.Vocab at 0x63b5b7080>,
#  'digitürk': <gensim.models.keyedvectors.Vocab at 0x63b5b70b8>,
#  'alay': <gensim.models.keyedvectors.Vocab at 0x63b5b70f0>,
#  'illet': <gensim.models.keyedvectors.Vocab at 0x63b5b7128>,
#  'moral': <gensim.models.keyedvectors.Vocab at 0x63b5b7160>,
#  'bozul': <gensim.models.keyedvectors.Vocab at 0x63b5b7198>,
#  'pislik': <gensim.models.keyedvectors.Vocab at 0x63b5b71d0>,
#  'kahır': <gensim.models.keyedvectors.Vocab at 0x63b5b7208>,
#  'demin': <gensim.models.keyedvectors.Vocab at 0x63b5b7240>,
#  'öv': <gensim.models.keyedvectors.Vocab at 0x63b5b7278>,
#  'turkcel': <gensim.models.keyedvectors.Vocab at 0x63b5b72b0>,
#  'eski': <gensim.models.keyedvectors.Vocab at 0x63b5b72e8>,
#  'sevgi': <gensim.models.keyedvectors.Vocab at 0x63b5b7320>,
#  'atıyosun': <gensim.models.keyedvectors.Vocab at 0x63b5b7358>,
#  'kurtul': <gensim.models.keyedvectors.Vocab at 0x63b5b7390>,
#  'yanlış': <gensim.models.keyedvectors.Vocab at 0x63b5b73c8>,
#  'internette': <gensim.models.keyedvectors.Vocab at 0x63b5b7400>,
#  'sıç': <gensim.models.keyedvectors.Vocab at 0x63b5b7438>,
#  'düşün': <gensim.models.keyedvectors.Vocab at 0x63b5b7470>,
#  'fiyat': <gensim.models.keyedvectors.Vocab at 0x63b5b74a8>,
#  'bil': <gensim.models.keyedvectors.Vocab at 0x63b5b74e0>,
#  'leş': <gensim.models.keyedvectors.Vocab at 0x63b5b7518>,
#  'dogum': <gensim.models.keyedvectors.Vocab at 0x63b5b7550>,
#  'günü': <gensim.models.keyedvectors.Vocab at 0x63b5b7588>,
#  'türlü': <gensim.models.keyedvectors.Vocab at 0x63b5b75c0>,
#  'abi': <gensim.models.keyedvectors.Vocab at 0x63b5b75f8>,
#  'yapsin': <gensim.models.keyedvectors.Vocab at 0x63b5b7630>,
#  'ilgilen': <gensim.models.keyedvectors.Vocab at 0x63b5b7668>,
#  'sırf': <gensim.models.keyedvectors.Vocab at 0x63b5b76a0>,
#  'yuzden': <gensim.models.keyedvectors.Vocab at 0x63b5b76d8>,
#  'hattimi': <gensim.models.keyedvectors.Vocab at 0x63b5b7710>,
#  'taşıyacam': <gensim.models.keyedvectors.Vocab at 0x63b5b7748>,
#  'göz': <gensim.models.keyedvectors.Vocab at 0x63b5b7780>,
#  'çık': <gensim.models.keyedvectors.Vocab at 0x63b5b77b8>,
#  'bayıl': <gensim.models.keyedvectors.Vocab at 0x63b5b77f0>,
#  'genç': <gensim.models.keyedvectors.Vocab at 0x63b5b7828>,
#  'utan': <gensim.models.keyedvectors.Vocab at 0x63b5b7860>,
#  'tarife': <gensim.models.keyedvectors.Vocab at 0x63b5b7898>,
#  'pttcell': <gensim.models.keyedvectors.Vocab at 0x63b5b78d0>,
#  'acep': <gensim.models.keyedvectors.Vocab at 0x63b5b7908>,
#  '96kbps': <gensim.models.keyedvectors.Vocab at 0x63b5b7940>,
#  'felan': <gensim.models.keyedvectors.Vocab at 0x63b5b7978>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x63b5b79b0>,
#  'yad': <gensim.models.keyedvectors.Vocab at 0x63b5b79e8>,
#  'yoğun': <gensim.models.keyedvectors.Vocab at 0x63b5b7a20>,
#  'itina': <gensim.models.keyedvectors.Vocab at 0x63b5b7a58>,
#  'sıkıntı': <gensim.models.keyedvectors.Vocab at 0x63b5b7a90>,
#  'yarat': <gensim.models.keyedvectors.Vocab at 0x63b5b7ac8>,
#  'sık': <gensim.models.keyedvectors.Vocab at 0x63b5b7b00>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x63b5b7b38>,
#  'kına': <gensim.models.keyedvectors.Vocab at 0x63b5b7b70>,
#  'pis': <gensim.models.keyedvectors.Vocab at 0x63b5b7ba8>,
#  'yavşak': <gensim.models.keyedvectors.Vocab at 0x63b5b7be0>,
#  'itiraf': <gensim.models.keyedvectors.Vocab at 0x63b5b7c18>,
#  'sarı': <gensim.models.keyedvectors.Vocab at 0x63b5b7c50>,
#  'kutu': <gensim.models.keyedvectors.Vocab at 0x63b5b7c88>,
#  'migros': <gensim.models.keyedvectors.Vocab at 0x63b5b7cc0>,
#  'sanal': <gensim.models.keyedvectors.Vocab at 0x63b5b7cf8>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x63b5b7d30>,
#  'çeki': <gensim.models.keyedvectors.Vocab at 0x63b5b7d68>,
#  'şifre': <gensim.models.keyedvectors.Vocab at 0x63b5b7da0>,
#  'sülale': <gensim.models.keyedvectors.Vocab at 0x63b5b7dd8>,
#  'sakin': <gensim.models.keyedvectors.Vocab at 0x63b5b7e10>,
#  'winn': <gensim.models.keyedvectors.Vocab at 0x63b5b7e48>,
#  'kullanmayin': <gensim.models.keyedvectors.Vocab at 0x63b5b7e80>,
#  'iptal': <gensim.models.keyedvectors.Vocab at 0x63b5b7eb8>,
#  'cani': <gensim.models.keyedvectors.Vocab at 0x63b5b7ef0>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x63b5b7f28>,
#  'boyun': <gensim.models.keyedvectors.Vocab at 0x63b5b7f60>,
#  'ramazan': <gensim.models.keyedvectors.Vocab at 0x63b5b7f98>,
#  'millet': <gensim.models.keyedvectors.Vocab at 0x63b5b7fd0>,
#  'taşım': <gensim.models.keyedvectors.Vocab at 0x63b5bb048>,
#  'kazik': <gensim.models.keyedvectors.Vocab at 0x63b5bb080>,
#  'yed': <gensim.models.keyedvectors.Vocab at 0x63b5bb0b8>,
#  'artik': <gensim.models.keyedvectors.Vocab at 0x63b5bb0f0>,
#  'geciyorum': <gensim.models.keyedvectors.Vocab at 0x63b5bb128>,
#  'ayır': <gensim.models.keyedvectors.Vocab at 0x63b5bb160>,
#  'nefret': <gensim.models.keyedvectors.Vocab at 0x63b5bb198>,
#  'dayan': <gensim.models.keyedvectors.Vocab at 0x63b5bb1d0>,
#  'yeni': <gensim.models.keyedvectors.Vocab at 0x63b5bb208>,
#  'getir': <gensim.models.keyedvectors.Vocab at 0x63b5bb240>,
#  'sony': <gensim.models.keyedvectors.Vocab at 0x63b5bb278>,
#  'xperia': <gensim.models.keyedvectors.Vocab at 0x63b5bb2b0>,
#  'z2': <gensim.models.keyedvectors.Vocab at 0x63b5bb2e8>,
#  'akşam': <gensim.models.keyedvectors.Vocab at 0x63b5bb320>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x63b5bb358>,
#  'ayrı': <gensim.models.keyedvectors.Vocab at 0x63b5bb390>,
#  'inşallah': <gensim.models.keyedvectors.Vocab at 0x63b5bb3c8>,
#  'iflas': <gensim.models.keyedvectors.Vocab at 0x63b5bb400>,
#  'fena': <gensim.models.keyedvectors.Vocab at 0x63b5bb438>,
#  'kerim': <gensim.models.keyedvectors.Vocab at 0x63b5bb470>,
#  'turbo': <gensim.models.keyedvectors.Vocab at 0x63b5bb4a8>,
#  'sakın': <gensim.models.keyedvectors.Vocab at 0x63b5bb4e0>,
#  'ağı': <gensim.models.keyedvectors.Vocab at 0x63b5bb518>,
#  'mumla': <gensim.models.keyedvectors.Vocab at 0x63b5bb550>,
#  'berbat': <gensim.models.keyedvectors.Vocab at 0x63b5bb588>,
#  'kop': <gensim.models.keyedvectors.Vocab at 0x63b5bb5c0>,
#  'hava': <gensim.models.keyedvectors.Vocab at 0x63b5bb5f8>,
#  'kandil': <gensim.models.keyedvectors.Vocab at 0x63b5bb630>,
#  'kilitle': <gensim.models.keyedvectors.Vocab at 0x63b5bb668>,
#  'deprem': <gensim.models.keyedvectors.Vocab at 0x63b5bb6a0>,
#  'titre': <gensim.models.keyedvectors.Vocab at 0x63b5bb6d8>,
#  'seferi': <gensim.models.keyedvectors.Vocab at 0x63b5bb710>,
#  'haber': <gensim.models.keyedvectors.Vocab at 0x63b5bb748>,
#  'bakiye': <gensim.models.keyedvectors.Vocab at 0x63b5bb780>,
#  'hırsız': <gensim.models.keyedvectors.Vocab at 0x63b5bb7b8>,
#  'amaç': <gensim.models.keyedvectors.Vocab at 0x63b5bb7f0>,
#  'allahım': <gensim.models.keyedvectors.Vocab at 0x63b5bb828>,
#  'kontur': <gensim.models.keyedvectors.Vocab at 0x63b5bb860>,
#  'sms': <gensim.models.keyedvectors.Vocab at 0x63b5bb898>,
#  'oc': <gensim.models.keyedvectors.Vocab at 0x63b5bb8d0>,
#  'ufak': <gensim.models.keyedvectors.Vocab at 0x63b5bb908>,
#  'kes': <gensim.models.keyedvectors.Vocab at 0x63b5bb940>,
#  'baş': <gensim.models.keyedvectors.Vocab at 0x63b5bb978>,
#  'buyruk': <gensim.models.keyedvectors.Vocab at 0x63b5bb9b0>,
#  'tavır': <gensim.models.keyedvectors.Vocab at 0x63b5bb9e8>,
#  'boz': <gensim.models.keyedvectors.Vocab at 0x63b5bba20>,
#  'turkcellli': <gensim.models.keyedvectors.Vocab at 0x63b5bba58>,
#  'hayat': <gensim.models.keyedvectors.Vocab at 0x63b5bba90>,
#  'gecmem': <gensim.models.keyedvectors.Vocab at 0x63b5bbac8>,
#  'lazim': <gensim.models.keyedvectors.Vocab at 0x63b5bbb00>,
#  'bkz': <gensim.models.keyedvectors.Vocab at 0x63b5bbb38>,
#  '70': <gensim.models.keyedvectors.Vocab at 0x63b5bbb70>,
#  'kredi': <gensim.models.keyedvectors.Vocab at 0x63b5bbba8>,
#  'kart': <gensim.models.keyedvectors.Vocab at 0x63b5bbbe0>,
#  'bloke': <gensim.models.keyedvectors.Vocab at 0x63b5bbc18>,
#  'rakam': <gensim.models.keyedvectors.Vocab at 0x63b5bbc50>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x63b5bbc88>,
#  'sorun': <gensim.models.keyedvectors.Vocab at 0x63b5bbcc0>,
#  'stres': <gensim.models.keyedvectors.Vocab at 0x63b5bbcf8>,
#  'paha': <gensim.models.keyedvectors.Vocab at 0x63b5bbd30>,
#  'biç': <gensim.models.keyedvectors.Vocab at 0x63b5bbd68>,
#  'masraf': <gensim.models.keyedvectors.Vocab at 0x63b5bbda0>,
#  'sömürge': <gensim.models.keyedvectors.Vocab at 0x63b5bbdd8>,
#  'sirketi': <gensim.models.keyedvectors.Vocab at 0x63b5bbe10>,
#  'devlet': <gensim.models.keyedvectors.Vocab at 0x63b5bbe48>,
#  'dinlen': <gensim.models.keyedvectors.Vocab at 0x63b5bbe80>,
#  'korku': <gensim.models.keyedvectors.Vocab at 0x63b5bbeb8>,
#  'gizli': <gensim.models.keyedvectors.Vocab at 0x63b5bbef0>,
#  'toplantı': <gensim.models.keyedvectors.Vocab at 0x63b5bbf28>,
#  'hayrola': <gensim.models.keyedvectors.Vocab at 0x63b5bbf60>,
#  'turkcellhizmet': <gensim.models.keyedvectors.Vocab at 0x63b5bbf98>,
#  'bugun': <gensim.models.keyedvectors.Vocab at 0x63b5bbfd0>,
#  'attigi': <gensim.models.keyedvectors.Vocab at 0x63b5be048>,
#  'kaziklara': <gensim.models.keyedvectors.Vocab at 0x63b5be080>,
#  'agladim': <gensim.models.keyedvectors.Vocab at 0x63b5be0b8>,
#  'devam': <gensim.models.keyedvectors.Vocab at 0x63b5be0f0>,
#  'onca': <gensim.models.keyedvectors.Vocab at 0x63b5be128>,
#  'şair': <gensim.models.keyedvectors.Vocab at 0x63b5be160>,
#  'helal': <gensim.models.keyedvectors.Vocab at 0x63b5be198>,
#  'baska': <gensim.models.keyedvectors.Vocab at 0x63b5be1d0>,
#  'bı': <gensim.models.keyedvectors.Vocab at 0x63b5be208>,
#  'sey': <gensim.models.keyedvectors.Vocab at 0x63b5be240>,
#  'ıstemıyorum': <gensim.models.keyedvectors.Vocab at 0x63b5be278>,
#  'duygu': <gensim.models.keyedvectors.Vocab at 0x63b5be2b0>,
#  'oyna': <gensim.models.keyedvectors.Vocab at 0x63b5be2e8>,
#  'uyuz': <gensim.models.keyedvectors.Vocab at 0x63b5be320>,
#  'doğru': <gensim.models.keyedvectors.Vocab at 0x63b5be358>,
#  'ey': <gensim.models.keyedvectors.Vocab at 0x63b5be390>,
#  'asker': <gensim.models.keyedvectors.Vocab at 0x63b5be3c8>,
#  'hic': <gensim.models.keyedvectors.Vocab at 0x63b5be400>,
#  'yatır': <gensim.models.keyedvectors.Vocab at 0x63b5be438>,
#  'yuh': <gensim.models.keyedvectors.Vocab at 0x63b5be470>,
#  'odemeye': <gensim.models.keyedvectors.Vocab at 0x63b5be4a8>,
#  'gittigim': <gensim.models.keyedvectors.Vocab at 0x63b5be4e0>,
#  'karsilastigim': <gensim.models.keyedvectors.Vocab at 0x63b5be518>,
#  'odemeyi': <gensim.models.keyedvectors.Vocab at 0x63b5be550>,
#  'iş': <gensim.models.keyedvectors.Vocab at 0x63b5be588>,
#  'zengin': <gensim.models.keyedvectors.Vocab at 0x63b5be5c0>,
#  'parasi': <gensim.models.keyedvectors.Vocab at 0x63b5be5f8>,
#  'yokmu': <gensim.models.keyedvectors.Vocab at 0x63b5be630>,
#  'cim': <gensim.models.keyedvectors.Vocab at 0x63b5be668>,
#  'icim': <gensim.models.keyedvectors.Vocab at 0x63b5be6a0>,
#  'smsi': <gensim.models.keyedvectors.Vocab at 0x63b5be6d8>,
#  'kuru': <gensim.models.keyedvectors.Vocab at 0x63b5be710>,
#  'atti': <gensim.models.keyedvectors.Vocab at 0x63b5be748>,
#  'sok': <gensim.models.keyedvectors.Vocab at 0x63b5be780>,
#  'tuvalet': <gensim.models.keyedvectors.Vocab at 0x63b5be7b8>,
#  'ayrıl': <gensim.models.keyedvectors.Vocab at 0x63b5be7f0>,
#  'sebep': <gensim.models.keyedvectors.Vocab at 0x63b5be828>,
#  'memnun': <gensim.models.keyedvectors.Vocab at 0x63b5be860>,
#  'akıl': <gensim.models.keyedvectors.Vocab at 0x63b5be898>,
#  'isim': <gensim.models.keyedvectors.Vocab at 0x63b5be8d0>,
#  'kısa': <gensim.models.keyedvectors.Vocab at 0x63b5be908>,
#  'azı': <gensim.models.keyedvectors.Vocab at 0x63b5be940>,
#  'sabri': <gensim.models.keyedvectors.Vocab at 0x63b5be978>,
#  'rey': <gensim.models.keyedvectors.Vocab at 0x63b5be9b0>,
#  'ilgi': <gensim.models.keyedvectors.Vocab at 0x63b5be9e8>,
#  'guzel': <gensim.models.keyedvectors.Vocab at 0x63b5bea20>,
#  'marka': <gensim.models.keyedvectors.Vocab at 0x63b5bea58>,
#  'dunyanin': <gensim.models.keyedvectors.Vocab at 0x63b5bea90>,
#  'reklamini': <gensim.models.keyedvectors.Vocab at 0x63b5beac8>,
#  'cekti': <gensim.models.keyedvectors.Vocab at 0x63b5beb00>,
#  'turkcellden': <gensim.models.keyedvectors.Vocab at 0x63b5beb38>,
#  'versi': <gensim.models.keyedvectors.Vocab at 0x63b5beb70>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x63b5beba8>,
#  'bitiyo': <gensim.models.keyedvectors.Vocab at 0x63b5bebe0>,
#  'ek': <gensim.models.keyedvectors.Vocab at 0x63b5bec18>,
#  'lüks': <gensim.models.keyedvectors.Vocab at 0x63b5bec50>,
#  'katı': <gensim.models.keyedvectors.Vocab at 0x63b5bec88>,
#  'ateş': <gensim.models.keyedvectors.Vocab at 0x63b5becc0>,
#  'reklamlari': <gensim.models.keyedvectors.Vocab at 0x63b5becf8>,
#  'saçma': <gensim.models.keyedvectors.Vocab at 0x63b5bed30>,
#  'çalış': <gensim.models.keyedvectors.Vocab at 0x63b5bed68>,
#  'sömürü': <gensim.models.keyedvectors.Vocab at 0x63b5beda0>,
#  'yapıyo': <gensim.models.keyedvectors.Vocab at 0x63b5bedd8>,
#  'ateşle': <gensim.models.keyedvectors.Vocab at 0x63b5bee10>,
#  'sal': <gensim.models.keyedvectors.Vocab at 0x63b5bee48>,
#  'ilet': <gensim.models.keyedvectors.Vocab at 0x63b5bee80>,
#  'suç': <gensim.models.keyedvectors.Vocab at 0x63b5beeb8>,
#  'sıkıl': <gensim.models.keyedvectors.Vocab at 0x63b5beef0>,
#  'coca': <gensim.models.keyedvectors.Vocab at 0x63b5bef28>,
#  'cola': <gensim.models.keyedvectors.Vocab at 0x63b5bef60>,
#  'yla': <gensim.models.keyedvectors.Vocab at 0x63b5bef98>,
#  'vur': <gensim.models.keyedvectors.Vocab at 0x63b5befd0>,
#  'umut': <gensim.models.keyedvectors.Vocab at 0x63b5c2048>,
#  'sine': <gensim.models.keyedvectors.Vocab at 0x63b5c2080>,
#  'ocak': <gensim.models.keyedvectors.Vocab at 0x63b5c20b8>,
#  'tanı': <gensim.models.keyedvectors.Vocab at 0x63b5c20f0>,
#  'kapitalist': <gensim.models.keyedvectors.Vocab at 0x63b5c2128>,
#  'dünya': <gensim.models.keyedvectors.Vocab at 0x63b5c2160>,
#  'soyguncu': <gensim.models.keyedvectors.Vocab at 0x63b5c2198>,
#  'si': <gensim.models.keyedvectors.Vocab at 0x63b5c21d0>,
#  'fi': <gensim.models.keyedvectors.Vocab at 0x63b5c2208>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x63b5c2240>,
#  'hayır': <gensim.models.keyedvectors.Vocab at 0x63b5c2278>,
#  'kada': <gensim.models.keyedvectors.Vocab at 0x63b5c22b0>,
#  'kı': <gensim.models.keyedvectors.Vocab at 0x63b5c22e8>,
#  'unut': <gensim.models.keyedvectors.Vocab at 0x63b5c2320>,
#  'allahın': <gensim.models.keyedvectors.Vocab at 0x63b5c2358>,
#  'burun': <gensim.models.keyedvectors.Vocab at 0x63b5c2390>,
#  'gidi': <gensim.models.keyedvectors.Vocab at 0x63b5c23c8>,
#  'yarış': <gensim.models.keyedvectors.Vocab at 0x63b5c2400>,
#  'birbir': <gensim.models.keyedvectors.Vocab at 0x63b5c2438>,
#  'sapan': <gensim.models.keyedvectors.Vocab at 0x63b5c2470>,
#  'yayın': <gensim.models.keyedvectors.Vocab at 0x63b5c24a8>,
#  'sacma': <gensim.models.keyedvectors.Vocab at 0x63b5c24e0>,
#  'cok': <gensim.models.keyedvectors.Vocab at 0x63b5c2518>,
#  'kaziksin': <gensim.models.keyedvectors.Vocab at 0x63b5c2550>,
#  'sı': <gensim.models.keyedvectors.Vocab at 0x63b5c2588>,
#  'kuruş': <gensim.models.keyedvectors.Vocab at 0x63b5c25c0>,
#  'sesli': <gensim.models.keyedvectors.Vocab at 0x63b5c25f8>,
#  'dinle': <gensim.models.keyedvectors.Vocab at 0x63b5c2630>,
#  'kahrol': <gensim.models.keyedvectors.Vocab at 0x63b5c2668>,
#  'fakir': <gensim.models.keyedvectors.Vocab at 0x63b5c26a0>,
#  'whatsapp': <gensim.models.keyedvectors.Vocab at 0x63b5c26d8>,
#  'kapan': <gensim.models.keyedvectors.Vocab at 0x63b5c2710>,
#  'maxiplus5': <gensim.models.keyedvectors.Vocab at 0x63b5c2748>,
#  'alacak': <gensim.models.keyedvectors.Vocab at 0x63b5c2780>,
#  'vazgeç': <gensim.models.keyedvectors.Vocab at 0x63b5c27b8>,
#  'taksit': <gensim.models.keyedvectors.Vocab at 0x63b5c27f0>,
#  'duvar': <gensim.models.keyedvectors.Vocab at 0x63b5c2828>,
#  'lütfen': <gensim.models.keyedvectors.Vocab at 0x63b5c2860>,
#  'sanirim': <gensim.models.keyedvectors.Vocab at 0x63b5c2898>,
#  'suan': <gensim.models.keyedvectors.Vocab at 0x63b5c28d0>,
#  'servis': <gensim.models.keyedvectors.Vocab at 0x63b5c2908>,
#  'belanizi': <gensim.models.keyedvectors.Vocab at 0x63b5c2940>,
#  'internete': <gensim.models.keyedvectors.Vocab at 0x63b5c2978>,
#  'delir': <gensim.models.keyedvectors.Vocab at 0x63b5c29b0>,
#  'yayvan': <gensim.models.keyedvectors.Vocab at 0x63b5c29e8>,
#  'bebe': <gensim.models.keyedvectors.Vocab at 0x63b5c2a20>,
#  'duyu': <gensim.models.keyedvectors.Vocab at 0x63b5c2a58>,
#  'yapıyolar': <gensim.models.keyedvectors.Vocab at 0x63b5c2a90>,
#  'bodrum': <gensim.models.keyedvectors.Vocab at 0x63b5c2ac8>,
#  'yavas': <gensim.models.keyedvectors.Vocab at 0x63b5c2b00>,
#  'yaziklar': <gensim.models.keyedvectors.Vocab at 0x63b5c2b38>,
#  'reklami': <gensim.models.keyedvectors.Vocab at 0x63b5c2b70>,
#  'salakca': <gensim.models.keyedvectors.Vocab at 0x63b5c2ba8>,
#  'musteri': <gensim.models.keyedvectors.Vocab at 0x63b5c2be0>,
#  'temsil': <gensim.models.keyedvectors.Vocab at 0x63b5c2c18>,
#  'geldigine': <gensim.models.keyedvectors.Vocab at 0x63b5c2c50>,
#  'pisman': <gensim.models.keyedvectors.Vocab at 0x63b5c2c88>,
#  'babet': <gensim.models.keyedvectors.Vocab at 0x63b5c2cc0>,
#  'anne': <gensim.models.keyedvectors.Vocab at 0x63b5c2cf8>,
#  'nternetin': <gensim.models.keyedvectors.Vocab at 0x63b5c2d30>,
#  'keyfi': <gensim.models.keyedvectors.Vocab at 0x63b5c2d68>,
#  'sür': <gensim.models.keyedvectors.Vocab at 0x63b5c2da0>,
#  'gazete': <gensim.models.keyedvectors.Vocab at 0x63b5c2dd8>,
#  'oku': <gensim.models.keyedvectors.Vocab at 0x63b5c2e10>,
#  'ağ': <gensim.models.keyedvectors.Vocab at 0x63b5c2e48>,
#  'giriş': <gensim.models.keyedvectors.Vocab at 0x63b5c2e80>,
#  'işkence': <gensim.models.keyedvectors.Vocab at 0x63b5c2eb8>,
#  'denge': <gensim.models.keyedvectors.Vocab at 0x63b5c2ef0>,
#  'iğrenç': <gensim.models.keyedvectors.Vocab at 0x63b5c2f28>,
#  'küçük': <gensim.models.keyedvectors.Vocab at 0x63b5c2f60>,
#  'soğut': <gensim.models.keyedvectors.Vocab at 0x63b5c2f98>,
#  'yenile': <gensim.models.keyedvectors.Vocab at 0x63b5c2fd0>,
#  'anla': <gensim.models.keyedvectors.Vocab at 0x63b5c5048>,
#  'hemen': <gensim.models.keyedvectors.Vocab at 0x63b5c5080>,
#  'alıyo': <gensim.models.keyedvectors.Vocab at 0x63b5c50b8>,
#  'soy': <gensim.models.keyedvectors.Vocab at 0x63b5c50f0>,
#  'bişey': <gensim.models.keyedvectors.Vocab at 0x63b5c5128>,
#  'başka': <gensim.models.keyedvectors.Vocab at 0x63b5c5160>,
#  'mesele': <gensim.models.keyedvectors.Vocab at 0x63b5c5198>,
#  'çözüm': <gensim.models.keyedvectors.Vocab at 0x63b5c51d0>,
#  'bari': <gensim.models.keyedvectors.Vocab at 0x63b5c5208>,
#  'hisset': <gensim.models.keyedvectors.Vocab at 0x63b5c5240>,
#  'ah': <gensim.models.keyedvectors.Vocab at 0x63b5c5278>,
#  'uygula': <gensim.models.keyedvectors.Vocab at 0x63b5c52b0>,
#  'hergün': <gensim.models.keyedvectors.Vocab at 0x63b5c52e8>,
#  'kol': <gensim.models.keyedvectors.Vocab at 0x63b5c5320>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x63b5c5358>,
#  'duyar': <gensim.models.keyedvectors.Vocab at 0x63b5c5390>,
#  '80': <gensim.models.keyedvectors.Vocab at 0x63b5c53c8>,
#  'paylasinca': <gensim.models.keyedvectors.Vocab at 0x63b5c5400>,
#  'guzeldi': <gensim.models.keyedvectors.Vocab at 0x63b5c5438>,
#  'çağrı': <gensim.models.keyedvectors.Vocab at 0x63b5c5470>,
#  'merkezi': <gensim.models.keyedvectors.Vocab at 0x63b5c54a8>,
#  'reklamlarini': <gensim.models.keyedvectors.Vocab at 0x63b5c54e0>,
#  'ği': <gensim.models.keyedvectors.Vocab at 0x63b5c5518>,
#  'vodafonea': <gensim.models.keyedvectors.Vocab at 0x63b5c5550>,
#  'gecmek': <gensim.models.keyedvectors.Vocab at 0x63b5c5588>,
#  'sart': <gensim.models.keyedvectors.Vocab at 0x63b5c55c0>,
#  'reklamlarindaki': <gensim.models.keyedvectors.Vocab at 0x63b5c55f8>,
#  'kucuk': <gensim.models.keyedvectors.Vocab at 0x63b5c5630>,
#  'kizi': <gensim.models.keyedvectors.Vocab at 0x63b5c5668>,
#  'alip': <gensim.models.keyedvectors.Vocab at 0x63b5c56a0>,
#  'değişim': <gensim.models.keyedvectors.Vocab at 0x63b5c56d8>,
#  'güzel': <gensim.models.keyedvectors.Vocab at 0x63b5c5710>,
#  'çıkın': <gensim.models.keyedvectors.Vocab at 0x63b5c5748>,
#  'tarafindan': <gensim.models.keyedvectors.Vocab at 0x63b5c5780>,
#  'disinda': <gensim.models.keyedvectors.Vocab at 0x63b5c57b8>,
#  'gun': <gensim.models.keyedvectors.Vocab at 0x63b5c57f0>,
#  'çekiyomuş': <gensim.models.keyedvectors.Vocab at 0x63b5c5828>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x63b5c5860>,
#  'mms': <gensim.models.keyedvectors.Vocab at 0x63b5c5898>,
#  'koskoca': <gensim.models.keyedvectors.Vocab at 0x63b5c58d0>,
#  'silivri': <gensim.models.keyedvectors.Vocab at 0x63b5c5908>,
#  'olası': <gensim.models.keyedvectors.Vocab at 0x63b5c5940>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x63b5c5978>,
#  'diyo': <gensim.models.keyedvectors.Vocab at 0x63b5c59b0>,
#  'yüzsüz': <gensim.models.keyedvectors.Vocab at 0x63b5c59e8>,
#  'cevap': <gensim.models.keyedvectors.Vocab at 0x63b5c5a20>,
#  'zarar': <gensim.models.keyedvectors.Vocab at 0x63b5c5a58>,
#  'ciğim': <gensim.models.keyedvectors.Vocab at 0x63b5c5a90>,
#  'teknoloji': <gensim.models.keyedvectors.Vocab at 0x63b5c5ac8>,
#  'ilerle': <gensim.models.keyedvectors.Vocab at 0x63b5c5b00>,
#  'çağ': <gensim.models.keyedvectors.Vocab at 0x63b5c5b38>,
#  'bul': <gensim.models.keyedvectors.Vocab at 0x63b5c5b70>,
#  'batır': <gensim.models.keyedvectors.Vocab at 0x63b5c5ba8>,
#  'aptal': <gensim.models.keyedvectors.Vocab at 0x63b5c5be0>,
#  'dava': <gensim.models.keyedvectors.Vocab at 0x63b5c5c18>,
#  'krs': <gensim.models.keyedvectors.Vocab at 0x63b5c5c50>,
#  'kontürlerimi': <gensim.models.keyedvectors.Vocab at 0x63b5c5c88>,
#  'turkcelli': <gensim.models.keyedvectors.Vocab at 0x63b5c5cc0>,
#  'sirf': <gensim.models.keyedvectors.Vocab at 0x63b5c5cf8>,
#  'pismanliktir': <gensim.models.keyedvectors.Vocab at 0x63b5c5d30>,
#  'gec': <gensim.models.keyedvectors.Vocab at 0x63b5c5d68>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x63b5c5da0>,
#  'yasina': <gensim.models.keyedvectors.Vocab at 0x63b5c5dd8>,
#  'bas': <gensim.models.keyedvectors.Vocab at 0x63b5c5e10>,
#  'kontör': <gensim.models.keyedvectors.Vocab at 0x63b5c5e48>,
#  'kere': <gensim.models.keyedvectors.Vocab at 0x63b5c5e80>,
#  'yiyosun': <gensim.models.keyedvectors.Vocab at 0x63b5c5eb8>,
#  'zalim': <gensim.models.keyedvectors.Vocab at 0x63b5c5ef0>,
#  'kota': <gensim.models.keyedvectors.Vocab at 0x63b5c5f28>,
#  'serefsizini': <gensim.models.keyedvectors.Vocab at 0x63b5c5f60>,
#  'gormedim': <gensim.models.keyedvectors.Vocab at 0x63b5c5f98>,
#  'kabar': <gensim.models.keyedvectors.Vocab at 0x63b5c5fd0>,
#  'güç': <gensim.models.keyedvectors.Vocab at 0x63b5c9048>,
#  'vallahi': <gensim.models.keyedvectors.Vocab at 0x63b5c9080>,
#  'yansı': <gensim.models.keyedvectors.Vocab at 0x63b5c90b8>,
#  'yak': <gensim.models.keyedvectors.Vocab at 0x63b5c90f0>,
#  'cevizlibağ': <gensim.models.keyedvectors.Vocab at 0x63b5c9128>,
#  'ın': <gensim.models.keyedvectors.Vocab at 0x63b5c9160>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x63b5c9198>,
#  '200': <gensim.models.keyedvectors.Vocab at 0x63b5c91d0>,
#  'borç': <gensim.models.keyedvectors.Vocab at 0x63b5c9208>,
#  'ciğer': <gensim.models.keyedvectors.Vocab at 0x63b5c9240>,
#  'paketı': <gensim.models.keyedvectors.Vocab at 0x63b5c9278>,
#  'yapıcaktım': <gensim.models.keyedvectors.Vocab at 0x63b5c92b0>,
#  'cahit': <gensim.models.keyedvectors.Vocab at 0x63b5c92e8>,
#  'berkay': <gensim.models.keyedvectors.Vocab at 0x63b5c9320>,
#  'lı': <gensim.models.keyedvectors.Vocab at 0x63b5c9358>,
#  'iğren': <gensim.models.keyedvectors.Vocab at 0x63b5c9390>,
#  'cüzdan': <gensim.models.keyedvectors.Vocab at 0x63b5c93c8>,
#  'korkunç': <gensim.models.keyedvectors.Vocab at 0x63b5c9400>,
#  'hata': <gensim.models.keyedvectors.Vocab at 0x63b5c9438>,
#  'kot': <gensim.models.keyedvectors.Vocab at 0x63b5c9470>,
#  'kontorlerimi': <gensim.models.keyedvectors.Vocab at 0x63b5c94a8>,
#  'yemek': <gensim.models.keyedvectors.Vocab at 0x63b5c94e0>,
#  'bikmadin': <gensim.models.keyedvectors.Vocab at 0x63b5c9518>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x63b5c9550>,
#  'tane': <gensim.models.keyedvectors.Vocab at 0x63b5c9588>,
#  'attii': <gensim.models.keyedvectors.Vocab at 0x63b5c95c0>,
#  'ajans': <gensim.models.keyedvectors.Vocab at 0x63b5c95f8>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x63b5c9630>,
#  'harlem': <gensim.models.keyedvectors.Vocab at 0x63b5c9668>,
#  'shake': <gensim.models.keyedvectors.Vocab at 0x63b5c96a0>,
#  'bay': <gensim.models.keyedvectors.Vocab at 0x63b5c96d8>,
#  'reklaminda': <gensim.models.keyedvectors.Vocab at 0x63b5c9710>,
#  'saygi': <gensim.models.keyedvectors.Vocab at 0x63b5c9748>,
#  'gencler': <gensim.models.keyedvectors.Vocab at 0x63b5c9780>,
#  'gerzek': <gensim.models.keyedvectors.Vocab at 0x63b5c97b8>,
#  'yuzunden': <gensim.models.keyedvectors.Vocab at 0x63b5c97f0>,
#  'çıkar': <gensim.models.keyedvectors.Vocab at 0x63b5c9828>,
#  'versiyon': <gensim.models.keyedvectors.Vocab at 0x63b5c9860>,
#  'bey': <gensim.models.keyedvectors.Vocab at 0x63b5c9898>,
#  'bedava': <gensim.models.keyedvectors.Vocab at 0x63b5c98d0>,
#  'olduguna': <gensim.models.keyedvectors.Vocab at 0x63b5c9908>,
#  'hakikaten': <gensim.models.keyedvectors.Vocab at 0x63b5c9940>,
#  'sarki': <gensim.models.keyedvectors.Vocab at 0x63b5c9978>,
#  'anı': <gensim.models.keyedvectors.Vocab at 0x63b5c99b0>,
#  'hayal': <gensim.models.keyedvectors.Vocab at 0x63b5c99e8>,
#  'kur': <gensim.models.keyedvectors.Vocab at 0x63b5c9a20>,
#  'halbuki': <gensim.models.keyedvectors.Vocab at 0x63b5c9a58>,
#  'daglarda': <gensim.models.keyedvectors.Vocab at 0x63b5c9a90>,
#  'vadi': <gensim.models.keyedvectors.Vocab at 0x63b5c9ac8>,
#  'ceken': <gensim.models.keyedvectors.Vocab at 0x63b5c9b00>,
#  'karsiyaka': <gensim.models.keyedvectors.Vocab at 0x63b5c9b38>,
#  'arasi': <gensim.models.keyedvectors.Vocab at 0x63b5c9b70>,
#  'deniz': <gensim.models.keyedvectors.Vocab at 0x63b5c9ba8>,
#  'arkadas': <gensim.models.keyedvectors.Vocab at 0x63b5c9be0>,
#  'mani': <gensim.models.keyedvectors.Vocab at 0x63b5c9c18>,
#  'ceo': <gensim.models.keyedvectors.Vocab at 0x63b5c9c50>,
#  'rüya': <gensim.models.keyedvectors.Vocab at 0x63b5c9c88>,
#  'ahmedim': <gensim.models.keyedvectors.Vocab at 0x63b5c9cc0>,
#  'nerdesin': <gensim.models.keyedvectors.Vocab at 0x63b5c9cf8>,
#  'insallah': <gensim.models.keyedvectors.Vocab at 0x63b5c9d30>,
#  'hülya': <gensim.models.keyedvectors.Vocab at 0x63b5c9d68>,
#  'koçyiğit': <gensim.models.keyedvectors.Vocab at 0x63b5c9da0>,
#  'li': <gensim.models.keyedvectors.Vocab at 0x63b5c9dd8>,
#  'yahu': <gensim.models.keyedvectors.Vocab at 0x63b5c9e10>,
#  'cehennemi': <gensim.models.keyedvectors.Vocab at 0x63b5c9e48>,
#  'dip': <gensim.models.keyedvectors.Vocab at 0x63b5c9e80>,
#  'çay': <gensim.models.keyedvectors.Vocab at 0x63b5c9eb8>,
#  'taaa': <gensim.models.keyedvectors.Vocab at 0x63b5c9ef0>,
#  'öküz': <gensim.models.keyedvectors.Vocab at 0x63b5c9f28>,
#  'diyosun': <gensim.models.keyedvectors.Vocab at 0x63b5c9f60>,
#  'edicem': <gensim.models.keyedvectors.Vocab at 0x63b5c9f98>,
#  'istinye': <gensim.models.keyedvectors.Vocab at 0x63b5c9fd0>,
#  'tweeti': <gensim.models.keyedvectors.Vocab at 0x63b5cc048>,
#  'mucize': <gensim.models.keyedvectors.Vocab at 0x63b5cc080>,
#  'olmadi': <gensim.models.keyedvectors.Vocab at 0x63b5cc0b8>,
#  '220': <gensim.models.keyedvectors.Vocab at 0x63b5cc0f0>,
#  '250': <gensim.models.keyedvectors.Vocab at 0x63b5cc128>,
#  'yor': <gensim.models.keyedvectors.Vocab at 0x63b5cc160>,
#  'tablet': <gensim.models.keyedvectors.Vocab at 0x63b5cc198>,
#  'saçmalık': <gensim.models.keyedvectors.Vocab at 0x63b5cc1d0>,
#  'kufur': <gensim.models.keyedvectors.Vocab at 0x63b5cc208>,
#  'nerden': <gensim.models.keyedvectors.Vocab at 0x63b5cc240>,
#  'yorum': <gensim.models.keyedvectors.Vocab at 0x63b5cc278>,
#  'çift': <gensim.models.keyedvectors.Vocab at 0x63b5cc2b0>,
#  'genel': <gensim.models.keyedvectors.Vocab at 0x63b5cc2e8>,
#  '2g': <gensim.models.keyedvectors.Vocab at 0x63b5cc320>,
#  'herhalde': <gensim.models.keyedvectors.Vocab at 0x63b5cc358>,
#  'sayın': <gensim.models.keyedvectors.Vocab at 0x63b5cc390>,
#  'mustafa': <gensim.models.keyedvectors.Vocab at 0x63b5cc3c8>,
#  'sandal': <gensim.models.keyedvectors.Vocab at 0x63b5cc400>,
#  'fazla': <gensim.models.keyedvectors.Vocab at 0x63b5cc438>,
#  'simge': <gensim.models.keyedvectors.Vocab at 0x63b5cc470>,
#  'nasil': <gensim.models.keyedvectors.Vocab at 0x63b5cc4a8>,
#  'belli': <gensim.models.keyedvectors.Vocab at 0x63b5cc4e0>,
#  'degil': <gensim.models.keyedvectors.Vocab at 0x63b5cc518>,
#  'cümle': <gensim.models.keyedvectors.Vocab at 0x63b5cc550>,
#  'sahip': <gensim.models.keyedvectors.Vocab at 0x63b5cc588>,
#  'senın': <gensim.models.keyedvectors.Vocab at 0x63b5cc5c0>,
#  'çöz': <gensim.models.keyedvectors.Vocab at 0x63b5cc5f8>,
#  'çöp': <gensim.models.keyedvectors.Vocab at 0x63b5cc630>,
#  'iphone5': <gensim.models.keyedvectors.Vocab at 0x63b5cc668>,
#  'ceza': <gensim.models.keyedvectors.Vocab at 0x63b5cc6a0>,
#  'sev': <gensim.models.keyedvectors.Vocab at 0x63b5cc6d8>,
#  'gir': <gensim.models.keyedvectors.Vocab at 0x63b5cc710>,
#  'sağolsun': <gensim.models.keyedvectors.Vocab at 0x63b5cc748>,
#  'kampanya': <gensim.models.keyedvectors.Vocab at 0x63b5cc780>,
#  'iphone': <gensim.models.keyedvectors.Vocab at 0x63b5cc7b8>,
#  'ipad': <gensim.models.keyedvectors.Vocab at 0x63b5cc7f0>,
#  'kalp': <gensim.models.keyedvectors.Vocab at 0x63b5cc828>,
#  'hasta': <gensim.models.keyedvectors.Vocab at 0x63b5cc860>,
#  'zamanla': <gensim.models.keyedvectors.Vocab at 0x63b5cc898>,
#  'süper': <gensim.models.keyedvectors.Vocab at 0x63b5cc8d0>,
#  '78': <gensim.models.keyedvectors.Vocab at 0x63b5cc908>,
#  'bilgi': <gensim.models.keyedvectors.Vocab at 0x63b5cc940>,
#  'imza': <gensim.models.keyedvectors.Vocab at 0x63b5cc978>,
#  'sahte': <gensim.models.keyedvectors.Vocab at 0x63b5cc9b0>,
#  'evrak': <gensim.models.keyedvectors.Vocab at 0x63b5cc9e8>,
#  'savcı': <gensim.models.keyedvectors.Vocab at 0x63b5cca20>,
#  'başvur': <gensim.models.keyedvectors.Vocab at 0x63b5cca58>,
#  'gunde': <gensim.models.keyedvectors.Vocab at 0x63b5cca90>,
#  'pc': <gensim.models.keyedvectors.Vocab at 0x63b5ccac8>,
#  'kullanirdik': <gensim.models.keyedvectors.Vocab at 0x63b5ccb00>,
#  'insaf': <gensim.models.keyedvectors.Vocab at 0x63b5ccb38>,
#  'pahali': <gensim.models.keyedvectors.Vocab at 0x63b5ccb70>,
#  'nere': <gensim.models.keyedvectors.Vocab at 0x63b5ccba8>,
#  'dalga': <gensim.models.keyedvectors.Vocab at 0x63b5ccbe0>,
#  'dolandiricilar': <gensim.models.keyedvectors.Vocab at 0x63b5ccc18>,
#  'gecmeyin': <gensim.models.keyedvectors.Vocab at 0x63b5ccc50>,
#  'beyin': <gensim.models.keyedvectors.Vocab at 0x63b5ccc88>,
#  'yan': <gensim.models.keyedvectors.Vocab at 0x63b5cccc0>,
#  'gsm': <gensim.models.keyedvectors.Vocab at 0x63b5cccf8>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x63b5ccd30>,
#  'dönüş': <gensim.models.keyedvectors.Vocab at 0x63b5ccd68>,
#  'tercih': <gensim.models.keyedvectors.Vocab at 0x63b5ccda0>,
#  'lazım': <gensim.models.keyedvectors.Vocab at 0x63b5ccdd8>,
#  'yau': <gensim.models.keyedvectors.Vocab at 0x63b5cce10>,
#  'yapiyorsun': <gensim.models.keyedvectors.Vocab at 0x63b5cce48>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x63b5cce80>,
#  'te': <gensim.models.keyedvectors.Vocab at 0x63b5cceb8>,
#  '4g': <gensim.models.keyedvectors.Vocab at 0x63b5ccef0>,
#  'varit': <gensim.models.keyedvectors.Vocab at 0x63b5ccf28>,
#  'dikkat': <gensim.models.keyedvectors.Vocab at 0x63b5ccf60>,
#  'eksik': <gensim.models.keyedvectors.Vocab at 0x63b5ccf98>,
#  'sapıt': <gensim.models.keyedvectors.Vocab at 0x63b5ccfd0>,
#  'hisse': <gensim.models.keyedvectors.Vocab at 0x63b5d0048>,
#  'sıfır': <gensim.models.keyedvectors.Vocab at 0x63b5d0080>,
#  'madur': <gensim.models.keyedvectors.Vocab at 0x63b5d00b8>,
#  '1000sms': <gensim.models.keyedvectors.Vocab at 0x63b5d00f0>,
#  'lik': <gensim.models.keyedvectors.Vocab at 0x63b5d0128>,
#  'paketle': <gensim.models.keyedvectors.Vocab at 0x63b5d0160>,
#  'merak': <gensim.models.keyedvectors.Vocab at 0x63b5d0198>,
#  'deyim': <gensim.models.keyedvectors.Vocab at 0x63b5d01d0>,
#  'tweet': <gensim.models.keyedvectors.Vocab at 0x63b5d0208>,
#  '60': <gensim.models.keyedvectors.Vocab at 0x63b5d0240>,
#  'sn': <gensim.models.keyedvectors.Vocab at 0x63b5d0278>,
#  '370': <gensim.models.keyedvectors.Vocab at 0x63b5d02b0>,
#  'allahtan': <gensim.models.keyedvectors.Vocab at 0x63b5d02e8>,
#  'kork': <gensim.models.keyedvectors.Vocab at 0x63b5d0320>,
#  'vicdan': <gensim.models.keyedvectors.Vocab at 0x63b5d0358>,
#  'heryerden': <gensim.models.keyedvectors.Vocab at 0x63b5d0390>,
#  'ttnetdestek': <gensim.models.keyedvectors.Vocab at 0x63b5d03c8>,
#  'arıza': <gensim.models.keyedvectors.Vocab at 0x63b5d0400>,
#  'kayıt': <gensim.models.keyedvectors.Vocab at 0x63b5d0438>,
#  'sistem': <gensim.models.keyedvectors.Vocab at 0x63b5d0470>,
#  'güncel': <gensim.models.keyedvectors.Vocab at 0x63b5d04a8>,
#  'açı': <gensim.models.keyedvectors.Vocab at 0x63b5d04e0>,
#  'ttnetas': <gensim.models.keyedvectors.Vocab at 0x63b5d0518>,
#  '90': <gensim.models.keyedvectors.Vocab at 0x63b5d0550>,
#  'türkiye': <gensim.models.keyedvectors.Vocab at 0x63b5d0588>,
#  'kapsa': <gensim.models.keyedvectors.Vocab at 0x63b5d05c0>,
#  'sehrin': <gensim.models.keyedvectors.Vocab at 0x63b5d05f8>,
#  'göbeginde': <gensim.models.keyedvectors.Vocab at 0x63b5d0630>,
#  'yaş': <gensim.models.keyedvectors.Vocab at 0x63b5d0668>,
#  'grup': <gensim.models.keyedvectors.Vocab at 0x63b5d06a0>,
#  'oyun': <gensim.models.keyedvectors.Vocab at 0x63b5d06d8>,
#  'efe': <gensim.models.keyedvectors.Vocab at 0x63b5d0710>,
#  'kıbrıs': <gensim.models.keyedvectors.Vocab at 0x63b5d0748>,
#  'aşı': <gensim.models.keyedvectors.Vocab at 0x63b5d0780>,
#  'terbiye': <gensim.models.keyedvectors.Vocab at 0x63b5d07b8>,
#  'maalesef': <gensim.models.keyedvectors.Vocab at 0x63b5d07f0>,
#  'yönlen': <gensim.models.keyedvectors.Vocab at 0x63b5d0828>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x63b5d0860>,
#  'kabul': <gensim.models.keyedvectors.Vocab at 0x63b5d0898>,
#  'istanbul': <gensim.models.keyedvectors.Vocab at 0x63b5d08d0>,
#  '99': <gensim.models.keyedvectors.Vocab at 0x63b5d0908>,
#  'alan': <gensim.models.keyedvectors.Vocab at 0x63b5d0940>,
#  'uygun': <gensim.models.keyedvectors.Vocab at 0x63b5d0978>,
#  'bilader': <gensim.models.keyedvectors.Vocab at 0x63b5d09b0>,
#  'yaklaşık': <gensim.models.keyedvectors.Vocab at 0x63b5d09e8>,
#  'kapalı': <gensim.models.keyedvectors.Vocab at 0x63b5d0a20>,
#  'msj': <gensim.models.keyedvectors.Vocab at 0x63b5d0a58>,
#  'gozunu': <gensim.models.keyedvectors.Vocab at 0x63b5d0a90>,
#  'cekmiyo': <gensim.models.keyedvectors.Vocab at 0x63b5d0ac8>,
#  'yerin': <gensim.models.keyedvectors.Vocab at 0x63b5d0b00>,
#  'kelime': <gensim.models.keyedvectors.Vocab at 0x63b5d0b38>,
#  'boyle': <gensim.models.keyedvectors.Vocab at 0x63b5d0b70>,
#  'bır': <gensim.models.keyedvectors.Vocab at 0x63b5d0ba8>,
#  'operator': <gensim.models.keyedvectors.Vocab at 0x63b5d0be0>,
#  'ıptal': <gensim.models.keyedvectors.Vocab at 0x63b5d0c18>,
#  'dıyorum': <gensim.models.keyedvectors.Vocab at 0x63b5d0c50>,
#  'bimcell': <gensim.models.keyedvectors.Vocab at 0x63b5d0c88>,
#  'internetinin': <gensim.models.keyedvectors.Vocab at 0x63b5d0cc0>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x63b5d0cf8>,
#  'daki': <gensim.models.keyedvectors.Vocab at 0x63b5d0d30>,
#  'amerikayı': <gensim.models.keyedvectors.Vocab at 0x63b5d0d68>,
#  'gectik': <gensim.models.keyedvectors.Vocab at 0x63b5d0da0>,
#  'heralde': <gensim.models.keyedvectors.Vocab at 0x63b5d0dd8>,
#  'açma': <gensim.models.keyedvectors.Vocab at 0x63b5d0e10>,
#  'bahane': <gensim.models.keyedvectors.Vocab at 0x63b5d0e48>,
#  '3tl': <gensim.models.keyedvectors.Vocab at 0x63b5d0e80>,
#  'sözleş': <gensim.models.keyedvectors.Vocab at 0x63b5d0eb8>,
#  'yaz': <gensim.models.keyedvectors.Vocab at 0x63b5d0ef0>,
#  'illa': <gensim.models.keyedvectors.Vocab at 0x63b5d0f28>,
#  'hakaret': <gensim.models.keyedvectors.Vocab at 0x63b5d0f60>,
#  'yüklem': <gensim.models.keyedvectors.Vocab at 0x63b5d0f98>,
#  'onda': <gensim.models.keyedvectors.Vocab at 0x63b5d0fd0>,
#  'paragöz': <gensim.models.keyedvectors.Vocab at 0x63b665048>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x63b665080>,
#  'yamyam': <gensim.models.keyedvectors.Vocab at 0x63b6650b8>,
#  'çiğköfte': <gensim.models.keyedvectors.Vocab at 0x63b6650f0>,
#  'internetimiz': <gensim.models.keyedvectors.Vocab at 0x63b665128>,
#  'slogan': <gensim.models.keyedvectors.Vocab at 0x63b665160>,
#  'ısrar': <gensim.models.keyedvectors.Vocab at 0x63b665198>,
#  'aktif': <gensim.models.keyedvectors.Vocab at 0x63b6651d0>,
#  'keşke': <gensim.models.keyedvectors.Vocab at 0x63b665208>,
#  'turkiye': <gensim.models.keyedvectors.Vocab at 0x63b665240>,
#  'sini': <gensim.models.keyedvectors.Vocab at 0x63b665278>,
#  'kafasi': <gensim.models.keyedvectors.Vocab at 0x63b6652b0>,
#  'soğu': <gensim.models.keyedvectors.Vocab at 0x63b6652e8>,
#  'karşılaş': <gensim.models.keyedvectors.Vocab at 0x63b665320>,
#  ...}

# %%
model.most_similar('turkcell')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('anlatiyor', 0.23928648233413696),
#  ('ol', 0.22458797693252563),
#  ('sak', 0.2237774282693863),
#  ('by', 0.22273793816566467),
#  ('odunc', 0.22208234667778015),
#  ('turkcellakillikadinlarkulubu', 0.22112055122852325),
#  ('öbürülaöbürü', 0.219574436545372),
#  ('escobar', 0.21668019890785217),
#  ('eyjwywdlijoiag9yb3njb3blxc9kzxrhawwilcjxcyi6imlkpteyjnr5cgu9myj9',
#   0.21526719629764557),
#  ('alirken', 0.21001583337783813)]

# %%
#to find the vector of a document which is not in training data
test_data = word_tokenize("2".lower())
v1 = model.infer_vector(test_data)
print(test_data)
print("V1_infer", v1)
# Out:
# ['2']
# V1_infer [-0.03737827 -0.08217598  0.05897779  0.04295481  0.04406261 -0.01183352
#   0.0726761  -0.01144092  0.04881437 -0.00684601  0.04838407 -0.06048566
#  -0.04084711  0.06238113  0.03074199  0.05869396 -0.02505491 -0.01250112
#  -0.01824988  0.04761232 -0.09492981 -0.02362792 -0.09096128  0.08197915
#   0.01207124  0.00329877  0.04168056  0.06442592 -0.03951911  0.04573657
#  -0.07926989  0.02268605  0.06632239 -0.04250176 -0.03479092  0.12830956
#   0.0067775  -0.0044645   0.13353355  0.0271051  -0.00940917  0.04173548
#  -0.0339273  -0.02016051 -0.02423552 -0.08493184 -0.02600931  0.08246565
#  -0.10996543  0.04070801 -0.02299405  0.05146294  0.11879726  0.03539389
#  -0.09574382  0.00767232 -0.0229358   0.05753192 -0.02410503  0.0766781
#  -0.01903024  0.04721741 -0.00343341 -0.03622256 -0.03278359  0.06925772
#   0.0458094  -0.06590406  0.05477072  0.04022017  0.00090872  0.06538519
#   0.05885214 -0.01943279 -0.04467616 -0.02703006  0.01983195  0.06660437
#   0.0164433   0.04222489 -0.00774265 -0.06667513  0.05112796  0.02458048
#   0.06215677  0.06889296 -0.00993449  0.04248393  0.00918531 -0.09939582
#   0.0423682  -0.03180666 -0.00394838  0.07298528 -0.11198907  0.01235136
#  -0.04294649 -0.00410967  0.00691709 -0.0222215   0.00057863 -0.06558946
#   0.11187821 -0.06432626 -0.05895265 -0.03801564  0.06399925 -0.01995572
#   0.04082201  0.04672473 -0.01545141  0.0688114   0.05465356  0.0734456
#  -0.05227366  0.02924062 -0.06547902 -0.00017036  0.06310131 -0.02997743
#   0.00329387  0.02610185 -0.02562549 -0.06547625 -0.03790475  0.01538029
#   0.06524637 -0.12249307 -0.05158114 -0.04924065  0.04882615  0.00264887
#  -0.00539289  0.00750862  0.00470894  0.00668822 -0.01964139 -0.03741531
#  -0.03506925  0.05401069 -0.01518886  0.00663215  0.03751472  0.06411919
#  -0.05895633  0.00037858  0.04581271  0.04868028 -0.00113647 -0.03117165
#   0.0413787  -0.08613872 -0.02296114  0.01095203 -0.07185267 -0.00842088
#   0.0540888  -0.05535505 -0.07961422  0.02527412 -0.0237396   0.00024434
#  -0.12051869  0.0395775   0.01324268  0.04375721 -0.04725933  0.04636389
#  -0.00019076 -0.03247151 -0.08852797 -0.01143877  0.00942514 -0.06045717
#  -0.04281464 -0.04216736 -0.00452863  0.02560205  0.06072859 -0.03017827
#  -0.02652579 -0.08766954 -0.04471027 -0.09293749 -0.093074    0.00114673
#  -0.02736396 -0.03511578  0.00592484 -0.00975613  0.0476187   0.0610453
#  -0.00330204  0.01482592  0.08023253  0.00944229  0.03811366  0.07751166
#  -0.05894733  0.07813659 -0.04460943  0.11183669 -0.04179921 -0.09486569
#  -0.0594159  -0.06794874  0.05177965 -0.01089365  0.03027512 -0.05162593
#   0.02301106 -0.00040512  0.02789463 -0.09405033  0.0398237  -0.04372503
#   0.07002078  0.05438853  0.02815505 -0.09308874 -0.00703413  0.0572399
#   0.1144359  -0.16055977  0.02812664  0.07649219 -0.02181961  0.1595302
#  -0.09295598 -0.09037065  0.03950056  0.02338371 -0.04214268 -0.07193087
#  -0.06507298  0.01744812  0.0045409  -0.05984918 -0.02337596 -0.05808378
#  -0.02126406 -0.0466037   0.00574048  0.03333707 -0.05567369  0.04536811
#   0.09389974  0.00086391  0.00757731 -0.1042265   0.00780756 -0.11074103
#  -0.03892473 -0.0300943   0.08414958 -0.01116696  0.07358694  0.04037538
#   0.00557374  0.03539273 -0.09554999 -0.00348715  0.04886436 -0.03458216
#  -0.08273201  0.02398694 -0.0795567  -0.0061407  -0.03605641 -0.05009455
#   0.10894283  0.09434779  0.06582692 -0.07316697 -0.02261856 -0.03955084
#   0.09920422 -0.02782675  0.14529397  0.00206914 -0.07069184 -0.00378421
#  -0.04771562  0.02118647  0.01990058  0.03224405  0.04963083  0.03701272
#   0.05125231 -0.00095757 -0.00796233  0.01657393 -0.02168796 -0.05139419
#  -0.04189346 -0.06135058 -0.0051928  -0.02424482  0.02831856 -0.05144906]

# %% [markdown]
# ## Load pre-trained model

# %%
#model= Doc2Vec.load("d2vz.model")

# %% [markdown]
# # Run Logistic Regression on vector represenations of words

# %%
def vec_for_learning(model, tagged_docs):
    targets, regressors = zip(*[(doc.tags[0], model.infer_vector(doc.words, steps=20)) for doc in tagged_docs])
    return targets, regressors

# %%
y_train, X_train = vec_for_learning(model, train_tagged_data)
y_test, X_test = vec_for_learning(model, test_tagged_data)

# %%
sentiment = {'olumsuz':0, 'notr':1, 'olumlu':2}
inv_sentiment = {v:k for k, v in sentiment.items()}
inv_sentiment
# Out:
# {0: 'olumsuz', 1: 'notr', 2: 'olumlu'}

# %%
y_train = np.array([sentiment[s] for s in y_train])
y_test = np.array([sentiment[s] for s in y_test])
y_train
# Out:
# array([0, 0, 0, ..., 0, 1, 2])

# %%
y_test
# Out:
# array([0, 0, 0, ..., 1, 1, 2])

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(n_jobs=1, C=1e5)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score

print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Testing accuracy 0.40873589817761063
# Testing F1 score: 0.40445415788027606

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[411, 622, 344],
#        [229, 602, 333],
#        [163, 353, 400]])

# %%
len(y_pred)
# Out:
# 3457

# %% [markdown]
# ## To-Do
#
# Zemberek correct words
