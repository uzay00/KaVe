# %% [markdown]
# ## Turkish NLP Zemberek

# %%
import jpype
# JVM başlat
jpype.startJVM(jpype.getDefaultJVMPath(),
         "-Djava.class.path=/Users/uzaycetin/Documents/driver/zemberek-tum-2.0.jar", "-ea")

# Türkiye Türkçesine göre çözümlemek için gerekli sınıfı hazırla
Tr = jpype.JClass("net.zemberek.tr.yapi.TurkiyeTurkcesi")
# tr nesnesini oluştur
tr = Tr()
# Zemberek sınıfını yükle
Zemberek = jpype.JClass("net.zemberek.erisim.Zemberek")
# zemberek nesnesini oluştur
zemberek = Zemberek(tr)

# %%
def kokbul(word = 'karasal'):
    kok = word
    ornSonuc = zemberek.kelimeCozumle(kok)
    try:
        kok = ornSonuc[0].kok().icerik()
    except:
        pass
    return kok

# %%
txt = 'gezinti gelsene'
[kokbul(w) for w in txt.split()]
# Out:
# ['gezinti', 'gel']

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import re
import pickle 
import nltk
from nltk.corpus import stopwords
from sklearn.datasets import load_files
nltk.download('stopwords')

# stopwordsleri sil
from nltk.corpus import stopwords
stop = stopwords.words('Turkish')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/uzaycetin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Get twitter 17000 Data

# %%
# Turkish Stopwords
with open('17bintweet/turkce-stop-words.txt') as file:  
    stw = file.read() 
stw = stw.split()
stw = [s.lower() for s in stw] 
stop += stw

# %%
def preprocessing(text):
    text = text.lower()
    # get rid of non-alphanumerical characters
    text = re.sub(r'\W', ' ', text) 
    # get rid of spaces
    text = re.sub(r'\s+', ' ', text) 
    # Correct mistakes 
    # zemberek!!
    
    # and do the stemming
    kelimeler = [kokbul(w) for w in text.split()]
    return " ".join([word for word in kelimeler if word not in stop])

# %%
preprocessing(txt)
# Out:
# 'gezinti gel'

# %%
test_data = pd.read_excel('17bintweet/test_tweets.xlsx', header=None)
test_data.head(3)
# Out:
#                                                    0        1
# 0  Turkcell'e kızgınım. Ve bu kızgınlık sanırım a...  olumsuz
# 1                 turkcell kadar şerefsiz misiniz ya  olumsuz
# 2  Burdan Turkcell'e sesleniyorum o 3 tl haram olsun  olumsuz

# %%
train_data = pd.read_excel('17bintweet/train_tweets.xlsx', header=None)
train_data.head(3)
# Out:
#                                                    0        1
# 0  Ulan Wifi'ye bağlıyım ben. Ona bağlıyken Turkc...  olumsuz
# 1  20 dk 1 GB internet 500 mb sadece kaşar turkce...  olumsuz
# 2  Ayrıca turkcell superonline reklamı kadar da k...  olumsuz

# %%
test_data[0] = test_data[0].apply(preprocessing)
train_data[0] = train_data[0].apply(preprocessing)

train_data.head(3)
# Out:
#                                                    0        1
# 0  ulan wifi bağ bağ turkcell internet paket bit ...  olumsuz
# 1  20 dk 1 gb internet 500 mb sadece kaşar turkce...  olumsuz
# 2        turkcell superonline reklam kötü reklam gör  olumsuz

# %% [markdown]
# ## Doc2Vec starts

# %%
#Import all the dependencies
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

# %% [markdown]
# ## Label documents

# %%
# Creating the corpus for train_data
train_tagged_data = []
for i in range(len(train_data)):
    train_tagged_data.append(TaggedDocument(word_tokenize(train_data.iloc[i,0]), tags=[train_data.iloc[i,1]]))

# %%
# Creating the corpus for test_data
test_tagged_data = []
for i in range(len(test_data)):
    test_tagged_data.append(TaggedDocument(word_tokenize(test_data.iloc[i,0]), tags=[test_data.iloc[i,1]]))

# %%
train_tagged_data[:3]
# Out:
# [TaggedDocument(words=['ulan', 'wifi', 'bağ', 'bağ', 'turkcell', 'internet', 'paket', 'bit', 'mesaj', 'at', 'öde'], tags=['olumsuz']),
#  TaggedDocument(words=['20', 'dk', '1', 'gb', 'internet', '500', 'mb', 'sadece', 'kaşar', 'turkcell', 'düş', 'oç', 'çocuk'], tags=['olumsuz']),
#  TaggedDocument(words=['turkcell', 'superonline', 'reklam', 'kötü', 'reklam', 'gör'], tags=['olumsuz'])]

# %%
test_tagged_data[:3]
# Out:
# [TaggedDocument(words=['turkcell', 'kızgın', 'kızgın', 'san', 'ayrıl', 'sonlanıcak', 'gel', 'fark', 'operatör', '30', 'fazla', 'fiyat', 'teklif', 'et'], tags=['olumsuz']),
#  TaggedDocument(words=['turkcell', 'şeref', 'mis'], tags=['olumsuz']),
#  TaggedDocument(words=['burdan', 'turkcell', 'sesle', '3', 'tl', 'haram', 'ol'], tags=['olumsuz'])]

# %%
len(test_tagged_data), len(train_tagged_data)
# Out:
# (3457, 13832)

# %%
train_tagged_data[0].words
# Out:
# ['ulan',
#  'wifi',
#  'bağ',
#  'bağ',
#  'turkcell',
#  'internet',
#  'paket',
#  'bit',
#  'mesaj',
#  'at',
#  'öde']

# %% [markdown]
# ## Train doc2vec dm=1 ‘distributed memory’ (PV-DM)

# %%
max_epochs = 20
vec_size = 200

model = Doc2Vec(size=vec_size,
                window=5,
                alpha=0.065, 
                min_alpha=0.065,
                min_count=2,
                dm =1)
  
model.build_vocab(train_tagged_data)

for epoch in range(max_epochs):
    if epoch% (max_epochs/5) == 0: print('iteration {0}/{1}'.format(epoch, max_epochs))
        
    model.train(train_tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    
    # decrease the learning rate
    model.alpha -= 0.002
    
    # fix the learning rate, no decay
    model.min_alpha = model.alpha

#model.save("d2vz.model")
print("Model Saved")
# Out:
# /anaconda3/lib/python3.6/site-packages/gensim/models/doc2vec.py:366: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# iteration 0/20
# iteration 4/20
# iteration 8/20
# iteration 12/20
# iteration 16/20
# Model Saved

# %%
len(model.wv.vocab)
# Out:
# 3010

# %%
len(model.docvecs) # The number of trained document tags is available from:
# Out:
# 3

# %%
model.wv.vocab
# Out:
# {'ulan': <gensim.models.keyedvectors.Vocab at 0x633d8b978>,
#  'wifi': <gensim.models.keyedvectors.Vocab at 0x633d8b940>,
#  'bağ': <gensim.models.keyedvectors.Vocab at 0x633d8ba20>,
#  'turkcell': <gensim.models.keyedvectors.Vocab at 0x633d8bba8>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x633d8b9e8>,
#  'paket': <gensim.models.keyedvectors.Vocab at 0x633d8bbe0>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x633d8bc18>,
#  'mesaj': <gensim.models.keyedvectors.Vocab at 0x633d8bc50>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x633d8bc88>,
#  'öde': <gensim.models.keyedvectors.Vocab at 0x633d8bcc0>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x633d8bcf8>,
#  'dk': <gensim.models.keyedvectors.Vocab at 0x633d8bd30>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x633d8bd68>,
#  'gb': <gensim.models.keyedvectors.Vocab at 0x633d8bda0>,
#  '500': <gensim.models.keyedvectors.Vocab at 0x633d8bdd8>,
#  'mb': <gensim.models.keyedvectors.Vocab at 0x633d8be10>,
#  'sadece': <gensim.models.keyedvectors.Vocab at 0x633d8be48>,
#  'düş': <gensim.models.keyedvectors.Vocab at 0x633d8be80>,
#  'oç': <gensim.models.keyedvectors.Vocab at 0x633d8beb8>,
#  'çocuk': <gensim.models.keyedvectors.Vocab at 0x633d8bef0>,
#  'superonline': <gensim.models.keyedvectors.Vocab at 0x633d8bf28>,
#  'reklam': <gensim.models.keyedvectors.Vocab at 0x633d8bf60>,
#  'kötü': <gensim.models.keyedvectors.Vocab at 0x633d8bf98>,
#  'gör': <gensim.models.keyedvectors.Vocab at 0x633d8bfd0>,
#  'pahalı': <gensim.models.keyedvectors.Vocab at 0x633dc9048>,
#  'internetin': <gensim.models.keyedvectors.Vocab at 0x633dc9080>,
#  'cekmiyor': <gensim.models.keyedvectors.Vocab at 0x633dc90b8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x633dc90f0>,
#  'allah': <gensim.models.keyedvectors.Vocab at 0x633dc9128>,
#  'bela': <gensim.models.keyedvectors.Vocab at 0x633dc9160>,
#  'ver': <gensim.models.keyedvectors.Vocab at 0x633dc9198>,
#  'iste': <gensim.models.keyedvectors.Vocab at 0x633dc91d0>,
#  'yürek': <gensim.models.keyedvectors.Vocab at 0x633dc9208>,
#  'şiş': <gensim.models.keyedvectors.Vocab at 0x633dc9240>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x633dc9278>,
#  'cehennem': <gensim.models.keyedvectors.Vocab at 0x633dc92b0>,
#  'yönetim': <gensim.models.keyedvectors.Vocab at 0x633dc92e8>,
#  'el': <gensim.models.keyedvectors.Vocab at 0x633dc9320>,
#  'geçir': <gensim.models.keyedvectors.Vocab at 0x633dc9358>,
#  'akp': <gensim.models.keyedvectors.Vocab at 0x633dc9390>,
#  'abone': <gensim.models.keyedvectors.Vocab at 0x633dc93c8>,
#  'seçim': <gensim.models.keyedvectors.Vocab at 0x633dc9400>,
#  'gönder': <gensim.models.keyedvectors.Vocab at 0x633dc9438>,
#  'şeref': <gensim.models.keyedvectors.Vocab at 0x633dc9470>,
#  'iddia': <gensim.models.keyedvectors.Vocab at 0x633dc94a8>,
#  'ede': <gensim.models.keyedvectors.Vocab at 0x633dc94e0>,
#  'elim': <gensim.models.keyedvectors.Vocab at 0x633dc9518>,
#  'ayak': <gensim.models.keyedvectors.Vocab at 0x633dc9550>,
#  'çek': <gensim.models.keyedvectors.Vocab at 0x633dc9588>,
#  'iyi': <gensim.models.keyedvectors.Vocab at 0x633dc95c0>,
#  'ol': <gensim.models.keyedvectors.Vocab at 0x633dc95f8>,
#  'bayram': <gensim.models.keyedvectors.Vocab at 0x633dc9630>,
#  'vodafone': <gensim.models.keyedvectors.Vocab at 0x633dc9668>,
#  'geç': <gensim.models.keyedvectors.Vocab at 0x633dc96a0>,
#  'kazık': <gensim.models.keyedvectors.Vocab at 0x633dc96d8>,
#  'amk': <gensim.models.keyedvectors.Vocab at 0x633dc9710>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x633dc9748>,
#  'evin': <gensim.models.keyedvectors.Vocab at 0x633dc9780>,
#  'köşe': <gensim.models.keyedvectors.Vocab at 0x633dc97b8>,
#  'kazıkla': <gensim.models.keyedvectors.Vocab at 0x633dc97f0>,
#  'kal': <gensim.models.keyedvectors.Vocab at 0x633dc9828>,
#  'düşük': <gensim.models.keyedvectors.Vocab at 0x633dc9860>,
#  'hızlı': <gensim.models.keyedvectors.Vocab at 0x633dc9898>,
#  'hay': <gensim.models.keyedvectors.Vocab at 0x633dc98d0>,
#  'çekim': <gensim.models.keyedvectors.Vocab at 0x633dc9908>,
#  'gücün': <gensim.models.keyedvectors.Vocab at 0x633dc9940>,
#  'nalet': <gensim.models.keyedvectors.Vocab at 0x633dc9978>,
#  'şehir': <gensim.models.keyedvectors.Vocab at 0x633dc99b0>,
#  'dış': <gensim.models.keyedvectors.Vocab at 0x633dc99e8>,
#  'bura': <gensim.models.keyedvectors.Vocab at 0x633dc9a20>,
#  'bide': <gensim.models.keyedvectors.Vocab at 0x633dc9a58>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x633dc9a90>,
#  'dakika': <gensim.models.keyedvectors.Vocab at 0x633dc9ac8>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x633dc9b00>,
#  'izle': <gensim.models.keyedvectors.Vocab at 0x633dc9b38>,
#  'icin': <gensim.models.keyedvectors.Vocab at 0x633dc9b70>,
#  'yarım': <gensim.models.keyedvectors.Vocab at 0x633dc9ba8>,
#  'saat': <gensim.models.keyedvectors.Vocab at 0x633dc9be0>,
#  'dolma': <gensim.models.keyedvectors.Vocab at 0x633dc9c18>,
#  'bekle': <gensim.models.keyedvectors.Vocab at 0x633dc9c50>,
#  'bağla': <gensim.models.keyedvectors.Vocab at 0x633dc9c88>,
#  'git': <gensim.models.keyedvectors.Vocab at 0x633dc9cc0>,
#  'zor': <gensim.models.keyedvectors.Vocab at 0x633dc9cf8>,
#  'su': <gensim.models.keyedvectors.Vocab at 0x633dc9d30>,
#  'dur': <gensim.models.keyedvectors.Vocab at 0x633dc9d68>,
#  'yer': <gensim.models.keyedvectors.Vocab at 0x633dc9da0>,
#  'kac': <gensim.models.keyedvectors.Vocab at 0x633dc9dd8>,
#  'gore': <gensim.models.keyedvectors.Vocab at 0x633dc9e10>,
#  'parala': <gensim.models.keyedvectors.Vocab at 0x633dc9e48>,
#  'cekiyo': <gensim.models.keyedvectors.Vocab at 0x633dc9e80>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x633dc9eb8>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x633dc9ef0>,
#  'ara': <gensim.models.keyedvectors.Vocab at 0x633dc9f28>,
#  'ayıp': <gensim.models.keyedvectors.Vocab at 0x633dc9f60>,
#  'başla': <gensim.models.keyedvectors.Vocab at 0x633dc9f98>,
#  'kurtar': <gensim.models.keyedvectors.Vocab at 0x633dc9fd0>,
#  'sevin': <gensim.models.keyedvectors.Vocab at 0x633dcc048>,
#  'kurum': <gensim.models.keyedvectors.Vocab at 0x633dcc080>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x633dcc0b8>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x633dcc0f0>,
#  'digiturk': <gensim.models.keyedvectors.Vocab at 0x633dcc128>,
#  'garanti': <gensim.models.keyedvectors.Vocab at 0x633dcc160>,
#  'interneti': <gensim.models.keyedvectors.Vocab at 0x633dcc198>,
#  'rezil': <gensim.models.keyedvectors.Vocab at 0x633dcc1d0>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x633dcc208>,
#  'köy': <gensim.models.keyedvectors.Vocab at 0x633dcc240>,
#  'çekme': <gensim.models.keyedvectors.Vocab at 0x633dcc278>,
#  'sürekli': <gensim.models.keyedvectors.Vocab at 0x633dcc2b0>,
#  'yerel': <gensim.models.keyedvectors.Vocab at 0x633dcc2e8>,
#  'değer': <gensim.models.keyedvectors.Vocab at 0x633dcc320>,
#  'kullan': <gensim.models.keyedvectors.Vocab at 0x633dcc358>,
#  'ayar': <gensim.models.keyedvectors.Vocab at 0x633dcc390>,
#  'telefon': <gensim.models.keyedvectors.Vocab at 0x633dcc3c8>,
#  'sözde': <gensim.models.keyedvectors.Vocab at 0x633dcc400>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x633dcc438>,
#  'göbek': <gensim.models.keyedvectors.Vocab at 0x633dcc470>,
#  'tek': <gensim.models.keyedvectors.Vocab at 0x633dcc4a8>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x633dcc4e0>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x633dcc518>,
#  'geçmiş': <gensim.models.keyedvectors.Vocab at 0x633dcc550>,
#  'yüksel': <gensim.models.keyedvectors.Vocab at 0x633dcc588>,
#  'kolay': <gensim.models.keyedvectors.Vocab at 0x633dcc5c0>,
#  'geri': <gensim.models.keyedvectors.Vocab at 0x633dcc5f8>,
#  'zeka': <gensim.models.keyedvectors.Vocab at 0x633dcc630>,
#  'nterneti': <gensim.models.keyedvectors.Vocab at 0x633dcc668>,
#  '23': <gensim.models.keyedvectors.Vocab at 0x633dcc6a0>,
#  'lira': <gensim.models.keyedvectors.Vocab at 0x633dcc6d8>,
#  '35': <gensim.models.keyedvectors.Vocab at 0x633dcc710>,
#  'vere': <gensim.models.keyedvectors.Vocab at 0x633dcc748>,
#  'salak': <gensim.models.keyedvectors.Vocab at 0x633dcc780>,
#  'türk': <gensim.models.keyedvectors.Vocab at 0x633dcc7b8>,
#  'operatör': <gensim.models.keyedvectors.Vocab at 0x633dcc7f0>,
#  'dek': <gensim.models.keyedvectors.Vocab at 0x633dcc828>,
#  'halka': <gensim.models.keyedvectors.Vocab at 0x633dcc860>,
#  'hediye': <gensim.models.keyedvectors.Vocab at 0x633dcc898>,
#  'ürün': <gensim.models.keyedvectors.Vocab at 0x633dcc8d0>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x633dcc908>,
#  'yılla': <gensim.models.keyedvectors.Vocab at 0x633dcc940>,
#  'halk': <gensim.models.keyedvectors.Vocab at 0x633dcc978>,
#  'sömür': <gensim.models.keyedvectors.Vocab at 0x633dcc9b0>,
#  'yap': <gensim.models.keyedvectors.Vocab at 0x633dcc9e8>,
#  'müşteri': <gensim.models.keyedvectors.Vocab at 0x633dcca20>,
#  'hizmet': <gensim.models.keyedvectors.Vocab at 0x633dcca58>,
#  'kalite': <gensim.models.keyedvectors.Vocab at 0x633dcca90>,
#  'felaket': <gensim.models.keyedvectors.Vocab at 0x633dccac8>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x633dccb00>,
#  'hesap': <gensim.models.keyedvectors.Vocab at 0x633dccb38>,
#  'aynı': <gensim.models.keyedvectors.Vocab at 0x633dccb70>,
#  'yazı': <gensim.models.keyedvectors.Vocab at 0x633dccba8>,
#  'arkadaş': <gensim.models.keyedvectors.Vocab at 0x633dccbe0>,
#  'paylaş': <gensim.models.keyedvectors.Vocab at 0x633dccc18>,
#  'yaa': <gensim.models.keyedvectors.Vocab at 0x633dccc50>,
#  'ağız': <gensim.models.keyedvectors.Vocab at 0x633dccc88>,
#  'et': <gensim.models.keyedvectors.Vocab at 0x633dcccc0>,
#  'düzel': <gensim.models.keyedvectors.Vocab at 0x633dcccf8>,
#  'fotoğraf': <gensim.models.keyedvectors.Vocab at 0x633dccd30>,
#  'aç': <gensim.models.keyedvectors.Vocab at 0x633dccd68>,
#  'sürü': <gensim.models.keyedvectors.Vocab at 0x633dccda0>,
#  'heryerde': <gensim.models.keyedvectors.Vocab at 0x633dccdd8>,
#  'hat': <gensim.models.keyedvectors.Vocab at 0x633dcce10>,
#  'üst': <gensim.models.keyedvectors.Vocab at 0x633dcce48>,
#  'bık': <gensim.models.keyedvectors.Vocab at 0x633dcce80>,
#  'baba': <gensim.models.keyedvectors.Vocab at 0x633dcceb8>,
#  'duy': <gensim.models.keyedvectors.Vocab at 0x633dccef0>,
#  'ses': <gensim.models.keyedvectors.Vocab at 0x633dccf28>,
#  'dir': <gensim.models.keyedvectors.Vocab at 0x633dccf60>,
#  'bi': <gensim.models.keyedvectors.Vocab at 0x633dccf98>,
#  'yok': <gensim.models.keyedvectors.Vocab at 0x633dccfd0>,
#  'cekiyor': <gensim.models.keyedvectors.Vocab at 0x633dcf048>,
#  'aq': <gensim.models.keyedvectors.Vocab at 0x633dcf080>,
#  'numara': <gensim.models.keyedvectors.Vocab at 0x633dcf0b8>,
#  'değiş': <gensim.models.keyedvectors.Vocab at 0x633dcf0f0>,
#  'yeter': <gensim.models.keyedvectors.Vocab at 0x633dcf128>,
#  'para': <gensim.models.keyedvectors.Vocab at 0x633dcf160>,
#  'fatura': <gensim.models.keyedvectors.Vocab at 0x633dcf198>,
#  'söv': <gensim.models.keyedvectors.Vocab at 0x633dcf1d0>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x633dcf208>,
#  'sınırsız': <gensim.models.keyedvectors.Vocab at 0x633dcf240>,
#  'san': <gensim.models.keyedvectors.Vocab at 0x633dcf278>,
#  'kek': <gensim.models.keyedvectors.Vocab at 0x633dcf2b0>,
#  'yavaş': <gensim.models.keyedvectors.Vocab at 0x633dcf2e8>,
#  'öl': <gensim.models.keyedvectors.Vocab at 0x633dcf320>,
#  'adet': <gensim.models.keyedvectors.Vocab at 0x633dcf358>,
#  'kahret': <gensim.models.keyedvectors.Vocab at 0x633dcf390>,
#  'bildik': <gensim.models.keyedvectors.Vocab at 0x633dcf3c8>,
#  'ilk': <gensim.models.keyedvectors.Vocab at 0x633dcf400>,
#  'beddua': <gensim.models.keyedvectors.Vocab at 0x633dcf438>,
#  'yalan': <gensim.models.keyedvectors.Vocab at 0x633dcf470>,
#  'söyle': <gensim.models.keyedvectors.Vocab at 0x633dcf4a8>,
#  'sigorta': <gensim.models.keyedvectors.Vocab at 0x633dcf4e0>,
#  'kapsam': <gensim.models.keyedvectors.Vocab at 0x633dcf518>,
#  'çevir': <gensim.models.keyedvectors.Vocab at 0x633dcf550>,
#  'ev': <gensim.models.keyedvectors.Vocab at 0x633dcf588>,
#  'gel': <gensim.models.keyedvectors.Vocab at 0x633dcf5c0>,
#  'adam': <gensim.models.keyedvectors.Vocab at 0x633dcf5f8>,
#  'sinir': <gensim.models.keyedvectors.Vocab at 0x633dcf630>,
#  'çeker': <gensim.models.keyedvectors.Vocab at 0x633dcf668>,
#  'orta': <gensim.models.keyedvectors.Vocab at 0x633dcf6a0>,
#  'şahin': <gensim.models.keyedvectors.Vocab at 0x633dcf6d8>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x633dcf710>,
#  'gectigim': <gensim.models.keyedvectors.Vocab at 0x633dcf748>,
#  'pismanim': <gensim.models.keyedvectors.Vocab at 0x633dcf780>,
#  'allahin': <gensim.models.keyedvectors.Vocab at 0x633dcf7b8>,
#  'nternet': <gensim.models.keyedvectors.Vocab at 0x633dcf7f0>,
#  'allahsız': <gensim.models.keyedvectors.Vocab at 0x633dcf828>,
#  'turkcelle': <gensim.models.keyedvectors.Vocab at 0x633dcf860>,
#  'çekmiyo': <gensim.models.keyedvectors.Vocab at 0x633dcf898>,
#  'biçim': <gensim.models.keyedvectors.Vocab at 0x633dcf8d0>,
#  'sin': <gensim.models.keyedvectors.Vocab at 0x633dcf908>,
#  'edge': <gensim.models.keyedvectors.Vocab at 0x633dcf940>,
#  'sacmalik': <gensim.models.keyedvectors.Vocab at 0x633dcf978>,
#  'abv': <gensim.models.keyedvectors.Vocab at 0x633dcf9b0>,
#  'oda': <gensim.models.keyedvectors.Vocab at 0x633dcf9e8>,
#  'gerçek': <gensim.models.keyedvectors.Vocab at 0x633dcfa20>,
#  'bok': <gensim.models.keyedvectors.Vocab at 0x633dcfa58>,
#  'ur': <gensim.models.keyedvectors.Vocab at 0x633dcfa90>,
#  'adi': <gensim.models.keyedvectors.Vocab at 0x633dcfac8>,
#  'inan': <gensim.models.keyedvectors.Vocab at 0x633dcfb00>,
#  'yaşa': <gensim.models.keyedvectors.Vocab at 0x633dcfb38>,
#  'dürüst': <gensim.models.keyedvectors.Vocab at 0x633dcfb70>,
#  'aş': <gensim.models.keyedvectors.Vocab at 0x633dcfba8>,
#  '13': <gensim.models.keyedvectors.Vocab at 0x633dcfbe0>,
#  'tl': <gensim.models.keyedvectors.Vocab at 0x633dcfc18>,
#  'kit': <gensim.models.keyedvectors.Vocab at 0x633dcfc50>,
#  'sahtekar': <gensim.models.keyedvectors.Vocab at 0x633dcfc88>,
#  'gerizekalı': <gensim.models.keyedvectors.Vocab at 0x633dcfcc0>,
#  'kardeş': <gensim.models.keyedvectors.Vocab at 0x633dcfcf8>,
#  'dair': <gensim.models.keyedvectors.Vocab at 0x633dcfd30>,
#  'yolla': <gensim.models.keyedvectors.Vocab at 0x633dcfd68>,
#  'ömür': <gensim.models.keyedvectors.Vocab at 0x633dcfda0>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x633dcfdd8>,
#  'zaman': <gensim.models.keyedvectors.Vocab at 0x633dcfe10>,
#  'hız': <gensim.models.keyedvectors.Vocab at 0x633dcfe48>,
#  'rezalet': <gensim.models.keyedvectors.Vocab at 0x633dcfe80>,
#  'kontrat': <gensim.models.keyedvectors.Vocab at 0x633dcfeb8>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x633dcfef0>,
#  'ay': <gensim.models.keyedvectors.Vocab at 0x633dcff28>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x633dcff60>,
#  'yükle': <gensim.models.keyedvectors.Vocab at 0x633dcff98>,
#  'gelin': <gensim.models.keyedvectors.Vocab at 0x633dcffd0>,
#  'elde': <gensim.models.keyedvectors.Vocab at 0x633dd2048>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x633dd2080>,
#  'bugün': <gensim.models.keyedvectors.Vocab at 0x633dd20b8>,
#  'mutlu': <gensim.models.keyedvectors.Vocab at 0x633dd20f0>,
#  'şua': <gensim.models.keyedvectors.Vocab at 0x633dd2128>,
#  'internetim': <gensim.models.keyedvectors.Vocab at 0x633dd2160>,
#  'hafta': <gensim.models.keyedvectors.Vocab at 0x633dd2198>,
#  'yıl': <gensim.models.keyedvectors.Vocab at 0x633dd21d0>,
#  'bağlantı': <gensim.models.keyedvectors.Vocab at 0x633dd2208>,
#  'açık': <gensim.models.keyedvectors.Vocab at 0x633dd2240>,
#  'sınıf': <gensim.models.keyedvectors.Vocab at 0x633dd2278>,
#  'yazık': <gensim.models.keyedvectors.Vocab at 0x633dd22b0>,
#  'eziyet': <gensim.models.keyedvectors.Vocab at 0x633dd22e8>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x633dd2320>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x633dd2358>,
#  'sene': <gensim.models.keyedvectors.Vocab at 0x633dd2390>,
#  'belani': <gensim.models.keyedvectors.Vocab at 0x633dd23c8>,
#  'haram': <gensim.models.keyedvectors.Vocab at 0x633dd2400>,
#  'zıkkım': <gensim.models.keyedvectors.Vocab at 0x633dd2438>,
#  'çekiyo': <gensim.models.keyedvectors.Vocab at 0x633dd2470>,
#  'ada': <gensim.models.keyedvectors.Vocab at 0x633dd24a8>,
#  'bırak': <gensim.models.keyedvectors.Vocab at 0x633dd24e0>,
#  'galiba': <gensim.models.keyedvectors.Vocab at 0x633dd2518>,
#  'yavaşla': <gensim.models.keyedvectors.Vocab at 0x633dd2550>,
#  'metro': <gensim.models.keyedvectors.Vocab at 0x633dd2588>,
#  'konuş': <gensim.models.keyedvectors.Vocab at 0x633dd25c0>,
#  'açıkla': <gensim.models.keyedvectors.Vocab at 0x633dd25f8>,
#  'firma': <gensim.models.keyedvectors.Vocab at 0x633dd2630>,
#  'odedigim': <gensim.models.keyedvectors.Vocab at 0x633dd2668>,
#  'faturala': <gensim.models.keyedvectors.Vocab at 0x633dd26a0>,
#  'bol': <gensim.models.keyedvectors.Vocab at 0x633dd26d8>,
#  'net': <gensim.models.keyedvectors.Vocab at 0x633dd2710>,
#  'yemin': <gensim.models.keyedvectors.Vocab at 0x633dd2748>,
#  'eder': <gensim.models.keyedvectors.Vocab at 0x633dd2780>,
#  'ton': <gensim.models.keyedvectors.Vocab at 0x633dd27b8>,
#  'dolu': <gensim.models.keyedvectors.Vocab at 0x633dd27f0>,
#  'tut': <gensim.models.keyedvectors.Vocab at 0x633dd2828>,
#  'gayrettepe': <gensim.models.keyedvectors.Vocab at 0x633dd2860>,
#  '3g': <gensim.models.keyedvectors.Vocab at 0x633dd2898>,
#  'eriş': <gensim.models.keyedvectors.Vocab at 0x633dd28d0>,
#  'ney': <gensim.models.keyedvectors.Vocab at 0x633dd2908>,
#  'avea': <gensim.models.keyedvectors.Vocab at 0x633dd2940>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x633dd2978>,
#  'işe': <gensim.models.keyedvectors.Vocab at 0x633dd29b0>,
#  'resmen': <gensim.models.keyedvectors.Vocab at 0x633dd29e8>,
#  'tekrar': <gensim.models.keyedvectors.Vocab at 0x633dd2a20>,
#  'sefer': <gensim.models.keyedvectors.Vocab at 0x633dd2a58>,
#  'dene': <gensim.models.keyedvectors.Vocab at 0x633dd2a90>,
#  'kafa': <gensim.models.keyedvectors.Vocab at 0x633dd2ac8>,
#  'deli': <gensim.models.keyedvectors.Vocab at 0x633dd2b00>,
#  'soru': <gensim.models.keyedvectors.Vocab at 0x633dd2b38>,
#  'neymis': <gensim.models.keyedvectors.Vocab at 0x633dd2b70>,
#  'bak': <gensim.models.keyedvectors.Vocab at 0x633dd2ba8>,
#  'evet': <gensim.models.keyedvectors.Vocab at 0x633dd2be0>,
#  'dort': <gensim.models.keyedvectors.Vocab at 0x633dd2c18>,
#  'ceker': <gensim.models.keyedvectors.Vocab at 0x633dd2c50>,
#  'olayi': <gensim.models.keyedvectors.Vocab at 0x633dd2c88>,
#  'kadın': <gensim.models.keyedvectors.Vocab at 0x633dd2cc0>,
#  'gül': <gensim.models.keyedvectors.Vocab at 0x633dd2cf8>,
#  'kucak': <gensim.models.keyedvectors.Vocab at 0x633dd2d30>,
#  'kız': <gensim.models.keyedvectors.Vocab at 0x633dd2d68>,
#  'telekom': <gensim.models.keyedvectors.Vocab at 0x633dd2da0>,
#  'arena': <gensim.models.keyedvectors.Vocab at 0x633dd2dd8>,
#  'kağnı': <gensim.models.keyedvectors.Vocab at 0x633dd2e10>,
#  'kandır': <gensim.models.keyedvectors.Vocab at 0x633dd2e48>,
#  'yarın': <gensim.models.keyedvectors.Vocab at 0x633dd2e80>,
#  'karar': <gensim.models.keyedvectors.Vocab at 0x633dd2eb8>,
#  'dd': <gensim.models.keyedvectors.Vocab at 0x633dd2ef0>,
#  'mekan': <gensim.models.keyedvectors.Vocab at 0x633dd2f28>,
#  'sıcak': <gensim.models.keyedvectors.Vocab at 0x633dd2f60>,
#  'şebeke': <gensim.models.keyedvectors.Vocab at 0x633dd2f98>,
#  'kesin': <gensim.models.keyedvectors.Vocab at 0x633dd2fd0>,
#  'önem': <gensim.models.keyedvectors.Vocab at 0x633dd6048>,
#  'mesj': <gensim.models.keyedvectors.Vocab at 0x633dd6080>,
#  'gelir': <gensim.models.keyedvectors.Vocab at 0x633dd60b8>,
#  'heyecan': <gensim.models.keyedvectors.Vocab at 0x633dd60f0>,
#  'görün': <gensim.models.keyedvectors.Vocab at 0x633dd6128>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x633dd6160>,
#  'taşı': <gensim.models.keyedvectors.Vocab at 0x633dd6198>,
#  'insan': <gensim.models.keyedvectors.Vocab at 0x633dd61d0>,
#  'ücret': <gensim.models.keyedvectors.Vocab at 0x633dd6208>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x633dd6240>,
#  'gün': <gensim.models.keyedvectors.Vocab at 0x633dd6278>,
#  'atıyo': <gensim.models.keyedvectors.Vocab at 0x633dd62b0>,
#  'çıldır': <gensim.models.keyedvectors.Vocab at 0x633dd62e8>,
#  'geçer': <gensim.models.keyedvectors.Vocab at 0x633dd6320>,
#  'dağ': <gensim.models.keyedvectors.Vocab at 0x633dd6358>,
#  'tepe': <gensim.models.keyedvectors.Vocab at 0x633dd6390>,
#  'veda': <gensim.models.keyedvectors.Vocab at 0x633dd63c8>,
#  'devir': <gensim.models.keyedvectors.Vocab at 0x633dd6400>,
#  'müthiş': <gensim.models.keyedvectors.Vocab at 0x633dd6438>,
#  'fikri': <gensim.models.keyedvectors.Vocab at 0x633dd6470>,
#  'başarı': <gensim.models.keyedvectors.Vocab at 0x633dd64a8>,
#  'aday': <gensim.models.keyedvectors.Vocab at 0x633dd64e0>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x633dd6518>,
#  'gece': <gensim.models.keyedvectors.Vocab at 0x633dd6550>,
#  'gündüz': <gensim.models.keyedvectors.Vocab at 0x633dd6588>,
#  'yağ': <gensim.models.keyedvectors.Vocab at 0x633dd65c0>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x633dd65f8>,
#  'kazan': <gensim.models.keyedvectors.Vocab at 0x633dd6630>,
#  'hale': <gensim.models.keyedvectors.Vocab at 0x633dd6668>,
#  'tavsiye': <gensim.models.keyedvectors.Vocab at 0x633dd66a0>,
#  'sifir': <gensim.models.keyedvectors.Vocab at 0x633dd66d8>,
#  'ttnet': <gensim.models.keyedvectors.Vocab at 0x633dd6710>,
#  'yol': <gensim.models.keyedvectors.Vocab at 0x633dd6748>,
#  'belasini': <gensim.models.keyedvectors.Vocab at 0x633dd6780>,
#  'anca': <gensim.models.keyedvectors.Vocab at 0x633dd67b8>,
#  'lanet': <gensim.models.keyedvectors.Vocab at 0x633dd67f0>,
#  'yaaa': <gensim.models.keyedvectors.Vocab at 0x633dd6828>,
#  'hak': <gensim.models.keyedvectors.Vocab at 0x633dd6860>,
#  'veri': <gensim.models.keyedvectors.Vocab at 0x633dd6898>,
#  'limit': <gensim.models.keyedvectors.Vocab at 0x633dd68d0>,
#  'düşür': <gensim.models.keyedvectors.Vocab at 0x633dd6908>,
#  'dolandır': <gensim.models.keyedvectors.Vocab at 0x633dd6940>,
#  'sabah': <gensim.models.keyedvectors.Vocab at 0x633dd6978>,
#  'yaptim': <gensim.models.keyedvectors.Vocab at 0x633dd69b0>,
#  'hal': <gensim.models.keyedvectors.Vocab at 0x633dd69e8>,
#  'internetimi': <gensim.models.keyedvectors.Vocab at 0x633dd6a20>,
#  'boşuna': <gensim.models.keyedvectors.Vocab at 0x633dd6a58>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x633dd6a90>,
#  'fatih': <gensim.models.keyedvectors.Vocab at 0x633dd6ac8>,
#  'kara': <gensim.models.keyedvectors.Vocab at 0x633dd6b00>,
#  'murat': <gensim.models.keyedvectors.Vocab at 0x633dd6b38>,
#  'uğraş': <gensim.models.keyedvectors.Vocab at 0x633dd6b70>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x633dd6ba8>,
#  'küfür': <gensim.models.keyedvectors.Vocab at 0x633dd6be0>,
#  'bedel': <gensim.models.keyedvectors.Vocab at 0x633dd6c18>,
#  'sinirli': <gensim.models.keyedvectors.Vocab at 0x633dd6c50>,
#  'bitir': <gensim.models.keyedvectors.Vocab at 0x633dd6c88>,
#  'sosyal': <gensim.models.keyedvectors.Vocab at 0x633dd6cc0>,
#  'digitürk': <gensim.models.keyedvectors.Vocab at 0x633dd6cf8>,
#  'alay': <gensim.models.keyedvectors.Vocab at 0x633dd6d30>,
#  'bozul': <gensim.models.keyedvectors.Vocab at 0x633dd6d68>,
#  'pislik': <gensim.models.keyedvectors.Vocab at 0x633dd6da0>,
#  'öv': <gensim.models.keyedvectors.Vocab at 0x633dd6dd8>,
#  'turkcel': <gensim.models.keyedvectors.Vocab at 0x633dd6e10>,
#  'eski': <gensim.models.keyedvectors.Vocab at 0x633dd6e48>,
#  'sevgi': <gensim.models.keyedvectors.Vocab at 0x633dd6e80>,
#  'kurtul': <gensim.models.keyedvectors.Vocab at 0x633dd6eb8>,
#  'yanlış': <gensim.models.keyedvectors.Vocab at 0x633dd6ef0>,
#  'internette': <gensim.models.keyedvectors.Vocab at 0x633dd6f28>,
#  'düşün': <gensim.models.keyedvectors.Vocab at 0x633dd6f60>,
#  'fiyat': <gensim.models.keyedvectors.Vocab at 0x633dd6f98>,
#  'bil': <gensim.models.keyedvectors.Vocab at 0x633dd6fd0>,
#  'leş': <gensim.models.keyedvectors.Vocab at 0x633dd9048>,
#  'dogum': <gensim.models.keyedvectors.Vocab at 0x633dd9080>,
#  'günü': <gensim.models.keyedvectors.Vocab at 0x633dd90b8>,
#  'türlü': <gensim.models.keyedvectors.Vocab at 0x633dd90f0>,
#  'abi': <gensim.models.keyedvectors.Vocab at 0x633dd9128>,
#  'yapsin': <gensim.models.keyedvectors.Vocab at 0x633dd9160>,
#  'ilgilen': <gensim.models.keyedvectors.Vocab at 0x633dd9198>,
#  'sırf': <gensim.models.keyedvectors.Vocab at 0x633dd91d0>,
#  'yuzden': <gensim.models.keyedvectors.Vocab at 0x633dd9208>,
#  'hattimi': <gensim.models.keyedvectors.Vocab at 0x633dd9240>,
#  'göz': <gensim.models.keyedvectors.Vocab at 0x633dd9278>,
#  'çık': <gensim.models.keyedvectors.Vocab at 0x633dd92b0>,
#  'bayıl': <gensim.models.keyedvectors.Vocab at 0x633dd92e8>,
#  'genç': <gensim.models.keyedvectors.Vocab at 0x633dd9320>,
#  'utan': <gensim.models.keyedvectors.Vocab at 0x633dd9358>,
#  'tarife': <gensim.models.keyedvectors.Vocab at 0x633dd9390>,
#  'acep': <gensim.models.keyedvectors.Vocab at 0x633dd93c8>,
#  'felan': <gensim.models.keyedvectors.Vocab at 0x633dd9400>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x633dd9438>,
#  'yad': <gensim.models.keyedvectors.Vocab at 0x633dd9470>,
#  'yoğun': <gensim.models.keyedvectors.Vocab at 0x633dd94a8>,
#  'sıkıntı': <gensim.models.keyedvectors.Vocab at 0x633dd94e0>,
#  'yarat': <gensim.models.keyedvectors.Vocab at 0x633dd9518>,
#  'sık': <gensim.models.keyedvectors.Vocab at 0x633dd9550>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x633dd9588>,
#  'kına': <gensim.models.keyedvectors.Vocab at 0x633dd95c0>,
#  'pis': <gensim.models.keyedvectors.Vocab at 0x633dd95f8>,
#  'yavşak': <gensim.models.keyedvectors.Vocab at 0x633dd9630>,
#  'sarı': <gensim.models.keyedvectors.Vocab at 0x633dd9668>,
#  'kutu': <gensim.models.keyedvectors.Vocab at 0x633dd96a0>,
#  'migros': <gensim.models.keyedvectors.Vocab at 0x633dd96d8>,
#  'sanal': <gensim.models.keyedvectors.Vocab at 0x633dd9710>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x633dd9748>,
#  'çeki': <gensim.models.keyedvectors.Vocab at 0x633dd9780>,
#  'şifre': <gensim.models.keyedvectors.Vocab at 0x633dd97b8>,
#  'sülale': <gensim.models.keyedvectors.Vocab at 0x633dd97f0>,
#  'sakin': <gensim.models.keyedvectors.Vocab at 0x633dd9828>,
#  'kullanmayin': <gensim.models.keyedvectors.Vocab at 0x633dd9860>,
#  'iptal': <gensim.models.keyedvectors.Vocab at 0x633dd9898>,
#  'cani': <gensim.models.keyedvectors.Vocab at 0x633dd98d0>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x633dd9908>,
#  'boyun': <gensim.models.keyedvectors.Vocab at 0x633dd9940>,
#  'ramazan': <gensim.models.keyedvectors.Vocab at 0x633dd9978>,
#  'millet': <gensim.models.keyedvectors.Vocab at 0x633dd99b0>,
#  'taşım': <gensim.models.keyedvectors.Vocab at 0x633dd99e8>,
#  'kazik': <gensim.models.keyedvectors.Vocab at 0x633dd9a20>,
#  'yed': <gensim.models.keyedvectors.Vocab at 0x633dd9a58>,
#  'artik': <gensim.models.keyedvectors.Vocab at 0x633dd9a90>,
#  'geciyorum': <gensim.models.keyedvectors.Vocab at 0x633dd9ac8>,
#  'ayır': <gensim.models.keyedvectors.Vocab at 0x633dd9b00>,
#  'nefret': <gensim.models.keyedvectors.Vocab at 0x633dd9b38>,
#  'dayan': <gensim.models.keyedvectors.Vocab at 0x633dd9b70>,
#  'yeni': <gensim.models.keyedvectors.Vocab at 0x633dd9ba8>,
#  'getir': <gensim.models.keyedvectors.Vocab at 0x633dd9be0>,
#  'sony': <gensim.models.keyedvectors.Vocab at 0x633dd9c18>,
#  'xperia': <gensim.models.keyedvectors.Vocab at 0x633dd9c50>,
#  'akşam': <gensim.models.keyedvectors.Vocab at 0x633dd9c88>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x633dd9cc0>,
#  'ayrı': <gensim.models.keyedvectors.Vocab at 0x633dd9cf8>,
#  'inşallah': <gensim.models.keyedvectors.Vocab at 0x633dd9d30>,
#  'iflas': <gensim.models.keyedvectors.Vocab at 0x633dd9d68>,
#  'fena': <gensim.models.keyedvectors.Vocab at 0x633dd9da0>,
#  'turbo': <gensim.models.keyedvectors.Vocab at 0x633dd9dd8>,
#  'sakın': <gensim.models.keyedvectors.Vocab at 0x633dd9e10>,
#  'berbat': <gensim.models.keyedvectors.Vocab at 0x633dd9e48>,
#  'kop': <gensim.models.keyedvectors.Vocab at 0x633dd9e80>,
#  'hava': <gensim.models.keyedvectors.Vocab at 0x633dd9eb8>,
#  'kandil': <gensim.models.keyedvectors.Vocab at 0x633dd9ef0>,
#  'kilitle': <gensim.models.keyedvectors.Vocab at 0x633dd9f28>,
#  'deprem': <gensim.models.keyedvectors.Vocab at 0x633dd9f60>,
#  'seferi': <gensim.models.keyedvectors.Vocab at 0x633dd9f98>,
#  'haber': <gensim.models.keyedvectors.Vocab at 0x633dd9fd0>,
#  'bakiye': <gensim.models.keyedvectors.Vocab at 0x633ddd048>,
#  'hırsız': <gensim.models.keyedvectors.Vocab at 0x633ddd080>,
#  'amaç': <gensim.models.keyedvectors.Vocab at 0x633ddd0b8>,
#  'allahım': <gensim.models.keyedvectors.Vocab at 0x633ddd0f0>,
#  'sms': <gensim.models.keyedvectors.Vocab at 0x633ddd128>,
#  'oc': <gensim.models.keyedvectors.Vocab at 0x633ddd160>,
#  'ufak': <gensim.models.keyedvectors.Vocab at 0x633ddd198>,
#  'kes': <gensim.models.keyedvectors.Vocab at 0x633ddd1d0>,
#  'baş': <gensim.models.keyedvectors.Vocab at 0x633ddd208>,
#  'boz': <gensim.models.keyedvectors.Vocab at 0x633ddd240>,
#  'hayat': <gensim.models.keyedvectors.Vocab at 0x633ddd278>,
#  'lazim': <gensim.models.keyedvectors.Vocab at 0x633ddd2b0>,
#  '70': <gensim.models.keyedvectors.Vocab at 0x633ddd2e8>,
#  'kredi': <gensim.models.keyedvectors.Vocab at 0x633ddd320>,
#  'kart': <gensim.models.keyedvectors.Vocab at 0x633ddd358>,
#  'rakam': <gensim.models.keyedvectors.Vocab at 0x633ddd390>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x633ddd3c8>,
#  'sorun': <gensim.models.keyedvectors.Vocab at 0x633ddd400>,
#  'stres': <gensim.models.keyedvectors.Vocab at 0x633ddd438>,
#  'sirketi': <gensim.models.keyedvectors.Vocab at 0x633ddd470>,
#  'devlet': <gensim.models.keyedvectors.Vocab at 0x633ddd4a8>,
#  'dinlen': <gensim.models.keyedvectors.Vocab at 0x633ddd4e0>,
#  'korku': <gensim.models.keyedvectors.Vocab at 0x633ddd518>,
#  'gizli': <gensim.models.keyedvectors.Vocab at 0x633ddd550>,
#  'toplantı': <gensim.models.keyedvectors.Vocab at 0x633ddd588>,
#  'turkcellhizmet': <gensim.models.keyedvectors.Vocab at 0x633ddd5c0>,
#  'bugun': <gensim.models.keyedvectors.Vocab at 0x633ddd5f8>,
#  'attigi': <gensim.models.keyedvectors.Vocab at 0x633ddd630>,
#  'devam': <gensim.models.keyedvectors.Vocab at 0x633ddd668>,
#  'onca': <gensim.models.keyedvectors.Vocab at 0x633ddd6a0>,
#  'helal': <gensim.models.keyedvectors.Vocab at 0x633ddd6d8>,
#  'baska': <gensim.models.keyedvectors.Vocab at 0x633ddd710>,
#  'bı': <gensim.models.keyedvectors.Vocab at 0x633ddd748>,
#  'sey': <gensim.models.keyedvectors.Vocab at 0x633ddd780>,
#  'duygu': <gensim.models.keyedvectors.Vocab at 0x633ddd7b8>,
#  'oyna': <gensim.models.keyedvectors.Vocab at 0x633ddd7f0>,
#  'uyuz': <gensim.models.keyedvectors.Vocab at 0x633ddd828>,
#  'doğru': <gensim.models.keyedvectors.Vocab at 0x633ddd860>,
#  'ey': <gensim.models.keyedvectors.Vocab at 0x633ddd898>,
#  'asker': <gensim.models.keyedvectors.Vocab at 0x633ddd8d0>,
#  'hic': <gensim.models.keyedvectors.Vocab at 0x633ddd908>,
#  'yatır': <gensim.models.keyedvectors.Vocab at 0x633ddd940>,
#  'yuh': <gensim.models.keyedvectors.Vocab at 0x633ddd978>,
#  'iş': <gensim.models.keyedvectors.Vocab at 0x633ddd9b0>,
#  'zengin': <gensim.models.keyedvectors.Vocab at 0x633ddd9e8>,
#  'yokmu': <gensim.models.keyedvectors.Vocab at 0x633ddda20>,
#  'cim': <gensim.models.keyedvectors.Vocab at 0x633ddda58>,
#  'smsi': <gensim.models.keyedvectors.Vocab at 0x633ddda90>,
#  'kuru': <gensim.models.keyedvectors.Vocab at 0x633dddac8>,
#  'atti': <gensim.models.keyedvectors.Vocab at 0x633dddb00>,
#  'sok': <gensim.models.keyedvectors.Vocab at 0x633dddb38>,
#  'ayrıl': <gensim.models.keyedvectors.Vocab at 0x633dddb70>,
#  'sebep': <gensim.models.keyedvectors.Vocab at 0x633dddba8>,
#  'memnun': <gensim.models.keyedvectors.Vocab at 0x633dddbe0>,
#  'akıl': <gensim.models.keyedvectors.Vocab at 0x633dddc18>,
#  'isim': <gensim.models.keyedvectors.Vocab at 0x633dddc50>,
#  'kısa': <gensim.models.keyedvectors.Vocab at 0x633dddc88>,
#  'azı': <gensim.models.keyedvectors.Vocab at 0x633dddcc0>,
#  'sabri': <gensim.models.keyedvectors.Vocab at 0x633dddcf8>,
#  'ilgi': <gensim.models.keyedvectors.Vocab at 0x633dddd30>,
#  'guzel': <gensim.models.keyedvectors.Vocab at 0x633dddd68>,
#  'marka': <gensim.models.keyedvectors.Vocab at 0x633dddda0>,
#  'dunyanin': <gensim.models.keyedvectors.Vocab at 0x633ddddd8>,
#  'reklamini': <gensim.models.keyedvectors.Vocab at 0x633ddde10>,
#  'turkcellden': <gensim.models.keyedvectors.Vocab at 0x633ddde48>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x633ddde80>,
#  'bitiyo': <gensim.models.keyedvectors.Vocab at 0x633dddeb8>,
#  'ek': <gensim.models.keyedvectors.Vocab at 0x633dddef0>,
#  'katı': <gensim.models.keyedvectors.Vocab at 0x633dddf28>,
#  'ateş': <gensim.models.keyedvectors.Vocab at 0x633dddf60>,
#  'reklamlari': <gensim.models.keyedvectors.Vocab at 0x633dddf98>,
#  'saçma': <gensim.models.keyedvectors.Vocab at 0x633dddfd0>,
#  'çalış': <gensim.models.keyedvectors.Vocab at 0x633de0048>,
#  'sömürü': <gensim.models.keyedvectors.Vocab at 0x633de0080>,
#  'yapıyo': <gensim.models.keyedvectors.Vocab at 0x633de00b8>,
#  'ateşle': <gensim.models.keyedvectors.Vocab at 0x633de00f0>,
#  'sal': <gensim.models.keyedvectors.Vocab at 0x633de0128>,
#  'ilet': <gensim.models.keyedvectors.Vocab at 0x633de0160>,
#  'suç': <gensim.models.keyedvectors.Vocab at 0x633de0198>,
#  'sıkıl': <gensim.models.keyedvectors.Vocab at 0x633de01d0>,
#  'coca': <gensim.models.keyedvectors.Vocab at 0x633de0208>,
#  'cola': <gensim.models.keyedvectors.Vocab at 0x633de0240>,
#  'yla': <gensim.models.keyedvectors.Vocab at 0x633de0278>,
#  'vur': <gensim.models.keyedvectors.Vocab at 0x633de02b0>,
#  'umut': <gensim.models.keyedvectors.Vocab at 0x633de02e8>,
#  'sine': <gensim.models.keyedvectors.Vocab at 0x633de0320>,
#  'ocak': <gensim.models.keyedvectors.Vocab at 0x633de0358>,
#  'tanı': <gensim.models.keyedvectors.Vocab at 0x633de0390>,
#  'kapitalist': <gensim.models.keyedvectors.Vocab at 0x633de03c8>,
#  'dünya': <gensim.models.keyedvectors.Vocab at 0x633de0400>,
#  'soyguncu': <gensim.models.keyedvectors.Vocab at 0x633de0438>,
#  'si': <gensim.models.keyedvectors.Vocab at 0x633de0470>,
#  'fi': <gensim.models.keyedvectors.Vocab at 0x633de04a8>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x633de04e0>,
#  'hayır': <gensim.models.keyedvectors.Vocab at 0x633de0518>,
#  'unut': <gensim.models.keyedvectors.Vocab at 0x633de0550>,
#  'allahın': <gensim.models.keyedvectors.Vocab at 0x633de0588>,
#  'gidi': <gensim.models.keyedvectors.Vocab at 0x633de05c0>,
#  'yarış': <gensim.models.keyedvectors.Vocab at 0x633de05f8>,
#  'birbir': <gensim.models.keyedvectors.Vocab at 0x633de0630>,
#  'sapan': <gensim.models.keyedvectors.Vocab at 0x633de0668>,
#  'yayın': <gensim.models.keyedvectors.Vocab at 0x633de06a0>,
#  'sacma': <gensim.models.keyedvectors.Vocab at 0x633de06d8>,
#  'cok': <gensim.models.keyedvectors.Vocab at 0x633de0710>,
#  'kuruş': <gensim.models.keyedvectors.Vocab at 0x633de0748>,
#  'sesli': <gensim.models.keyedvectors.Vocab at 0x633de0780>,
#  'dinle': <gensim.models.keyedvectors.Vocab at 0x633de07b8>,
#  'kahrol': <gensim.models.keyedvectors.Vocab at 0x633de07f0>,
#  'fakir': <gensim.models.keyedvectors.Vocab at 0x633de0828>,
#  'whatsapp': <gensim.models.keyedvectors.Vocab at 0x633de0860>,
#  'kapan': <gensim.models.keyedvectors.Vocab at 0x633de0898>,
#  'alacak': <gensim.models.keyedvectors.Vocab at 0x633de08d0>,
#  'vazgeç': <gensim.models.keyedvectors.Vocab at 0x633de0908>,
#  'taksit': <gensim.models.keyedvectors.Vocab at 0x633de0940>,
#  'duvar': <gensim.models.keyedvectors.Vocab at 0x633de0978>,
#  'lütfen': <gensim.models.keyedvectors.Vocab at 0x633de09b0>,
#  'sanirim': <gensim.models.keyedvectors.Vocab at 0x633de09e8>,
#  'suan': <gensim.models.keyedvectors.Vocab at 0x633de0a20>,
#  'servis': <gensim.models.keyedvectors.Vocab at 0x633de0a58>,
#  'internete': <gensim.models.keyedvectors.Vocab at 0x633de0a90>,
#  'delir': <gensim.models.keyedvectors.Vocab at 0x633de0ac8>,
#  'duyu': <gensim.models.keyedvectors.Vocab at 0x633de0b00>,
#  'bodrum': <gensim.models.keyedvectors.Vocab at 0x633de0b38>,
#  'yavas': <gensim.models.keyedvectors.Vocab at 0x633de0b70>,
#  'yaziklar': <gensim.models.keyedvectors.Vocab at 0x633de0ba8>,
#  'reklami': <gensim.models.keyedvectors.Vocab at 0x633de0be0>,
#  'musteri': <gensim.models.keyedvectors.Vocab at 0x633de0c18>,
#  'temsil': <gensim.models.keyedvectors.Vocab at 0x633de0c50>,
#  'pisman': <gensim.models.keyedvectors.Vocab at 0x633de0c88>,
#  'anne': <gensim.models.keyedvectors.Vocab at 0x633de0cc0>,
#  'nternetin': <gensim.models.keyedvectors.Vocab at 0x633de0cf8>,
#  'keyfi': <gensim.models.keyedvectors.Vocab at 0x633de0d30>,
#  'sür': <gensim.models.keyedvectors.Vocab at 0x633de0d68>,
#  'gazete': <gensim.models.keyedvectors.Vocab at 0x633de0da0>,
#  'oku': <gensim.models.keyedvectors.Vocab at 0x633de0dd8>,
#  'giriş': <gensim.models.keyedvectors.Vocab at 0x633de0e10>,
#  'işkence': <gensim.models.keyedvectors.Vocab at 0x633de0e48>,
#  'iğrenç': <gensim.models.keyedvectors.Vocab at 0x633de0e80>,
#  'küçük': <gensim.models.keyedvectors.Vocab at 0x633de0eb8>,
#  'yenile': <gensim.models.keyedvectors.Vocab at 0x633de0ef0>,
#  'anla': <gensim.models.keyedvectors.Vocab at 0x633de0f28>,
#  'hemen': <gensim.models.keyedvectors.Vocab at 0x633de0f60>,
#  'alıyo': <gensim.models.keyedvectors.Vocab at 0x633de0f98>,
#  'soy': <gensim.models.keyedvectors.Vocab at 0x633de0fd0>,
#  'bişey': <gensim.models.keyedvectors.Vocab at 0x633de4048>,
#  'başka': <gensim.models.keyedvectors.Vocab at 0x633de4080>,
#  'mesele': <gensim.models.keyedvectors.Vocab at 0x633de40b8>,
#  'çözüm': <gensim.models.keyedvectors.Vocab at 0x633de40f0>,
#  'bari': <gensim.models.keyedvectors.Vocab at 0x633de4128>,
#  'hisset': <gensim.models.keyedvectors.Vocab at 0x633de4160>,
#  'ah': <gensim.models.keyedvectors.Vocab at 0x633de4198>,
#  'uygula': <gensim.models.keyedvectors.Vocab at 0x633de41d0>,
#  'hergün': <gensim.models.keyedvectors.Vocab at 0x633de4208>,
#  'kol': <gensim.models.keyedvectors.Vocab at 0x633de4240>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x633de4278>,
#  '80': <gensim.models.keyedvectors.Vocab at 0x633de42b0>,
#  'paylasinca': <gensim.models.keyedvectors.Vocab at 0x633de42e8>,
#  'guzeldi': <gensim.models.keyedvectors.Vocab at 0x633de4320>,
#  'çağrı': <gensim.models.keyedvectors.Vocab at 0x633de4358>,
#  'merkezi': <gensim.models.keyedvectors.Vocab at 0x633de4390>,
#  'reklamlarini': <gensim.models.keyedvectors.Vocab at 0x633de43c8>,
#  'ği': <gensim.models.keyedvectors.Vocab at 0x633de4400>,
#  'vodafonea': <gensim.models.keyedvectors.Vocab at 0x633de4438>,
#  'gecmek': <gensim.models.keyedvectors.Vocab at 0x633de4470>,
#  'kizi': <gensim.models.keyedvectors.Vocab at 0x633de44a8>,
#  'alip': <gensim.models.keyedvectors.Vocab at 0x633de44e0>,
#  'değişim': <gensim.models.keyedvectors.Vocab at 0x633de4518>,
#  'güzel': <gensim.models.keyedvectors.Vocab at 0x633de4550>,
#  'tarafindan': <gensim.models.keyedvectors.Vocab at 0x633de4588>,
#  'disinda': <gensim.models.keyedvectors.Vocab at 0x633de45c0>,
#  'gun': <gensim.models.keyedvectors.Vocab at 0x633de45f8>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x633de4630>,
#  'mms': <gensim.models.keyedvectors.Vocab at 0x633de4668>,
#  'koskoca': <gensim.models.keyedvectors.Vocab at 0x633de46a0>,
#  'olası': <gensim.models.keyedvectors.Vocab at 0x633de46d8>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x633de4710>,
#  'diyo': <gensim.models.keyedvectors.Vocab at 0x633de4748>,
#  'cevap': <gensim.models.keyedvectors.Vocab at 0x633de4780>,
#  'zarar': <gensim.models.keyedvectors.Vocab at 0x633de47b8>,
#  'teknoloji': <gensim.models.keyedvectors.Vocab at 0x633de47f0>,
#  'ilerle': <gensim.models.keyedvectors.Vocab at 0x633de4828>,
#  'çağ': <gensim.models.keyedvectors.Vocab at 0x633de4860>,
#  'bul': <gensim.models.keyedvectors.Vocab at 0x633de4898>,
#  'batır': <gensim.models.keyedvectors.Vocab at 0x633de48d0>,
#  'aptal': <gensim.models.keyedvectors.Vocab at 0x633de4908>,
#  'dava': <gensim.models.keyedvectors.Vocab at 0x633de4940>,
#  'krs': <gensim.models.keyedvectors.Vocab at 0x633de4978>,
#  'turkcelli': <gensim.models.keyedvectors.Vocab at 0x633de49b0>,
#  'sirf': <gensim.models.keyedvectors.Vocab at 0x633de49e8>,
#  'pismanliktir': <gensim.models.keyedvectors.Vocab at 0x633de4a20>,
#  'gec': <gensim.models.keyedvectors.Vocab at 0x633de4a58>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x633de4a90>,
#  'bas': <gensim.models.keyedvectors.Vocab at 0x633de4ac8>,
#  'kontör': <gensim.models.keyedvectors.Vocab at 0x633de4b00>,
#  'kere': <gensim.models.keyedvectors.Vocab at 0x633de4b38>,
#  'zalim': <gensim.models.keyedvectors.Vocab at 0x633de4b70>,
#  'kota': <gensim.models.keyedvectors.Vocab at 0x633de4ba8>,
#  'gormedim': <gensim.models.keyedvectors.Vocab at 0x633de4be0>,
#  'kabar': <gensim.models.keyedvectors.Vocab at 0x633de4c18>,
#  'güç': <gensim.models.keyedvectors.Vocab at 0x633de4c50>,
#  'vallahi': <gensim.models.keyedvectors.Vocab at 0x633de4c88>,
#  'yansı': <gensim.models.keyedvectors.Vocab at 0x633de4cc0>,
#  'yak': <gensim.models.keyedvectors.Vocab at 0x633de4cf8>,
#  'ın': <gensim.models.keyedvectors.Vocab at 0x633de4d30>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x633de4d68>,
#  '200': <gensim.models.keyedvectors.Vocab at 0x633de4da0>,
#  'borç': <gensim.models.keyedvectors.Vocab at 0x633de4dd8>,
#  'ciğer': <gensim.models.keyedvectors.Vocab at 0x633de4e10>,
#  'paketı': <gensim.models.keyedvectors.Vocab at 0x633de4e48>,
#  'lı': <gensim.models.keyedvectors.Vocab at 0x633de4e80>,
#  'cüzdan': <gensim.models.keyedvectors.Vocab at 0x633de4eb8>,
#  'hata': <gensim.models.keyedvectors.Vocab at 0x633de4ef0>,
#  'kot': <gensim.models.keyedvectors.Vocab at 0x633de4f28>,
#  'yemek': <gensim.models.keyedvectors.Vocab at 0x633de4f60>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x633de4f98>,
#  'tane': <gensim.models.keyedvectors.Vocab at 0x633de4fd0>,
#  'ajans': <gensim.models.keyedvectors.Vocab at 0x633de8048>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x633de8080>,
#  'harlem': <gensim.models.keyedvectors.Vocab at 0x633de80b8>,
#  'shake': <gensim.models.keyedvectors.Vocab at 0x633de80f0>,
#  'bay': <gensim.models.keyedvectors.Vocab at 0x633de8128>,
#  'reklaminda': <gensim.models.keyedvectors.Vocab at 0x633de8160>,
#  'gencler': <gensim.models.keyedvectors.Vocab at 0x633de8198>,
#  'yuzunden': <gensim.models.keyedvectors.Vocab at 0x633de81d0>,
#  'çıkar': <gensim.models.keyedvectors.Vocab at 0x633de8208>,
#  'bey': <gensim.models.keyedvectors.Vocab at 0x633de8240>,
#  'bedava': <gensim.models.keyedvectors.Vocab at 0x633de8278>,
#  'hakikaten': <gensim.models.keyedvectors.Vocab at 0x633de82b0>,
#  'sarki': <gensim.models.keyedvectors.Vocab at 0x633de82e8>,
#  'anı': <gensim.models.keyedvectors.Vocab at 0x633de8320>,
#  'hayal': <gensim.models.keyedvectors.Vocab at 0x633de8358>,
#  'kur': <gensim.models.keyedvectors.Vocab at 0x633de8390>,
#  'halbuki': <gensim.models.keyedvectors.Vocab at 0x633de83c8>,
#  'vadi': <gensim.models.keyedvectors.Vocab at 0x633de8400>,
#  'ceken': <gensim.models.keyedvectors.Vocab at 0x633de8438>,
#  'arasi': <gensim.models.keyedvectors.Vocab at 0x633de8470>,
#  'deniz': <gensim.models.keyedvectors.Vocab at 0x633de84a8>,
#  'arkadas': <gensim.models.keyedvectors.Vocab at 0x633de84e0>,
#  'ceo': <gensim.models.keyedvectors.Vocab at 0x633de8518>,
#  'rüya': <gensim.models.keyedvectors.Vocab at 0x633de8550>,
#  'ahmedim': <gensim.models.keyedvectors.Vocab at 0x633de8588>,
#  'nerdesin': <gensim.models.keyedvectors.Vocab at 0x633de85c0>,
#  'insallah': <gensim.models.keyedvectors.Vocab at 0x633de85f8>,
#  'hülya': <gensim.models.keyedvectors.Vocab at 0x633de8630>,
#  'koçyiğit': <gensim.models.keyedvectors.Vocab at 0x633de8668>,
#  'li': <gensim.models.keyedvectors.Vocab at 0x633de86a0>,
#  'yahu': <gensim.models.keyedvectors.Vocab at 0x633de86d8>,
#  'dip': <gensim.models.keyedvectors.Vocab at 0x633de8710>,
#  'çay': <gensim.models.keyedvectors.Vocab at 0x633de8748>,
#  'diyosun': <gensim.models.keyedvectors.Vocab at 0x633de8780>,
#  'edicem': <gensim.models.keyedvectors.Vocab at 0x633de87b8>,
#  'tweeti': <gensim.models.keyedvectors.Vocab at 0x633de87f0>,
#  'olmadi': <gensim.models.keyedvectors.Vocab at 0x633de8828>,
#  '250': <gensim.models.keyedvectors.Vocab at 0x633de8860>,
#  'yor': <gensim.models.keyedvectors.Vocab at 0x633de8898>,
#  'tablet': <gensim.models.keyedvectors.Vocab at 0x633de88d0>,
#  'saçmalık': <gensim.models.keyedvectors.Vocab at 0x633de8908>,
#  'nerden': <gensim.models.keyedvectors.Vocab at 0x633de8940>,
#  'yorum': <gensim.models.keyedvectors.Vocab at 0x633de8978>,
#  'çift': <gensim.models.keyedvectors.Vocab at 0x633de89b0>,
#  'genel': <gensim.models.keyedvectors.Vocab at 0x633de89e8>,
#  '2g': <gensim.models.keyedvectors.Vocab at 0x633de8a20>,
#  'herhalde': <gensim.models.keyedvectors.Vocab at 0x633de8a58>,
#  'sayın': <gensim.models.keyedvectors.Vocab at 0x633de8a90>,
#  'mustafa': <gensim.models.keyedvectors.Vocab at 0x633de8ac8>,
#  'sandal': <gensim.models.keyedvectors.Vocab at 0x633de8b00>,
#  'fazla': <gensim.models.keyedvectors.Vocab at 0x633de8b38>,
#  'nasil': <gensim.models.keyedvectors.Vocab at 0x633de8b70>,
#  'belli': <gensim.models.keyedvectors.Vocab at 0x633de8ba8>,
#  'degil': <gensim.models.keyedvectors.Vocab at 0x633de8be0>,
#  'cümle': <gensim.models.keyedvectors.Vocab at 0x633de8c18>,
#  'sahip': <gensim.models.keyedvectors.Vocab at 0x633de8c50>,
#  'çöz': <gensim.models.keyedvectors.Vocab at 0x633de8c88>,
#  'çöp': <gensim.models.keyedvectors.Vocab at 0x633de8cc0>,
#  'ceza': <gensim.models.keyedvectors.Vocab at 0x633de8cf8>,
#  'sev': <gensim.models.keyedvectors.Vocab at 0x633de8d30>,
#  'gir': <gensim.models.keyedvectors.Vocab at 0x633de8d68>,
#  'sağolsun': <gensim.models.keyedvectors.Vocab at 0x633de8da0>,
#  'kampanya': <gensim.models.keyedvectors.Vocab at 0x633de8dd8>,
#  'iphone': <gensim.models.keyedvectors.Vocab at 0x633de8e10>,
#  'ipad': <gensim.models.keyedvectors.Vocab at 0x633de8e48>,
#  'kalp': <gensim.models.keyedvectors.Vocab at 0x633de8e80>,
#  'hasta': <gensim.models.keyedvectors.Vocab at 0x633de8eb8>,
#  'zamanla': <gensim.models.keyedvectors.Vocab at 0x633de8ef0>,
#  'süper': <gensim.models.keyedvectors.Vocab at 0x633de8f28>,
#  'bilgi': <gensim.models.keyedvectors.Vocab at 0x633de8f60>,
#  'imza': <gensim.models.keyedvectors.Vocab at 0x633de8f98>,
#  'sahte': <gensim.models.keyedvectors.Vocab at 0x633de8fd0>,
#  'evrak': <gensim.models.keyedvectors.Vocab at 0x633deb048>,
#  'başvur': <gensim.models.keyedvectors.Vocab at 0x633deb080>,
#  'gunde': <gensim.models.keyedvectors.Vocab at 0x633deb0b8>,
#  'pc': <gensim.models.keyedvectors.Vocab at 0x633deb0f0>,
#  'insaf': <gensim.models.keyedvectors.Vocab at 0x633deb128>,
#  'pahali': <gensim.models.keyedvectors.Vocab at 0x633deb160>,
#  'nere': <gensim.models.keyedvectors.Vocab at 0x633deb198>,
#  'dalga': <gensim.models.keyedvectors.Vocab at 0x633deb1d0>,
#  'beyin': <gensim.models.keyedvectors.Vocab at 0x633deb208>,
#  'yan': <gensim.models.keyedvectors.Vocab at 0x633deb240>,
#  'gsm': <gensim.models.keyedvectors.Vocab at 0x633deb278>,
#  'dönüş': <gensim.models.keyedvectors.Vocab at 0x633deb2b0>,
#  'tercih': <gensim.models.keyedvectors.Vocab at 0x633deb2e8>,
#  'lazım': <gensim.models.keyedvectors.Vocab at 0x633deb320>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x633deb358>,
#  'te': <gensim.models.keyedvectors.Vocab at 0x633deb390>,
#  '4g': <gensim.models.keyedvectors.Vocab at 0x633deb3c8>,
#  'varit': <gensim.models.keyedvectors.Vocab at 0x633deb400>,
#  'dikkat': <gensim.models.keyedvectors.Vocab at 0x633deb438>,
#  'eksik': <gensim.models.keyedvectors.Vocab at 0x633deb470>,
#  'hisse': <gensim.models.keyedvectors.Vocab at 0x633deb4a8>,
#  'sıfır': <gensim.models.keyedvectors.Vocab at 0x633deb4e0>,
#  '1000sms': <gensim.models.keyedvectors.Vocab at 0x633deb518>,
#  'lik': <gensim.models.keyedvectors.Vocab at 0x633deb550>,
#  'paketle': <gensim.models.keyedvectors.Vocab at 0x633deb588>,
#  'merak': <gensim.models.keyedvectors.Vocab at 0x633deb5c0>,
#  'deyim': <gensim.models.keyedvectors.Vocab at 0x633deb5f8>,
#  'tweet': <gensim.models.keyedvectors.Vocab at 0x633deb630>,
#  '60': <gensim.models.keyedvectors.Vocab at 0x633deb668>,
#  'sn': <gensim.models.keyedvectors.Vocab at 0x633deb6a0>,
#  'allahtan': <gensim.models.keyedvectors.Vocab at 0x633deb6d8>,
#  'kork': <gensim.models.keyedvectors.Vocab at 0x633deb710>,
#  'vicdan': <gensim.models.keyedvectors.Vocab at 0x633deb748>,
#  'heryerden': <gensim.models.keyedvectors.Vocab at 0x633deb780>,
#  'ttnetdestek': <gensim.models.keyedvectors.Vocab at 0x633deb7b8>,
#  'arıza': <gensim.models.keyedvectors.Vocab at 0x633deb7f0>,
#  'kayıt': <gensim.models.keyedvectors.Vocab at 0x633deb828>,
#  'sistem': <gensim.models.keyedvectors.Vocab at 0x633deb860>,
#  'güncel': <gensim.models.keyedvectors.Vocab at 0x633deb898>,
#  'açı': <gensim.models.keyedvectors.Vocab at 0x633deb8d0>,
#  'ttnetas': <gensim.models.keyedvectors.Vocab at 0x633deb908>,
#  '90': <gensim.models.keyedvectors.Vocab at 0x633deb940>,
#  'türkiye': <gensim.models.keyedvectors.Vocab at 0x633deb978>,
#  'kapsa': <gensim.models.keyedvectors.Vocab at 0x633deb9b0>,
#  'yaş': <gensim.models.keyedvectors.Vocab at 0x633deb9e8>,
#  'grup': <gensim.models.keyedvectors.Vocab at 0x633deba20>,
#  'oyun': <gensim.models.keyedvectors.Vocab at 0x633deba58>,
#  'efe': <gensim.models.keyedvectors.Vocab at 0x633deba90>,
#  'kıbrıs': <gensim.models.keyedvectors.Vocab at 0x633debac8>,
#  'aşı': <gensim.models.keyedvectors.Vocab at 0x633debb00>,
#  'terbiye': <gensim.models.keyedvectors.Vocab at 0x633debb38>,
#  'maalesef': <gensim.models.keyedvectors.Vocab at 0x633debb70>,
#  'yönlen': <gensim.models.keyedvectors.Vocab at 0x633debba8>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x633debbe0>,
#  'kabul': <gensim.models.keyedvectors.Vocab at 0x633debc18>,
#  'istanbul': <gensim.models.keyedvectors.Vocab at 0x633debc50>,
#  '99': <gensim.models.keyedvectors.Vocab at 0x633debc88>,
#  'alan': <gensim.models.keyedvectors.Vocab at 0x633debcc0>,
#  'uygun': <gensim.models.keyedvectors.Vocab at 0x633debcf8>,
#  'yaklaşık': <gensim.models.keyedvectors.Vocab at 0x633debd30>,
#  'kapalı': <gensim.models.keyedvectors.Vocab at 0x633debd68>,
#  'msj': <gensim.models.keyedvectors.Vocab at 0x633debda0>,
#  'gozunu': <gensim.models.keyedvectors.Vocab at 0x633debdd8>,
#  'cekmiyo': <gensim.models.keyedvectors.Vocab at 0x633debe10>,
#  'yerin': <gensim.models.keyedvectors.Vocab at 0x633debe48>,
#  'kelime': <gensim.models.keyedvectors.Vocab at 0x633debe80>,
#  'boyle': <gensim.models.keyedvectors.Vocab at 0x633debeb8>,
#  'bır': <gensim.models.keyedvectors.Vocab at 0x633debef0>,
#  'operator': <gensim.models.keyedvectors.Vocab at 0x633debf28>,
#  'bimcell': <gensim.models.keyedvectors.Vocab at 0x633debf60>,
#  'internetinin': <gensim.models.keyedvectors.Vocab at 0x633debf98>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x633debfd0>,
#  'daki': <gensim.models.keyedvectors.Vocab at 0x633e80048>,
#  'heralde': <gensim.models.keyedvectors.Vocab at 0x633e80080>,
#  'açma': <gensim.models.keyedvectors.Vocab at 0x633e800b8>,
#  'bahane': <gensim.models.keyedvectors.Vocab at 0x633e800f0>,
#  'sözleş': <gensim.models.keyedvectors.Vocab at 0x633e80128>,
#  'yaz': <gensim.models.keyedvectors.Vocab at 0x633e80160>,
#  'illa': <gensim.models.keyedvectors.Vocab at 0x633e80198>,
#  'hakaret': <gensim.models.keyedvectors.Vocab at 0x633e801d0>,
#  'yüklem': <gensim.models.keyedvectors.Vocab at 0x633e80208>,
#  'onda': <gensim.models.keyedvectors.Vocab at 0x633e80240>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x633e80278>,
#  'internetimiz': <gensim.models.keyedvectors.Vocab at 0x633e802b0>,
#  'slogan': <gensim.models.keyedvectors.Vocab at 0x633e802e8>,
#  'ısrar': <gensim.models.keyedvectors.Vocab at 0x633e80320>,
#  'aktif': <gensim.models.keyedvectors.Vocab at 0x633e80358>,
#  'keşke': <gensim.models.keyedvectors.Vocab at 0x633e80390>,
#  'turkiye': <gensim.models.keyedvectors.Vocab at 0x633e803c8>,
#  'sini': <gensim.models.keyedvectors.Vocab at 0x633e80400>,
#  'soğu': <gensim.models.keyedvectors.Vocab at 0x633e80438>,
#  'karşılaş': <gensim.models.keyedvectors.Vocab at 0x633e80470>,
#  'saniye': <gensim.models.keyedvectors.Vocab at 0x633e804a8>,
#  'dolan': <gensim.models.keyedvectors.Vocab at 0x633e804e0>,
#  'büyük': <gensim.models.keyedvectors.Vocab at 0x633e80518>,
#  'pişman': <gensim.models.keyedvectors.Vocab at 0x633e80550>,
#  'boş': <gensim.models.keyedvectors.Vocab at 0x633e80588>,
#  'ora': <gensim.models.keyedvectors.Vocab at 0x633e805c0>,
#  'geçen': <gensim.models.keyedvectors.Vocab at 0x633e805f8>,
#  'aralık': <gensim.models.keyedvectors.Vocab at 0x633e80630>,
#  'ayı': <gensim.models.keyedvectors.Vocab at 0x633e80668>,
#  'platinum': <gensim.models.keyedvectors.Vocab at 0x633e806a0>,
#  'acil': <gensim.models.keyedvectors.Vocab at 0x633e806d8>,
#  'mobil': <gensim.models.keyedvectors.Vocab at 0x633e80710>,
#  'sırala': <gensim.models.keyedvectors.Vocab at 0x633e80748>,
#  'sim': <gensim.models.keyedvectors.Vocab at 0x633e80780>,
#  'tak': <gensim.models.keyedvectors.Vocab at 0x633e807b8>,
#  'umar': <gensim.models.keyedvectors.Vocab at 0x633e807f0>,
#  'detay': <gensim.models.keyedvectors.Vocab at 0x633e80828>,
#  'bulun': <gensim.models.keyedvectors.Vocab at 0x633e80860>,
#  'memnuniyet': <gensim.models.keyedvectors.Vocab at 0x633e80898>,
#  'hikaye': <gensim.models.keyedvectors.Vocab at 0x633e808d0>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x633e80908>,
#  'söylen': <gensim.models.keyedvectors.Vocab at 0x633e80940>,
#  'şirket': <gensim.models.keyedvectors.Vocab at 0x633e80978>,
#  'amerika': <gensim.models.keyedvectors.Vocab at 0x633e809b0>,
#  'dimi': <gensim.models.keyedvectors.Vocab at 0x633e809e8>,
#  'bölge': <gensim.models.keyedvectors.Vocab at 0x633e80a20>,
#  '01': <gensim.models.keyedvectors.Vocab at 0x633e80a58>,
#  'uyku': <gensim.models.keyedvectors.Vocab at 0x633e80a90>,
#  'dal': <gensim.models.keyedvectors.Vocab at 0x633e80ac8>,
#  'vakit': <gensim.models.keyedvectors.Vocab at 0x633e80b00>,
#  'uyan': <gensim.models.keyedvectors.Vocab at 0x633e80b38>,
#  'teşekkür': <gensim.models.keyedvectors.Vocab at 0x633e80b70>,
#  'fırsat': <gensim.models.keyedvectors.Vocab at 0x633e80ba8>,
#  'aylık': <gensim.models.keyedvectors.Vocab at 0x633e80be0>,
#  'sayfa': <gensim.models.keyedvectors.Vocab at 0x633e80c18>,
#  'yüksek': <gensim.models.keyedvectors.Vocab at 0x633e80c50>,
#  'niyet': <gensim.models.keyedvectors.Vocab at 0x633e80c88>,
#  'hergun': <gensim.models.keyedvectors.Vocab at 0x633e80cc0>,
#  'yil': <gensim.models.keyedvectors.Vocab at 0x633e80cf8>,
#  '2015': <gensim.models.keyedvectors.Vocab at 0x633e80d30>,
#  'malesef': <gensim.models.keyedvectors.Vocab at 0x633e80d68>,
#  'cekim': <gensim.models.keyedvectors.Vocab at 0x633e80da0>,
#  'gucu': <gensim.models.keyedvectors.Vocab at 0x633e80dd8>,
#  'samsung': <gensim.models.keyedvectors.Vocab at 0x633e80e10>,
#  'zorla': <gensim.models.keyedvectors.Vocab at 0x633e80e48>,
#  'deneme': <gensim.models.keyedvectors.Vocab at 0x633e80e80>,
#  'batar': <gensim.models.keyedvectors.Vocab at 0x633e80eb8>,
#  'kapat': <gensim.models.keyedvectors.Vocab at 0x633e80ef0>,
#  'ekran': <gensim.models.keyedvectors.Vocab at 0x633e80f28>,
#  'turkcell4g': <gensim.models.keyedvectors.Vocab at 0x633e80f60>,
#  'geçiş': <gensim.models.keyedvectors.Vocab at 0x633e80f98>,
#  'bahset': <gensim.models.keyedvectors.Vocab at 0x633e80fd0>,
#  'gurur': <gensim.models.keyedvectors.Vocab at 0x633e83048>,
#  'kanser': <gensim.models.keyedvectors.Vocab at 0x633e83080>,
#  'aga': <gensim.models.keyedvectors.Vocab at 0x633e830b8>,
#  'dön': <gensim.models.keyedvectors.Vocab at 0x633e830f0>,
#  'se': <gensim.models.keyedvectors.Vocab at 0x633e83128>,
#  'harika': <gensim.models.keyedvectors.Vocab at 0x633e83160>,
#  'gnctrkcll': <gensim.models.keyedvectors.Vocab at 0x633e83198>,
#  'gerekli': <gensim.models.keyedvectors.Vocab at 0x633e831d0>,
#  'incele': <gensim.models.keyedvectors.Vocab at 0x633e83208>,
#  'itibari': <gensim.models.keyedvectors.Vocab at 0x633e83240>,
#  '45': <gensim.models.keyedvectors.Vocab at 0x633e83278>,
#  'sabır': <gensim.models.keyedvectors.Vocab at 0x633e832b0>,
#  'sınır': <gensim.models.keyedvectors.Vocab at 0x633e832e8>,
#  'aveakullanmıyoruz': <gensim.models.keyedvectors.Vocab at 0x633e83320>,
#  'tcellplatinum': <gensim.models.keyedvectors.Vocab at 0x633e83358>,
#  'tebrik': <gensim.models.keyedvectors.Vocab at 0x633e83390>,
#  'müzik': <gensim.models.keyedvectors.Vocab at 0x633e833c8>,
#  'ileri': <gensim.models.keyedvectors.Vocab at 0x633e83400>,
#  'kesinti': <gensim.models.keyedvectors.Vocab at 0x633e83438>,
#  'çök': <gensim.models.keyedvectors.Vocab at 0x633e83470>,
#  'vay': <gensim.models.keyedvectors.Vocab at 0x633e834a8>,
#  'çanakkale': <gensim.models.keyedvectors.Vocab at 0x633e834e0>,
#  'zar': <gensim.models.keyedvectors.Vocab at 0x633e83518>,
#  'kusur': <gensim.models.keyedvectors.Vocab at 0x633e83550>,
#  'elektrik': <gensim.models.keyedvectors.Vocab at 0x633e83588>,
#  'sebeke': <gensim.models.keyedvectors.Vocab at 0x633e835c0>,
#  'diger': <gensim.models.keyedvectors.Vocab at 0x633e835f8>,
#  'sik': <gensim.models.keyedvectors.Vocab at 0x633e83630>,
#  'fark': <gensim.models.keyedvectors.Vocab at 0x633e83668>,
#  'ler': <gensim.models.keyedvectors.Vocab at 0x633e836a0>,
#  'holding': <gensim.models.keyedvectors.Vocab at 0x633e836d8>,
#  'kurt': <gensim.models.keyedvectors.Vocab at 0x633e83710>,
#  'globalbilgi': <gensim.models.keyedvectors.Vocab at 0x633e83748>,
#  'ciddi': <gensim.models.keyedvectors.Vocab at 0x633e83780>,
#  'sekilde': <gensim.models.keyedvectors.Vocab at 0x633e837b8>,
#  'bulan': <gensim.models.keyedvectors.Vocab at 0x633e837f0>,
#  'bent': <gensim.models.keyedvectors.Vocab at 0x633e83828>,
#  'denizbank': <gensim.models.keyedvectors.Vocab at 0x633e83860>,
#  'şikayet': <gensim.models.keyedvectors.Vocab at 0x633e83898>,
#  'alın': <gensim.models.keyedvectors.Vocab at 0x633e838d0>,
#  'anlam': <gensim.models.keyedvectors.Vocab at 0x633e83908>,
#  'durum': <gensim.models.keyedvectors.Vocab at 0x633e83940>,
#  'müdür': <gensim.models.keyedvectors.Vocab at 0x633e83978>,
#  'yardım': <gensim.models.keyedvectors.Vocab at 0x633e839b0>,
#  'görev': <gensim.models.keyedvectors.Vocab at 0x633e839e8>,
#  'istifa': <gensim.models.keyedvectors.Vocab at 0x633e83a20>,
#  'sayı': <gensim.models.keyedvectors.Vocab at 0x633e83a58>,
#  'çıktı': <gensim.models.keyedvectors.Vocab at 0x633e83a90>,
#  'çıkma': <gensim.models.keyedvectors.Vocab at 0x633e83ac8>,
#  'zahmet': <gensim.models.keyedvectors.Vocab at 0x633e83b00>,
#  'noluyo': <gensim.models.keyedvectors.Vocab at 0x633e83b38>,
#  'devre': <gensim.models.keyedvectors.Vocab at 0x633e83b70>,
#  'disi': <gensim.models.keyedvectors.Vocab at 0x633e83ba8>,
#  'platinium': <gensim.models.keyedvectors.Vocab at 0x633e83be0>,
#  'üye': <gensim.models.keyedvectors.Vocab at 0x633e83c18>,
#  '40': <gensim.models.keyedvectors.Vocab at 0x633e83c50>,
#  'kaybet': <gensim.models.keyedvectors.Vocab at 0x633e83c88>,
#  'anlaş': <gensim.models.keyedvectors.Vocab at 0x633e83cc0>,
#  'samimiyet': <gensim.models.keyedvectors.Vocab at 0x633e83cf8>,
#  'vodafonetr': <gensim.models.keyedvectors.Vocab at 0x633e83d30>,
#  'mağdur': <gensim.models.keyedvectors.Vocab at 0x633e83d68>,
#  'kaan': <gensim.models.keyedvectors.Vocab at 0x633e83da0>,
#  'kaan_terzioglu': <gensim.models.keyedvectors.Vocab at 0x633e83dd8>,
#  'superonlinetr': <gensim.models.keyedvectors.Vocab at 0x633e83e10>,
#  'cidden': <gensim.models.keyedvectors.Vocab at 0x633e83e48>,
#  'kriz': <gensim.models.keyedvectors.Vocab at 0x633e83e80>,
#  'yara': <gensim.models.keyedvectors.Vocab at 0x633e83eb8>,
#  'karı': <gensim.models.keyedvectors.Vocab at 0x633e83ef0>,
#  'azal': <gensim.models.keyedvectors.Vocab at 0x633e83f28>,
#  'cafe': <gensim.models.keyedvectors.Vocab at 0x633e83f60>,
#  'aracı': <gensim.models.keyedvectors.Vocab at 0x633e83f98>,
#  'geçin': <gensim.models.keyedvectors.Vocab at 0x633e83fd0>,
#  'işle': <gensim.models.keyedvectors.Vocab at 0x633e87048>,
#  'kayıp': <gensim.models.keyedvectors.Vocab at 0x633e87080>,
#  'yüzde': <gensim.models.keyedvectors.Vocab at 0x633e870b8>,
#  'ayla': <gensim.models.keyedvectors.Vocab at 0x633e870f0>,
#  'üstün': <gensim.models.keyedvectors.Vocab at 0x633e87128>,
#  'cihaz': <gensim.models.keyedvectors.Vocab at 0x633e87160>,
#  'hizli': <gensim.models.keyedvectors.Vocab at 0x633e87198>,
#  'farki': <gensim.models.keyedvectors.Vocab at 0x633e871d0>,
#  'kabus': <gensim.models.keyedvectors.Vocab at 0x633e87208>,
#  'vodafon': <gensim.models.keyedvectors.Vocab at 0x633e87240>,
#  'fenerbahçe': <gensim.models.keyedvectors.Vocab at 0x633e87278>,
#  'beraber': <gensim.models.keyedvectors.Vocab at 0x633e872b0>,
#  'fiber': <gensim.models.keyedvectors.Vocab at 0x633e872e8>,
#  'boykot': <gensim.models.keyedvectors.Vocab at 0x633e87320>,
#  'bağır': <gensim.models.keyedvectors.Vocab at 0x633e87358>,
#  'tüket': <gensim.models.keyedvectors.Vocab at 0x633e87390>,
#  'türkcell': <gensim.models.keyedvectors.Vocab at 0x633e873c8>,
#  'soygun': <gensim.models.keyedvectors.Vocab at 0x633e87400>,
#  'yatak': <gensim.models.keyedvectors.Vocab at 0x633e87438>,
#  'sağ': <gensim.models.keyedvectors.Vocab at 0x633e87470>,
#  'cin': <gensim.models.keyedvectors.Vocab at 0x633e874a8>,
#  'ortak': <gensim.models.keyedvectors.Vocab at 0x633e874e0>,
#  'güya': <gensim.models.keyedvectors.Vocab at 0x633e87518>,
#  'int': <gensim.models.keyedvectors.Vocab at 0x633e87550>,
#  'kala': <gensim.models.keyedvectors.Vocab at 0x633e87588>,
#  'dün': <gensim.models.keyedvectors.Vocab at 0x633e875c0>,
#  'nezt': <gensim.models.keyedvectors.Vocab at 0x633e875f8>,
#  'geber': <gensim.models.keyedvectors.Vocab at 0x633e87630>,
#  'sikayet': <gensim.models.keyedvectors.Vocab at 0x633e87668>,
#  'gobeginde': <gensim.models.keyedvectors.Vocab at 0x633e876a0>,
#  'göster': <gensim.models.keyedvectors.Vocab at 0x633e876d8>,
#  'mahalle': <gensim.models.keyedvectors.Vocab at 0x633e87710>,
#  'vodafona': <gensim.models.keyedvectors.Vocab at 0x633e87748>,
#  'inş': <gensim.models.keyedvectors.Vocab at 0x633e87780>,
#  'öğrenci': <gensim.models.keyedvectors.Vocab at 0x633e877b8>,
#  'beter': <gensim.models.keyedvectors.Vocab at 0x633e877f0>,
#  'dayı': <gensim.models.keyedvectors.Vocab at 0x633e87828>,
#  'burdan': <gensim.models.keyedvectors.Vocab at 0x633e87860>,
#  'sesle': <gensim.models.keyedvectors.Vocab at 0x633e87898>,
#  'zannet': <gensim.models.keyedvectors.Vocab at 0x633e878d0>,
#  ...}

# %%
model.most_similar('turkcell')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('ol', 0.2846031188964844),
#  ('kurt', 0.2792709469795227),
#  ('ver', 0.2715378999710083),
#  ('yap', 0.2708706259727478),
#  ('http', 0.2701042890548706),
#  ('ara', 0.26698189973831177),
#  ('https', 0.26491039991378784),
#  ('uzay', 0.2596946358680725),
#  ('alkisliyorum', 0.24467743933200836),
#  ('kısa', 0.24346014857292175)]

# %%
#to find the vector of a document which is not in training data
test_data = word_tokenize("2".lower())
v1 = model.infer_vector(test_data)
print(test_data)
print("V1_infer", v1)
# Out:
# ['2']
# V1_infer [-0.0658396   0.00154664  0.02480551 -0.06743868  0.04208385 -0.04714711
#  -0.17452891 -0.01235577  0.00375876 -0.03324285  0.03270067  0.05474114
#  -0.09169555 -0.05932066  0.0708919  -0.05236538  0.05560438 -0.01366046
#   0.03248015 -0.10350001 -0.01048315 -0.1171841  -0.02561115  0.05914393
#   0.0650729  -0.07150536  0.08035857  0.071274   -0.01021082  0.02001089
#   0.06207767 -0.01640065 -0.27542648 -0.06176654  0.03634369 -0.07913997
#  -0.03512963 -0.10112834  0.08481842 -0.0294768  -0.13642262  0.05355902
#  -0.04676862  0.09340989  0.03122408  0.04879354 -0.00085117  0.20424935
#  -0.11274365 -0.03550681  0.14094974  0.07018941  0.05713382 -0.01350317
#   0.03761854  0.04132842 -0.0503211   0.09951602 -0.01948802  0.00539477
#   0.02446734 -0.12434271  0.1400659  -0.08675782 -0.00951768  0.140519
#   0.11797898 -0.04553182 -0.03896495  0.07474744 -0.0650594   0.03321582
#  -0.0294863  -0.07953437  0.12629327 -0.00639837  0.10256018  0.00398439
#   0.07784899 -0.00953191 -0.10588035 -0.15284155 -0.04534185  0.04284818
#  -0.01590822 -0.01929448 -0.02793033 -0.14578967 -0.0040481   0.02592679
#  -0.14133489  0.10093248 -0.08372068  0.13895209 -0.00741273 -0.10331675
#  -0.00137825  0.07258558 -0.050457    0.0255363 ]

# %% [markdown]
# ## Load pre-trained model

# %%
#model= Doc2Vec.load("d2vz.model")

# %% [markdown]
# # Run Logistic Regression on vector represenations of words

# %%
def vec_for_learning(model, tagged_docs):
    targets, regressors = zip(*[(doc.tags[0], model.infer_vector(doc.words, steps=20)) for doc in tagged_docs])
    return targets, regressors

# %%
y_train, X_train = vec_for_learning(model, train_tagged_data)
y_test, X_test = vec_for_learning(model, test_tagged_data)

# %%
sentiment = {'olumsuz':0, 'notr':1, 'olumlu':2}
inv_sentiment = {v:k for k, v in sentiment.items()}
inv_sentiment
# Out:
# {0: 'olumsuz', 1: 'notr', 2: 'olumlu'}

# %%
y_train = np.array([sentiment[s] for s in y_train])
y_test = np.array([sentiment[s] for s in y_test])
y_train
# Out:
# array([0, 0, 0, ..., 0, 1, 2])

# %%
y_test
# Out:
# array([0, 0, 0, ..., 1, 1, 2])

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(n_jobs=1, C=1e5)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score

print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Testing accuracy 0.43390222736476713
# Testing F1 score: 0.43095281928906826

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[731, 436, 210],
#        [486, 467, 211],
#        [300, 314, 302]])

# %%
len(y_pred)
# Out:
# 3457

# %% [markdown]
# ## To-Do
#
# Zemberek correct words
