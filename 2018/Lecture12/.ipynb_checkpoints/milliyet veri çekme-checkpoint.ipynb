# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
url = "http://www.milliyet.com.tr/siyaset/"
siyaset = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    siyaset.append(headlines.text.strip())

siyaset = pd.DataFrame(siyaset)

# %%
url = "http://www.milliyet.com.tr/ekonomi/"
ekonomi = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    ekonomi.append(headlines.text.strip())
    
ekonomi = pd.DataFrame(ekonomi)

# %%
url = "http://www.milliyet.com.tr/ekonomi-tumhaberler/?PAGE=2"
epage2 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    epage2.append(headlines.text.strip())

epage2 = pd.DataFrame(epage2)

# %%
url = "http://www.milliyet.com.tr/ekonomi-tumhaberler/?PAGE=3"
epage3 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    epage3.append(headlines.text.strip())

epage3 = pd.DataFrame(epage3)

# %%
url = "http://www.milliyet.com.tr/ekonomi-tumhaberler/?PAGE=4"
epage4 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    epage4.append(headlines.text.strip())
    
epage4 = pd.DataFrame(epage4)

# %%
url = "http://www.milliyet.com.tr/ekonomi-tumhaberler/?PAGE=5"
epage5 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    epage5.append(headlines.text.strip())
    
epage5 = pd.DataFrame(epage5)

# %%
url = "http://www.milliyet.com.tr/dunya/"
dunya = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    dunya.append(headlines.text.strip())
    
dunya=pd.DataFrame(dunya)

# %%
url = "http://www.milliyet.com.tr/gundem/"
gundem = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    gundem.append(headlines.text.strip()) 
    
gundem=pd.DataFrame(gundem)

# %%
url = "http://www.milliyet.com.tr/gundem-tumhaberler/?PAGE=8"
gpage8 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    page8.append(headlines.text.strip()) 

gpage8=pd.DataFrame(gpage8)

# %%
url = "http://www.milliyet.com.tr/gundem-tumhaberler/?PAGE=9"
gpage9 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    page9.append(headlines.text.strip())
    
gpage9=pd.DataFrame(gpage9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-235-283f3658d23b> in <module>
#       3 page = BeautifulSoup(requests.get(url).text, "lxml")
#       4 for headlines in page.find_all("strong"):
# ----> 5     page9.append(headlines.text.strip())
#       6
#       7 gpage9=pd.DataFrame(gpage9)
#
# NameError: name 'page9' is not defined

# %%
url = "http://www.milliyet.com.tr/gundem-tumhaberler/?PAGE=10"
gpage10 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    gpage10.append(headlines.text.strip())
    
gpage10=pd.DataFrame(gpage10)

# %%
url = "http://www.milliyet.com.tr/gundem-tumhaberler/?PAGE=11"
gpage11 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    gpage11.append(headlines.text.strip())
    
gpage11=pd.DataFrame(gpage11)

# %%
url = "http://www.milliyet.com.tr/gundem-tumhaberler/?PAGE=12"
gpage12 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    gpage12.append(headlines.text.strip())
    
gpage12=pd.DataFrame(gpage12)

# %%
url = "http://www.milliyet.com.tr/gundem-tumhaberler/?PAGE=13"
gpage13 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    gpage13.append(headlines.text.strip())

gpage13=pd.DataFrame(gpage13)

# %%
url = "http://www.milliyet.com.tr/siyaset-tumhaberler/?PAGE=4"
spage4 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    spage4.append(headlines.text.strip())

spage4=pd.DataFrame(spage4)

# %%
url = "http://www.milliyet.com.tr/siyaset-tumhaberler/?PAGE=5"
spage5 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    spage5.append(headlines.text.strip())

spage5=pd.DataFrame(spage5)

# %%
url = "http://www.milliyet.com.tr/siyaset-tumhaberler/?PAGE=6"
spage6 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    spage6.append(headlines.text.strip())
    
    
spage6=pd.DataFrame(spage6)

# %%
url = "http://www.milliyet.com.tr/dunya-tumhaberler/?PAGE=3"
dpage3 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    dpage3.append(headlines.text.strip()
                  
dpage3=pd.DataFrame(dpage3)
# Out:
#   File "<ipython-input-244-b3bf89428e15>", line 7
#     dpage3=pd.DataFrame(dpage3)
#          ^
# SyntaxError: invalid syntax

# %%
url = "http://www.milliyet.com.tr/dunya-tumhaberler/?PAGE=5"
dpage5 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    dpage5.append(headlines.text.strip())
    
dpage5=pd.DataFrame(dpage5)

# %%
url = "http://www.milliyet.com.tr/dunya-tumhaberler/?PAGE=6"
dpage6 = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("strong"):
    dpage6.append(headlines.text.strip())
    
dpage6=pd.DataFrame(dpage6)

# %%
milliyetdata=pd.concat([dpage6, dpage5,spage6,spage5,spage4,gpage13,gpage12,gpage11,gpage10,gpage8,gundem,dunya,epage5,epage4,epage3,epage2,ekonomi,siyaset], axis=0)

# %%
milliyetdata['label'] = 1
milliyetdata.columns = ["Basliklar", "label"]

# %%
milliyetdata
# Out:
#                                             Basliklar  label
# 0                         'UFO yıldırımla şarj oldu!'      1
# 1      İran'da yüzlerce üst düzey yetkili istifa etti      1
# 2              Mısır'da tekne battı: 5 ölü, 20 yaralı      1
# 3   Savaşın ayak sesleri! Rus savaş uçakları haval...      1
# 4               Batan Güneş'in doğması iki ay sürecek      1
# 5   Son dakika... AB liderleri, Brexit anlaşmasını...      1
# 6                Süpermarkette çok fena yakalandılar!      1
# 7                      Lise öğrencileri uçak kaçırdı!      1
# 8                     Gölden feci görüntüler geliyor!      1
# 9                      Arap Prensler partide dağıttı!      1
# 10                       Trump açık açık tehdit etti!      1
# 11  4 bin yıllık mezar bulundu! Kimin olduğu ortay...      1
# 12  Rusya'dan çok konuşulacak Kırım hamlesi! Buray...      1
# 13  ABD Senatosu harekete geçti! Suudi Arabistan i...      1
# ...

# %%
milliyetdata.to_excel("MilliyetData.xlsx",encoding="UTF-16")

# %%
url = "http://www.zaytung.com/index.asp"
genel = []
page = BeautifulSoup(requests.get(url).text, "lxml")
for headlines in page.find_all("h3"):
    genel.append(headlines.text.strip())

# %%
genel = pd.DataFrame(genel)

# %%
zaytungdata = genel
zaytungdata['label'] = 0
zaytungdata.columns = ["Basliklar", "label"]

# %%
zaytungdata.to_excel("Zaytungdata.xlsx",encoding="UTF-16")

# %%
zaytungdata
# Out:
#                                              Basliklar  label
# 0    Cumhurbaşkanı Erdoğan: ''Halbuki bir Beyoğlu, ...      0
# 1    Türkiye de Mars'a insan yollamak için çalışmal...      0
# 2    FIFA, Hakem Tartışmalarına Son Vermek İçin Dev...      0
# 3    Bakan Albayrak: ''Devletin kasası tarihinde be...      0
# 4    İşsizleri Tanıma, Koruma ve Hayata Bağlama Reh...      0
# 5    Fantastik Canavarlar: Grindelwald'ın Suçları (...      0
# 6    Millet kıraathanelerinde unutulmaya yüz tutmuş...      0
# 7    Enflasyonla mücadelede bir sonraki adım ne olsun?      0
# 8    Kapital 3. Cilt'ten, Aşiretler Raporu'na... 14...      0
# 9    ''Amaaan şimdi eve gidip kim yemek yapacak?'' ...      0
# 10         Yeni Türk Yapımı Oyun Geliyor : Future Army      0
# 11   Tek-tip ve Bedelli Askerlikle İlgili Gerçekten...      0
# 12   Dışişleri Bakanlığı: ''Rusya ile Ukrayna arası...      0
# 13   Hiçbir Yerde Soğan Kuyruğu Görmemesine Rağmen ...      0
# ...
