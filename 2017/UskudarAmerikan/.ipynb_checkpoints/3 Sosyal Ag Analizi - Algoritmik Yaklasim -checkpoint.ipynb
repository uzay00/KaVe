# %% [markdown]
# # Sosyal Ag Analizi III - Algoritmik Yaklasim
#
# > Bu calisma Uzay Cetin tarafindan, Uskudar Amerikan Lisesi CodeFest 2018 (https://www.codefesttr.org) icin hazirlanmistir.
#
# NetworkX version: 2.0 gereklidir.
#
# ---
#
# Su sorulara cevap vermek istiyoruz
#
#  - Networkte bir mesajin/virusun yayilmasi ne kadar surer?
#  - A'dan B'ye en kisa yol nedir?
#
# ## Breadth First Search Algoritmasi
#
# <video controls src="https://algs4.cs.princeton.edu/lectures/41DemoBreadthFirstSearch.mov" />

# %%
import warnings
warnings.filterwarnings('ignore')

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G = nx.Graph() # empty graph
G.add_edge("Leyla","Mecnun")
G.add_edge("Juliet","Romeo")
G.add_edge("Uzay","Mecnun")
G.add_edge("Uzay","Romeo")
G.add_edge("Romeo","Mecnun")

nx.draw(G, node_size=1000, node_color='lightblue', with_labels=True)

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 5
# Number of edges: 5
# Average degree:   2.0000

# %%
from queue import *

def BFS(bas, G): 
    kuyruk = Queue()
    kuyruk.put(bas)
    
    goruldu = set()
    goruldu.add(bas)
    
    nerden_geldim = dict()
    while not kuyruk.empty():
        n = kuyruk.get() 
        komsular = list(G.neighbors(n))   
        for k in komsular:
            if k not in goruldu:
                goruldu.add(k)
                kuyruk.put(k)   
                nerden_geldim[k] = n
    return nerden_geldim

# %% [markdown]
# ## Sorular
#
#  - Leyla'dan Juliet'e yol var mi?
#  - Yolu yazar misiniz?

# %%
nerden_geldim = BFS('Leyla', G)
nerden_geldim
# Out:
# {'Juliet': 'Romeo', 'Mecnun': 'Leyla', 'Romeo': 'Mecnun', 'Uzay': 'Mecnun'}

# %%
# 'Mecnun'a 'Leyla'dan geldim
nerden_geldim['Mecnun']
# Out:
# 'Leyla'

# %%
for u, w in nerden_geldim.items():
    print(w, "->", u)
# Out:
# Leyla -> Mecnun
# Mecnun -> Uzay
# Mecnun -> Romeo
# Romeo -> Juliet

# %%
nx.draw(G, node_size=1000, node_color='lightblue', with_labels=True)

# %%
# 'Leyla'dan, 'Juliet'e yol var mi anlamak icin
# 'Juliet'ten baslayip geri geri gidiyoruz, 'Leyla'yi bulana kadar

n = 'Juliet'
yol = [n]
while n != 'Leyla':
    n = nerden_geldim[n]
    yol.append(n)
    print(n)
# Out:
# Romeo
# Mecnun
# Leyla

# %%
yol.reverse()
yol
# Out:
# ['Leyla', 'Mecnun', 'Romeo', 'Juliet']

# %%
def yol(G, bas, son):
    nerden_geldim = BFS(bas, G)
    n = son
    yol = [n]
    while n != bas:
        n = nerden_geldim[n]
        yol.append(n)
    yol.reverse()
    return yol
yol(G, 'Mecnun', 'Juliet')
# Out:
# ['Mecnun', 'Romeo', 'Juliet']

# %% [markdown]
# ## DFS Algortitmasi
#
# <video controls src="https://algs4.cs.princeton.edu/lectures/41DemoDepthFirstSearch.mov" />

# %%
class DFSclass:
    def __init__(self):
        self.nerden_geldim = dict() 
        self.goruldu = set()

    def DFS(self, n, G):     
        self.goruldu.add(n)
        komsular = list(G.neighbors(n))   
        for k in komsular:
            if k not in self.goruldu:  
                self.nerden_geldim[k] = n
                self.DFS(k, G)

# %%
d = DFSclass()
d.DFS('Leyla', G)
d.nerden_geldim
# Out:
# {'Juliet': 'Romeo', 'Mecnun': 'Leyla', 'Romeo': 'Uzay', 'Uzay': 'Mecnun'}

# %%
d.goruldu
# Out:
# {'Juliet', 'Leyla', 'Mecnun', 'Romeo', 'Uzay'}

# %% [markdown]
# ## Agirlik Ekleme ve Dijkstra Algoritmasi
#
# [Dijkstra Algoritmasi](https://algs4.cs.princeton.edu/lectures/44DemoDijkstra.pdf)

# %%
G = nx.DiGraph()
G.add_edge("Istanbul", "Ankara", weight = "450")
G.add_edge("Istanbul", "Izmir", weight = "472")
G.add_edge("Izmir", "Antalya", weight = "457")
G.add_edge("Ankara", "Antalya", weight = "451")
G.add_edge("Ankara", "Hatay", weight = "454")
G.add_edge("Antalya", "Hatay", weight = "783")

G.add_edge("Izmir", "Hatay", weight = "1")

pos_fr = nx.circular_layout(G)
nx.draw(G, pos=pos_fr, node_size=1000, node_color='lightblue', with_labels=True)
nx.draw_networkx_edge_labels(G,pos=pos_fr, edge_labels=nx.get_edge_attributes(G, 'weight'))
plt.tight_layout()

# %%
list(G.neighbors('Ankara'))
# Out:
# ['Antalya', 'Hatay']

# %%
list(G.edges(data = True))
# Out:
# [('Istanbul', 'Ankara', {'weight': '450'}),
#  ('Istanbul', 'Izmir', {'weight': '472'}),
#  ('Ankara', 'Antalya', {'weight': '451'}),
#  ('Ankara', 'Hatay', {'weight': '454'}),
#  ('Izmir', 'Antalya', {'weight': '457'}),
#  ('Izmir', 'Hatay', {'weight': '1'}),
#  ('Antalya', 'Hatay', {'weight': '783'})]

# %%
int(G['Antalya']['Hatay']['weight'])
# Out:
# 783

# %%
G['Antalya']['Hatay']
# Out:
# {'weight': '783'}

# %%
from heapq import *

def dijkstra(G, s, t):
    q = [] # Priority Queue
    path = ()
    heappush(q, (0, s, path))
    seen = set()
    while q:
        (cost,v1,path) = heappop(q)
        if v1 not in seen:
            seen.add(v1)
            path = (v1, path)
            if v1 == t: 
                return (cost, path)
            
            for v2 in list(G.neighbors(v1)) :
                c = int(G[v1][v2]['weight'])
                if v2 not in seen:
                    heappush(q, (cost+c, v2, path))

    return float("inf")

# %%
dijkstra(G, 'Istanbul', 'Hatay')
# Out:
# (473, ('Hatay', ('Izmir', ('Istanbul', ()))))

# %%
q = [] # Priority Queue
s = 'Ist'
heappush(q, (s, 0))# KEY: distance(0) and VALUE: node(s)
heappush(q, (s, 2))
heappop(q)
# Out:
# ('Ist', 0)

# %%
q != []
# Out:
# True

# %%
import numpy as np
from heapq import *

def my_dijkstra(G, s, t):  
    """Write Lazy Dijkstra Algorithm"""
    pq, edgeTo, distTo = [], dict(), {n:float("inf") for n in G.nodes()}
    # initially distance to every vertex is +inf, except source vertex s
    distTo[s] = 0
    heappush(pq, (distTo[s], s)) # Add vertex v to priority queue with priority distTo[v]
    while pq: # while queue is not empty
        cost, v1 = heappop(pq) # pop a vertex
        if v1 == t: return (cost, edgeTo) # if target is reached stop
        for v2 in list(G.neighbors(v1)) : # if not, relax every edge to all neighbors
            c = int(G[v1][v2]['weight'])
            if cost+c < distTo[v2]:
                distTo[v2] = cost+c
                heappush(pq, (distTo[v2], v2))
                edgeTo[v2] = v1

    return float("inf")

# %%
cost, edgeTo = my_dijkstra(G, 'Istanbul', 'Hatay')
print(cost)
edgeTo
# Out:
# 473
# {'Ankara': 'Istanbul',
#  'Antalya': 'Ankara',
#  'Hatay': 'Izmir',
#  'Izmir': 'Istanbul'}

# %%
import numpy as np
from heapq import *

def myDijkstra(G, s, t):    
    """Write Lazy Dijkstra Algorithm"""
    pq, edgeTo, distTo = [], dict(), {n:float("inf") for n in G.nodes()}
    
    distTo[s] = 0 # initially distance to every vertex is +inf, except source vertex s
    for v2 in list(G.neighbors(s)):
        distTo[v2] = int(G[s][v2]['weight'])
        heappush(pq, ((s,v2), distTo[v2])) # add edge (s,v2) to priprity queue with priority distTo[v2]
        edgeTo[v2] = s
            
    while pq: # while queue is not empty
        ((v1,v2), cost) = heappop(pq) # pop an edge
        if v2 == t: return (cost, edgeTo) # if target is reached stop
        for v3 in list(G.neighbors(v2)): # if not, relax every edge pointing from v2
            c = int(G[v2][v3]['weight'])
            if cost+c < distTo[v3]: # Edge relaxation
                distTo[v3] = cost+c
                heappush(pq, ((v2,v3), distTo[v3]))
                edgeTo[v3] = v2 # store from where you come to v3

    return float("inf")

# %%
cost, edgeTo = myDijkstra(G, 'Istanbul', 'Hatay')
cost
# Out:
# 904

# %%
edgeTo
# Out:
# {'Ankara': 'Istanbul',
#  'Antalya': 'Ankara',
#  'Hatay': 'Ankara',
#  'Izmir': 'Istanbul'}

# %%
s, t = 'Istanbul', 'Hatay'
path = []

path.append(t)
print(t)

print(edgeTo[t])
t = edgeTo[t]
path.append(t)

print(edgeTo[t])
t = edgeTo[t]
path.append(t)
# Out:
# Hatay
# Ankara
# Istanbul

# %%
path
# Out:
# ['Hatay', 'Ankara', 'Istanbul']

# %%
s, t = 'Istanbul', 'Hatay'
def getPathFromEdgeTo(s, t, edgeTo):
    path = []
    while t != s:
        path.append(t)
        t = edgeTo[t]
    path.append(t)
    return list(reversed(path))
path = getPathFromEdgeTo(s, t, edgeTo)
path
# Out:
# ['Istanbul', 'Ankara', 'Hatay']
