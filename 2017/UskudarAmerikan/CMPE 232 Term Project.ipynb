# %% [markdown]
# # Term Project

# %%
import warnings
warnings.filterwarnings('ignore')

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G = nx.DiGraph()
G.add_edge("Istanbul", "Ankara", weight = "450")
G.add_edge("Istanbul", "Izmir", weight = "472")
G.add_edge("Izmir", "Antalya", weight = "457")
G.add_edge("Ankara", "Antalya", weight = "451")
G.add_edge("Ankara", "Hatay", weight = "454")
G.add_edge("Antalya", "Hatay", weight = "783")

G.add_edge("Izmir", "Hatay", weight = "1")

pos_fr = nx.circular_layout(G)
nx.draw(G, pos=pos_fr, node_size=1000, node_color='lightblue', with_labels=True)
nx.draw_networkx_edge_labels(G,pos=pos_fr, edge_labels=nx.get_edge_attributes(G, 'weight'))
plt.tight_layout()

print(nx.info(G))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 5
# Number of edges: 7
# Average in degree:   1.4000
# Average out degree:   1.4000

# %% [markdown]
# # Find Shortest Paths
#
# [Dijkstra Algorithm](https://algs4.cs.princeton.edu/lectures/44DemoDijkstra.pdf)

# %%
import numpy as np
from heapq import *

def my_dijkstra(G, s, t):  
    """Write Lazy Dijkstra Algorithm"""
    pq, edgeTo, distTo = [], dict(), {n:float("inf") for n in G.nodes()}
    # initially distance to every vertex is +inf, except source vertex s
    distTo[s] = 0
    heappush(pq, (distTo[s], s)) # Add vertex v to priority queue with priority distTo[v]
    while pq: # while queue is not empty
        cost, v1 = heappop(pq) # pop a vertex
        if v1 == t: return (cost, edgeTo) # if target is reached stop
        for v2 in list(G.neighbors(v1)) : # if not, relax every edge to all neighbors
            c = int(G[v1][v2]['weight'])
            if cost+c < distTo[v2]:
                distTo[v2] = cost+c # Edge relaxation
                heappush(pq, (distTo[v2], v2))
                edgeTo[v2] = v1 # store from where you come to v3

    return (float("inf"), edgeTo)

def getPathFromEdgeTo(s, t, edgeTo):
    path = []
    while t != s:
        path.append(t)
        t = edgeTo[t]
    path.append(t)
    return list(reversed(path))


def findAllShortestPaths(G, display = False):
    sp = dict()
    for s in G.nodes():
        for t in G.nodes():
            if s != t:
                cost, edgeTo = my_dijkstra(G, s, t)
                if cost != float("inf"):
                    path = getPathFromEdgeTo(s, t, edgeTo)
                    sp[(s,t)] = (path, cost)
                else:
                    if display: print("INF (No Way Out): ", s, t)
    return sp


def getEdgesFromPath(path):
    return list(zip(path[:-1], path[1:]))


def numberOfShortestPaths_PassingThroughEdges(G):
    sp = findAllShortestPaths(G)
    onsp =dict()
    for path, cost in sp.values():
        for edges in getEdgesFromPath(path):
            if edges in onsp: 
                onsp[edges] += 1
            else:
                onsp[edges] = 1
    return onsp


def getEdgeWithMaxSP(G):
    onsp = numberOfShortestPaths_PassingThroughEdges(G)
    return max(onsp, key=lambda i: onsp[i])


def draw(G):
    plt.figure(figsize=(15,15))
    B = list(nx.betweenness_centrality(G).values())
    nx.draw(G, node_size=B,
            alpha = 0.7,
            node_color = B,
            cmap = plt.cm.Blues,
            with_labels=True)

# %%
s, t = 'Istanbul', 'Hatay'
cost, edgeTo = my_dijkstra(G, s,t)
path = getPathFromEdgeTo(s, t, edgeTo)

print('\nPath from ', s, ' to ', t, ' has cost ', cost,'\n\tPath >>> ', path)
edgeTo
# Out:
# Path from  Istanbul  to  Hatay  has cost  473
# 	Path >>>  ['Istanbul', 'Izmir', 'Hatay']
# {'Ankara': 'Istanbul',
#  'Antalya': 'Ankara',
#  'Hatay': 'Izmir',
#  'Izmir': 'Istanbul'}

# %%
nx.shortest_path(G, s,t, weight=True)
# Out:
# ['Istanbul', 'Ankara', 'Hatay']

# %%
findAllShortestPaths(G)
# Out:
# INF (No Way Out):  Ankara Istanbul
# INF (No Way Out):  Ankara Izmir
# INF (No Way Out):  Izmir Istanbul
# INF (No Way Out):  Izmir Ankara
# INF (No Way Out):  Antalya Istanbul
# INF (No Way Out):  Antalya Ankara
# INF (No Way Out):  Antalya Izmir
# INF (No Way Out):  Hatay Istanbul
# INF (No Way Out):  Hatay Ankara
# INF (No Way Out):  Hatay Izmir
# INF (No Way Out):  Hatay Antalya
# {('Ankara', 'Antalya'): (['Ankara', 'Antalya'], 451),
#  ('Ankara', 'Hatay'): (['Ankara', 'Hatay'], 454),
#  ('Antalya', 'Hatay'): (['Antalya', 'Hatay'], 783),
#  ('Istanbul', 'Ankara'): (['Istanbul', 'Ankara'], 450),
#  ('Istanbul', 'Antalya'): (['Istanbul', 'Ankara', 'Antalya'], 901),
#  ('Istanbul', 'Hatay'): (['Istanbul', 'Izmir', 'Hatay'], 473),
#  ('Istanbul', 'Izmir'): (['Istanbul', 'Izmir'], 472),
#  ('Izmir', 'Antalya'): (['Izmir', 'Antalya'], 457),
#  ('Izmir', 'Hatay'): (['Izmir', 'Hatay'], 1)}

# %% [markdown]
# ## Film Babel
# ![Babel Film](https://img03.imgsinemalar.com/images/afis_buyuk/b/Babil-1294695025.jpg)

# %%
G =nx.read_gexf("babel.gexf", relabel= True)
draw(G)

# %% [markdown]
# ## Find all Shortest Paths for Babel Movie

# %%
sp = findAllShortestPaths(G)

# %%
path, cost = sp[('REPORTER', 'HARUKI')]
path, cost
# Out:
# (['REPORTER', 'KENJI', 'YASUJIRO', 'CHIEKO', 'HARUKI'], 4)

# %%
getEdgesFromPath(path)
# Out:
# [('REPORTER', 'KENJI'),
#  ('KENJI', 'YASUJIRO'),
#  ('YASUJIRO', 'CHIEKO'),
#  ('CHIEKO', 'HARUKI')]

# %%
onsp = numberOfShortestPaths_PassingThroughEdges(G)
onsp
# Out:
# {('ABDULLAH', 'AHMED'): 1,
#  ('ABDULLAH', 'ALARID'): 4,
#  ('ABDULLAH', 'HASSAN'): 2,
#  ('ABDULLAH', 'POLICE OFFICER'): 124,
#  ('ABDULLAH', 'YASIRA'): 1,
#  ('ABDULLAH', 'ZORA'): 64,
#  ('AHMED', 'ABDULLAH'): 1,
#  ('AHMED', 'HASSAN'): 66,
#  ('AHMED', 'YASIRA'): 2,
#  ('AHMED', 'ZORA'): 1,
#  ('ALARID', 'ABDULLAH'): 90,
#  ('ALARID', 'HASSAN'): 180,
#  ('ALARID', 'OLD MAN'): 54,
#  ('ALARID', 'POLICE OFFICER'): 19,
#  ('ALARID', 'WIFE'): 2,
#  ('ALARID', 'YUSSEF'): 2,
#  ('AMELIA', 'COMADRE 1'): 134,
#  ('AMELIA', 'DAUGHTER 1'): 69,
#  ('AMELIA', 'ELISEO'): 69,
#  ('AMELIA', 'GUITAR PLAYER'): 69,
#  ('AMELIA', 'JACINTO'): 69,
#  ('AMELIA', 'JOHN'): 69,
#  ('AMELIA', 'LUCIA'): 70,
#  ('AMELIA', 'MADRE'): 67,
#  ('AMELIA', 'MOTHER'): 70,
#  ('AMELIA', 'OFFICER'): 120,
#  ('AMELIA', 'PATRICIA'): 67,
#  ('AMELIA', 'POLICE OFFICER'): 287,
#  ('AMELIA', 'RICHARD'): 1090,
#  ('AMELIA', 'WOMAN'): 70,
#  ('ANWAR', "ANWAR'S GRANDMOTHER"): 16,
#  ('ANWAR', 'DOCTOR'): 15,
#  ('ANWAR', 'DOUGLAS'): 64,
#  ('ANWAR', 'JAMES'): 7,
#  ('ANWAR', 'LILLY'): 29,
#  ('ANWAR', 'MOHAMMED'): 50,
#  ('ANWAR', 'POLICEMAN'): 9,
#  ('ANWAR', 'RACHEL'): 28,
#  ('ANWAR', 'SHEIK'): 18,
#  ('ANWAR', 'TENDERO'): 31,
#  ('ANWAR', 'TOM'): 7,
#  ("ANWAR'S GRANDMOTHER", 'ANWAR'): 16,
#  ("ANWAR'S GRANDMOTHER", 'DOCTOR'): 2,
#  ("ANWAR'S GRANDMOTHER", 'RICHARD'): 52,
#  ('BARTENDER', 'KENJI'): 14,
#  ('BARTENDER', 'REPORTER'): 56,
#  ('BARTH', 'RICHARD'): 70,
#  ('CHIEKO', 'HARUKI'): 68,
#  ('CHIEKO', 'HOSTESS'): 69,
#  ('CHIEKO', 'KUMIKO'): 68,
#  ('CHIEKO', 'MITSU'): 67,
#  ('CHIEKO', 'REFEREE'): 69,
#  ('CHIEKO', 'TEAMMATE'): 69,
#  ('CHIEKO', 'TEAMMATE 1'): 69,
#  ('CHIEKO', 'TEAMMATE 2'): 69,
#  ('CHIEKO', 'YASUJIRO'): 610,
#  ('CHIEKO', 'YOUNG MAN'): 70,
#  ('COMADRE 1', 'AMELIA'): 190,
#  ('COMADRE 1', 'LUIS'): 61,
#  ('COMADRE 1', 'SANTIAGO'): 9,
#  ('COP', 'HASSAN'): 70,
#  ('DAUGHTER 1', 'AMELIA'): 66,
#  ('DAUGHTER 1', 'SANTIAGO'): 4,
#  ('DEBBIE', 'OFFICER'): 56,
#  ('DEBBIE', 'POLICE OFFICER'): 12,
#  ('DEBBIE', 'SANTIAGO'): 12,
#  ('DOCTOR', 'ANWAR'): 15,
#  ('DOCTOR', "ANWAR'S GRANDMOTHER"): 2,
#  ('DOCTOR', 'RICHARD'): 51,
#  ('DOCTOR', 'SUSAN'): 4,
#  ('DOORMAN', 'HAMANO'): 12,
#  ('DOORMAN', 'KENJI'): 58,
#  ('DOORMAN', 'YASUJIRO'): 22,
#  ('DOUGLAS', 'ANWAR'): 64,
#  ('DOUGLAS', 'JAMES'): 2,
#  ('DOUGLAS', 'LILLY'): 3,
#  ('DOUGLAS', 'RICHARD'): 101,
#  ('DOUGLAS', 'TOM'): 1,
#  ('DOUGLAS', 'WALTER'): 3,
#  ('DRIVER', 'JANE'): 1,
#  ('DRIVER', 'LILLY'): 62,
#  ('DRIVER', 'TOM'): 7,
#  ('ELISEO', 'AMELIA'): 69,
#  ('ELISEO', 'JOHN'): 1,
#  ('FRIEND 1', 'FRIEND 2'): 1,
#  ('FRIEND 1', 'FRIEND 3'): 1,
#  ('FRIEND 1', 'MOHAMMED'): 67,
#  ('FRIEND 1', 'NEWSCASTER'): 1,
#  ('FRIEND 2', 'FRIEND 1'): 1,
#  ('FRIEND 2', 'FRIEND 3'): 1,
#  ('FRIEND 2', 'MOHAMMED'): 67,
#  ('FRIEND 2', 'NEWSCASTER'): 1,
#  ('FRIEND 3', 'FRIEND 1'): 1,
#  ('FRIEND 3', 'FRIEND 2'): 1,
#  ('FRIEND 3', 'MOHAMMED'): 67,
#  ('FRIEND 3', 'NEWSCASTER'): 1,
#  ('GUITAR PLAYER', 'AMELIA'): 68,
#  ('GUITAR PLAYER', 'LUIS'): 2,
#  ('HAMANO', 'DOORMAN'): 12,
#  ('HAMANO', 'KENJI'): 58,
#  ('HARUKI', 'CHIEKO'): 68,
#  ('HARUKI', 'KUMIKO'): 1,
#  ('HARUKI', 'MITSU'): 1,
#  ('HASSAN', 'ABDULLAH'): 2,
#  ('HASSAN', 'AHMED'): 67,
#  ('HASSAN', 'ALARID'): 8,
#  ('HASSAN', 'COP'): 70,
#  ('HASSAN', 'POLICE OFFICER'): 246,
#  ('HASSAN', 'WIFE'): 5,
#  ('HASSAN', 'YASIRA'): 69,
#  ('HOSTESS', 'CHIEKO'): 69,
#  ('HOSTESS', 'MITSU'): 1,
#  ('JACINTO', 'AMELIA'): 66,
#  ('JACINTO', 'SANTIAGO'): 4,
#  ('JAMES', 'ANWAR'): 7,
#  ('JAMES', 'DOUGLAS'): 2,
#  ('JAMES', 'LILLY'): 3,
#  ('JAMES', 'POLICEMAN'): 6,
#  ('JAMES', 'RICHARD'): 51,
#  ('JAMES', 'TOM'): 1,
#  ('JANE', 'DRIVER'): 1,
#  ('JANE', 'LILLY'): 62,
#  ('JANE', 'TOM'): 7,
#  ('JOHN', 'AMELIA'): 69,
#  ('JOHN', 'ELISEO'): 1,
#  ('KEN', 'REPORTER'): 32,
#  ('KEN', 'RICHARD'): 53,
#  ('KEN', 'SECRETARY'): 17,
#  ('KENJI', 'BARTENDER'): 14,
#  ('KENJI', 'DOORMAN'): 58,
#  ('KENJI', 'HAMANO'): 58,
#  ('KENJI', 'REPORTER'): 784,
#  ('KENJI', 'YASUJIRO'): 638,
#  ('KUMIKO', 'CHIEKO'): 68,
#  ('KUMIKO', 'HARUKI'): 1,
#  ('KUMIKO', 'MITSU'): 1,
#  ('LILLY', 'ANWAR'): 30,
#  ('LILLY', 'DOUGLAS'): 3,
#  ('LILLY', 'DRIVER'): 63,
#  ('LILLY', 'JAMES'): 3,
#  ('LILLY', 'JANE'): 63,
#  ('LILLY', 'RICHARD'): 150,
#  ('LILLY', 'TOM'): 1,
#  ('LILLY', 'WALTER'): 3,
#  ('LUCIA', 'AMELIA'): 70,
#  ('LUIS', 'COMADRE 1'): 64,
#  ('LUIS', 'GUITAR PLAYER'): 1,
#  ('LUIS', 'PATRICIA'): 2,
#  ('LUIS', 'SANTIAGO'): 4,
#  ('MADRE', 'AMELIA'): 67,
#  ('MADRE', 'PATRICIA'): 3,
#  ('MARK', 'RACHEL'): 7,
#  ('MARK', 'RICHARD'): 63,
#  ('MIKE', 'POLICE OFFICER'): 24,
#  ('MIKE', 'RICHARD'): 44,
#  ('MIKE', 'SANTIAGO'): 46,
#  ('MITSU', 'CHIEKO'): 67,
#  ('MITSU', 'HARUKI'): 1,
#  ('MITSU', 'HOSTESS'): 1,
#  ('MITSU', 'KUMIKO'): 1,
#  ('MOHAMMED', 'ANWAR'): 50,
#  ('MOHAMMED', 'FRIEND 1'): 67,
#  ('MOHAMMED', 'FRIEND 2'): 67,
#  ('MOHAMMED', 'FRIEND 3'): 67,
#  ('MOHAMMED', 'NEWSCASTER'): 67,
#  ('MOHAMMED', 'POLICEMAN'): 260,
#  ('MOHAMMED', 'TOM'): 20,
#  ('MOROCCAN DOCTOR', 'RICHARD'): 70,
#  ('MOTHER', 'AMELIA'): 70,
#  ('NEWSCASTER', 'FRIEND 1'): 1,
#  ('NEWSCASTER', 'FRIEND 2'): 1,
#  ('NEWSCASTER', 'FRIEND 3'): 1,
#  ('NEWSCASTER', 'MOHAMMED'): 67,
#  ('OFFICER', 'AMELIA'): 121,
#  ('OFFICER', 'DEBBIE'): 53,
#  ('OFFICER', 'SANTIAGO'): 3,
#  ('OLD MAN', 'ALARID'): 311,
#  ('OLD MAN', 'RICHARD'): 103,
#  ('PATRICIA', 'AMELIA'): 65,
#  ('PATRICIA', 'LUIS'): 2,
#  ('PATRICIA', 'MADRE'): 3,
#  ('PATRICIA', 'SANTIAGO'): 4,
#  ('POLICE OFFICER', 'ABDULLAH'): 38,
#  ('POLICE OFFICER', 'ALARID'): 20,
#  ('POLICE OFFICER', 'AMELIA'): 540,
#  ('POLICE OFFICER', 'DEBBIE'): 21,
#  ('POLICE OFFICER', 'HASSAN'): 75,
#  ('POLICE OFFICER', 'MIKE'): 19,
#  ('POLICE OFFICER', 'WIFE'): 63,
#  ('POLICE OFFICER', 'YUSSEF'): 65,
#  ('POLICEMAN', 'ANWAR'): 11,
#  ('POLICEMAN', 'JAMES'): 6,
#  ('POLICEMAN', 'MOHAMMED'): 260,
#  ('POLICEMAN', 'RICHARD'): 302,
#  ('POLICEMAN', 'TOM'): 1,
#  ('RACHEL', 'ANWAR'): 24,
#  ('RACHEL', 'MARK'): 11,
#  ('RACHEL', 'RICHARD'): 51,
#  ('REFEREE', 'CHIEKO'): 69,
#  ('REFEREE', 'TEAMMATE'): 1,
#  ('REPORTER', 'BARTENDER'): 56,
#  ('REPORTER', 'KEN'): 32,
#  ('REPORTER', 'KENJI'): 784,
#  ('REPORTER', 'RICHARD'): 848,
#  ('RICHARD', 'AMELIA'): 789,
#  ('RICHARD', "ANWAR'S GRANDMOTHER"): 52,
#  ('RICHARD', 'BARTH'): 70,
#  ('RICHARD', 'DOCTOR'): 51,
#  ('RICHARD', 'DOUGLAS'): 101,
#  ('RICHARD', 'JAMES'): 51,
#  ('RICHARD', 'KEN'): 53,
#  ('RICHARD', 'LILLY'): 153,
#  ('RICHARD', 'MARK'): 59,
#  ('RICHARD', 'MIKE'): 88,
#  ('RICHARD', 'MOROCCAN DOCTOR'): 70,
#  ('RICHARD', 'OLD MAN'): 360,
#  ('RICHARD', 'POLICEMAN'): 302,
#  ('RICHARD', 'RACHEL'): 51,
#  ('RICHARD', 'REPORTER'): 848,
#  ('RICHARD', 'SECRETARY'): 53,
#  ('RICHARD', 'SHEIK'): 52,
#  ('RICHARD', 'TENDERO'): 103,
#  ('RICHARD', 'TOM'): 51,
#  ('RICHARD', 'WAITER'): 68,
#  ('RICHARD', 'WALTER'): 58,
#  ('SANTIAGO', 'COMADRE 1'): 62,
#  ('SANTIAGO', 'DAUGHTER 1'): 1,
#  ('SANTIAGO', 'DEBBIE'): 6,
#  ('SANTIAGO', 'JACINTO'): 1,
#  ('SANTIAGO', 'LUIS'): 6,
#  ('SANTIAGO', 'MIKE'): 7,
#  ('SANTIAGO', 'OFFICER'): 1,
#  ('SANTIAGO', 'PATRICIA'): 2,
#  ('SECRETARY', 'KEN'): 17,
#  ('SECRETARY', 'RICHARD'): 53,
#  ('SHEIK', 'ANWAR'): 18,
#  ('SHEIK', 'RICHARD'): 52,
#  ('SUSAN', 'DOCTOR'): 4,
#  ('SUSAN', 'TENDERO'): 68,
#  ('SUSAN', 'WAITER'): 2,
#  ('TEAMMATE', 'CHIEKO'): 69,
#  ('TEAMMATE', 'REFEREE'): 1,
#  ('TEAMMATE 1', 'CHIEKO'): 69,
#  ('TEAMMATE 1', 'TEAMMATE 2'): 1,
#  ('TEAMMATE 2', 'CHIEKO'): 69,
#  ('TEAMMATE 2', 'TEAMMATE 1'): 1,
#  ('TENDERO', 'ANWAR'): 31,
#  ('TENDERO', 'RICHARD'): 103,
#  ('TENDERO', 'SUSAN'): 68,
#  ('TOM', 'ANWAR'): 8,
#  ('TOM', 'DOUGLAS'): 1,
#  ('TOM', 'DRIVER'): 6,
#  ('TOM', 'JAMES'): 1,
#  ('TOM', 'JANE'): 6,
#  ('TOM', 'LILLY'): 1,
#  ('TOM', 'MOHAMMED'): 20,
#  ('TOM', 'POLICEMAN'): 3,
#  ('TOM', 'RICHARD'): 50,
#  ('TOM', 'WALTER'): 6,
#  ('WAITER', 'RICHARD'): 68,
#  ('WAITER', 'SUSAN'): 2,
#  ('WALTER', 'DOUGLAS'): 3,
#  ('WALTER', 'LILLY'): 3,
#  ('WALTER', 'RICHARD'): 58,
#  ('WALTER', 'TOM'): 6,
#  ('WIFE', 'ALARID'): 2,
#  ('WIFE', 'HASSAN'): 5,
#  ('WIFE', 'POLICE OFFICER'): 63,
#  ('WOMAN', 'AMELIA'): 70,
#  ('YASIRA', 'ABDULLAH'): 1,
#  ('YASIRA', 'AHMED'): 1,
#  ('YASIRA', 'HASSAN'): 69,
#  ('YASIRA', 'YUSSEF'): 2,
#  ('YASIRA', 'ZORA'): 4,
#  ('YASUJIRO', 'CHIEKO'): 610,
#  ('YASUJIRO', 'DOORMAN'): 22,
#  ('YASUJIRO', 'KENJI'): 638,
#  ('YOUNG MAN', 'CHIEKO'): 70,
#  ('YUSSEF', 'ALARID'): 2,
#  ('YUSSEF', 'POLICE OFFICER'): 66,
#  ('YUSSEF', 'YASIRA'): 1,
#  ('YUSSEF', 'ZORA'): 1,
#  ('ZORA', 'ABDULLAH'): 64,
#  ('ZORA', 'AHMED'): 1,
#  ('ZORA', 'YASIRA'): 4,
#  ('ZORA', 'YUSSEF'): 1}

# %%
max(onsp, key=lambda i: onsp[i])
# Out:
# ('AMELIA', 'RICHARD')

# %%
e = getEdgeWithMaxSP(G)
e
# Out:
# ('AMELIA', 'RICHARD')

# %%
G.remove_edge(*e)

# %%
draw(G)

# %%
G =nx.read_gexf("babel.gexf", relabel= True)
for i in range(10):
    e = getEdgeWithMaxSP(G)
    G.remove_edge(*e)
draw(G)
