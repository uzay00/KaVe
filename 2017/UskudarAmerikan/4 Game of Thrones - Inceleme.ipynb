# %% [markdown]
# # 4 Game of Thrones - Inceleme
#
# [Google'da karakter aramalari](https://trends.google.com.tr/trends/explore?date=today%205-y&q=Eddard%20Stark,%2Fm%2F02yxj7t,%2Fm%2F02ntqy8,%2Fm%2F02ntqy0)
#
#
# 5 adet kitabin verisine [adresinden](https://github.com/mathbeveridge/asoiaf/tree/master/data) ulasilabilir.
#
# > This is an interaction network and were created by connecting two characters whenever their names (or nicknames) appeared within 15 words of one another in one of the books. The edge weight corresponds to the number of interactions.

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import community

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
kitap1 = pd.read_csv('https://raw.githubusercontent.com/mathbeveridge/asoiaf/master/data/asoiaf-book1-edges.csv')
kitap2 = pd.read_csv('https://raw.githubusercontent.com/mathbeveridge/asoiaf/master/data/asoiaf-book2-edges.csv')
kitap3 = pd.read_csv('https://raw.githubusercontent.com/mathbeveridge/asoiaf/master/data/asoiaf-book3-edges.csv')
kitap4 = pd.read_csv('https://raw.githubusercontent.com/mathbeveridge/asoiaf/master/data/asoiaf-book4-edges.csv')
kitap5 = pd.read_csv('https://raw.githubusercontent.com/mathbeveridge/asoiaf/master/data/asoiaf-book5-edges.csv')

# %%
kitap1.head()
# Out:
#                             Source              Target        Type  weight  \
# 0                   Addam-Marbrand     Jaime-Lannister  Undirected       3
# 1                   Addam-Marbrand     Tywin-Lannister  Undirected       6
# 2                Aegon-I-Targaryen  Daenerys-Targaryen  Undirected       5
# 3                Aegon-I-Targaryen        Eddard-Stark  Undirected       4
# 4  Aemon-Targaryen-(Maester-Aemon)      Alliser-Thorne  Undirected       4
#
#    book
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
kitap1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 684 entries, 0 to 683
# Data columns (total 5 columns):
# Source    684 non-null object
# Target    684 non-null object
# Type      684 non-null object
# weight    684 non-null int64
# book      684 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 26.8+ KB

# %%
len(kitap1)
# Out:
# 684

# %%
kitap1.Source[0:3]
# Out:
# 0       Addam-Marbrand
# 1       Addam-Marbrand
# 2    Aegon-I-Targaryen
# Name: Source, dtype: object

# %%
G1 = nx.Graph(name='Kitap 1') 
for i in range(len(kitap1)):
    G1.add_edge(kitap1.Source[i], kitap1.Target[i],  weight= kitap1.weight[i])

# %%
plt.figure(figsize=(24, 24))
pos2=nx.spring_layout(G1,scale=1) 
nx.draw(G1, pos=pos2, node_size=1000, node_color='lightblue', with_labels=True)
plt.title("Kitap 1 - Game of Thrones")
# Out:
# Text(0.5,1,'Kitap 1 - Game of Thrones')

# %%
sorted(nx.degree_centrality(G1).items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Eddard-Stark', 0.3548387096774194),
#  ('Robert-Baratheon', 0.2688172043010753),
#  ('Tyrion-Lannister', 0.24731182795698928),
#  ('Catelyn-Stark', 0.23118279569892475),
#  ('Jon-Snow', 0.19892473118279572),
#  ('Robb-Stark', 0.18817204301075272),
#  ('Sansa-Stark', 0.18817204301075272),
#  ('Bran-Stark', 0.17204301075268819),
#  ('Cersei-Lannister', 0.16129032258064518),
#  ('Joffrey-Baratheon', 0.16129032258064518)]

# %%
plt.hist(list(nx.degree_centrality(G1).values()))
plt.show()

# %%
sorted(nx.pagerank_numpy(G1, weight=None).items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Eddard-Stark', 0.04552079222830664),
#  ('Tyrion-Lannister', 0.03301362462493269),
#  ('Catelyn-Stark', 0.030193105286631914),
#  ('Robert-Baratheon', 0.029834742227736695),
#  ('Jon-Snow', 0.02683449952206629),
#  ('Robb-Stark', 0.02156294129724754),
#  ('Sansa-Stark', 0.020008034042864633),
#  ('Bran-Stark', 0.019945786786238352),
#  ('Jaime-Lannister', 0.01750784720284688),
#  ('Cersei-Lannister', 0.017082604584758066)]

# %%
sorted(nx.pagerank_numpy(G1, weight='weight').items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Eddard-Stark', 0.07239401100498274),
#  ('Robert-Baratheon', 0.048517275705099575),
#  ('Jon-Snow', 0.04770689062474903),
#  ('Tyrion-Lannister', 0.04367437892706297),
#  ('Catelyn-Stark', 0.03466703470130745),
#  ('Bran-Stark', 0.0297742005398002),
#  ('Robb-Stark', 0.02921618364519686),
#  ('Daenerys-Targaryen', 0.02708962251302111),
#  ('Sansa-Stark', 0.026961778915683167),
#  ('Cersei-Lannister', 0.021631679397419005)]

# %%
#first compute the best partition
partition = community.best_partition(G1)

#drawing
size = float(len(set(partition.values())))
pos = nx.spring_layout(G1)
count = 0.
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys()
                                if partition[nodes] == com]
    nx.draw_networkx_nodes(G1, pos, list_nodes, node_size = 20,
                                node_color = str(count / size))


nx.draw_networkx_edges(G1,pos, alpha=0.5)
plt.show()

## Calismazsa: pip3 install networkx --upgrade ve pip3 install python-louvain --upgrade.

# %%
if partition is not None:
        values = [partition.get(node) for node in G1.nodes()]

plt.figure(figsize=(24, 24))
pos2=nx.spring_layout(G1,scale=1) 
nx.draw_networkx_nodes(G1,pos2,node_size=500,node_color=values, alpha=0.3,cmap = plt.get_cmap('jet'))
nx.draw_networkx_edges(G1,pos2,width=1,alpha=0.5)
nx.draw_networkx_labels(G1,pos2,font_size=18)

plt.title("Kitap 1 - Game of Thrones")
# Out:
# Text(0.5,1,'Kitap 1 - Game of Thrones')

# %%
# If your Graph has more than one component, this will return False:
print(nx.is_connected(G1))

# Next, use nx.connected_components to get the list of components,
# then use the max() command to find the largest one:
components = nx.connected_components(G1)
largest_component = max(components, key=len)

# Create a "subgraph" of just the largest component
# Then calculate the diameter of the subgraph, just like you did with density.
#

subgraph = G1.subgraph(largest_component)
diameter = nx.diameter(subgraph)
print("Network diameter of largest component:", diameter)
# Out:
# True
# Network diameter of largest component: 7

# %% [markdown]
# ## Kendi Community Detection Algoritmamiz

# %%
length, path = nx.single_source_dijkstra(G1, 'Eddard-Stark')
length, path
# Out:
# ({'Addam-Marbrand': 9,
#   'Aegon-I-Targaryen': 4,
#   'Aemon-Targaryen-(Maester-Aemon)': 17,
#   'Aerys-II-Targaryen': 6,
#   'Aggo': 13,
#   'Albett': 15,
#   'Alliser-Thorne': 15,
#   'Alyn': 11,
#   'Arthur-Dayne': 7,
#   'Arya-Stark': 7,
#   'Arys-Oakheart': 11,
#   'Balon-Greyjoy': 3,
#   'Balon-Swann': 11,
#   'Barristan-Selmy': 10,
#   'Benjen-Stark': 9,
#   'Beric-Dondarrion': 3,
#   'Boros-Blount': 11,
#   'Bowen-Marsh': 15,
#   'Bran-Stark': 8,
#   'Brandon-Stark': 10,
#   'Bronn': 10,
#   'Brynden-Tully': 6,
#   'Catelyn-Stark': 7,
#   'Cayn': 7,
#   'Cersei-Lannister': 8,
#   'Chella': 13,
#   'Chett': 14,
#   'Chiggen': 13,
#   'Clement-Piper': 10,
#   'Clydas': 22,
#   'Cohollo': 12,
#   'Colemon': 10,
#   'Conn': 14,
#   'Coratt': 19,
#   'Daenerys-Targaryen': 5,
#   'Danwell-Frey': 12,
#   'Dareon': 16,
#   'Daryn-Hornwood': 3,
#   'Desmond': 4,
#   'Dolf': 20,
#   'Donal-Noye': 17,
#   'Donnel-Waynwood': 10,
#   'Doreah': 13,
#   'Drogo': 10,
#   'Dywen': 14,
#   'Eddard-Stark': 0,
#   'Edmure-Tully': 3,
#   'Eon-Hunter': 10,
#   'Eroeh': 10,
#   'Fogo': 20,
#   'Galbart-Glover': 4,
#   'Gared': 15,
#   'Gendry': 3,
#   'Gerold-Hightower': 3,
#   'Gregor-Clegane': 9,
#   'Grenn': 14,
#   'Gunthor-son-of-Gurn': 15,
#   'Haggo': 12,
#   'Halder': 18,
#   'Hali': 11,
#   'Hallis-Mollen': 11,
#   'Harwin': 5,
#   'Harys-Swyft': 9,
#   'Heward': 6,
#   'High-Septon-(fat_one)': 4,
#   'Hobb': 15,
#   'Hodor': 13,
#   'Hosteen-Frey': 15,
#   'Hoster-Tully': 10,
#   'Howland-Reed': 3,
#   'Hugh': 12,
#   'Hullen': 8,
#   'Illyrio-Mopatis': 13,
#   'Ilyn-Payne': 6,
#   'Irri': 14,
#   'Jacks': 4,
#   'Jafer-Flowers': 15,
#   'Jaime-Lannister': 6,
#   'Janos-Slynt': 4,
#   'Jared-Frey': 15,
#   'Jaremy-Rykker': 12,
#   'Jeor-Mormont': 11,
#   'Jeyne-Poole': 9,
#   'Jhiqui': 14,
#   'Jhogo': 15,
#   'Joffrey-Baratheon': 8,
#   'Jommo': 13,
#   'Jon-Arryn': 9,
#   'Jon-Snow': 10,
#   'Jon-Umber-(Greatjon)': 8,
#   'Jonos-Bracken': 9,
#   'Jorah-Mormont': 10,
#   'Jory-Cassel': 8,
#   'Joseth': 10,
#   'Joss': 5,
#   'Jyck': 14,
#   'Karyl-Vance': 6,
#   'Kevan-Lannister': 10,
#   'Kurleket': 13,
#   'Lancel-Lannister': 10,
#   'Leo-Lefford': 12,
#   'Loras-Tyrell': 8,
#   'Luwin': 7,
#   'Lyanna-Stark': 11,
#   'Lyn-Corbray': 11,
#   'Lysa-Arryn': 8,
#   'Mace-Tyrell': 11,
#   'Maege-Mormont': 7,
#   'Maegor-I-Targaryen': 11,
#   'Mance-Rayder': 12,
#   'Marillion': 12,
#   'Marq-Piper': 3,
#   'Masha-Heddle': 12,
#   'Matthar': 13,
#   'Meryn-Trant': 10,
#   'Mirri-Maz-Duur': 15,
#   'Mord': 28,
#   'Mordane': 10,
#   'Moreo-Tumitis': 10,
#   'Morrec': 13,
#   'Mya-Stone': 16,
#   'Mycah': 3,
#   'Mychel-Redfort': 10,
#   'Myrcella-Baratheon': 10,
#   'Nan': 11,
#   'Nestor-Royce': 9,
#   'Ogo': 16,
#   'Osha': 11,
#   'Oswell-Whent': 6,
#   'Othor': 15,
#   'Paxter-Redwyne': 14,
#   'Petyr-Baelish': 7,
#   'Porther': 4,
#   'Pycelle': 7,
#   'Pypar': 19,
#   'Qotho': 14,
#   'Quaro': 10,
#   'Rakharo': 9,
#   'Randyll-Tarly': 17,
#   'Rast': 15,
#   'Raymun-Darry': 4,
#   'Renly-Baratheon': 10,
#   'Rhaegar-Targaryen': 9,
#   'Rhaego': 15,
#   'Rickard-Karstark': 4,
#   'Rickard-Stark': 12,
#   'Rickon-Stark': 4,
#   'Robb-Stark': 8,
#   'Robert-Arryn': 10,
#   'Robert-Baratheon': 7,
#   'Rodrik-Cassel': 7,
#   'Roose-Bolton': 7,
#   'Samwell-Tarly': 12,
#   'Sandor-Clegane': 8,
#   'Sansa-Stark': 7,
#   'Shae': 13,
#   'Shagga': 13,
#   'Stannis-Baratheon': 10,
#   'Stevron-Frey': 12,
#   'Stiv': 11,
#   'Syrio-Forel': 6,
#   'Theon-Greyjoy': 5,
#   'Thoros-of-Myr': 8,
#   'Timett': 11,
#   'Tobho-Mott': 7,
#   'Todder': 21,
#   'Tomard': 10,
#   'Tommen-Baratheon': 10,
#   'Torrhen-Karstark': 5,
#   'Tregar': 4,
#   'Tyrion-Lannister': 8,
#   'Tytos-Blackwood': 6,
#   'Tywin-Lannister': 6,
#   'Ulf-son-of-Umar': 17,
#   'Vardis-Egen': 12,
#   'Varly': 4,
#   'Varys': 9,
#   'Vayon-Poole': 10,
#   'Viserys-Targaryen': 14,
#   'Walder-Frey': 9,
#   'Waymar-Royce': 12,
#   'Wendel-Manderly': 10,
#   'Will-(prologue)': 27,
#   'Willis-Wode': 12,
#   'Wyl-(guard)': 3,
#   'Wylla': 3,
#   'Yoren': 11},
#  {'Addam-Marbrand': ['Eddard-Stark',
#    'Wyl-(guard)',
#    'Jaime-Lannister',
#    'Addam-Marbrand'],
#   'Aegon-I-Targaryen': ['Eddard-Stark', 'Aegon-I-Targaryen'],
#   'Aemon-Targaryen-(Maester-Aemon)': ['Eddard-Stark',
#    'Edmure-Tully',
#    'Robb-Stark',
#    'Samwell-Tarly',
#    'Aemon-Targaryen-(Maester-Aemon)'],
#   'Aerys-II-Targaryen': ['Eddard-Stark',
#    'Gerold-Hightower',
#    'Aerys-II-Targaryen'],
#   'Aggo': ['Eddard-Stark', 'Daenerys-Targaryen', 'Quaro', 'Aggo'],
#   'Albett': ['Eddard-Stark', 'Rodrik-Cassel', 'Jon-Snow', 'Albett'],
#   'Alliser-Thorne': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Tyrion-Lannister',
#    'Alliser-Thorne'],
#   'Alyn': ['Eddard-Stark', 'Alyn'],
#   'Arthur-Dayne': ['Eddard-Stark', 'Gerold-Hightower', 'Arthur-Dayne'],
#   'Arya-Stark': ['Eddard-Stark', 'Desmond', 'Arya-Stark'],
#   'Arys-Oakheart': ['Eddard-Stark',
#    'Janos-Slynt',
#    'Cersei-Lannister',
#    'Arys-Oakheart'],
#   'Balon-Greyjoy': ['Eddard-Stark', 'Balon-Greyjoy'],
#   'Balon-Swann': ['Eddard-Stark', 'Mycah', 'Sandor-Clegane', 'Balon-Swann'],
#   'Barristan-Selmy': ['Eddard-Stark',
#    'Wyl-(guard)',
#    'Jaime-Lannister',
#    'Barristan-Selmy'],
#   'Benjen-Stark': ['Eddard-Stark', 'Theon-Greyjoy', 'Benjen-Stark'],
#   'Beric-Dondarrion': ['Eddard-Stark', 'Beric-Dondarrion'],
#   'Boros-Blount': ['Eddard-Stark',
#    'High-Septon-(fat_one)',
#    'Joffrey-Baratheon',
#    'Boros-Blount'],
#   'Bowen-Marsh': ['Eddard-Stark',
#    'Edmure-Tully',
#    'Robb-Stark',
#    'Samwell-Tarly',
#    'Bowen-Marsh'],
#   'Bran-Stark': ['Eddard-Stark', 'Rickard-Karstark', 'Bran-Stark'],
#   'Brandon-Stark': ['Eddard-Stark',
#    'Gerold-Hightower',
#    'Aerys-II-Targaryen',
#    'Brandon-Stark'],
#   'Bronn': ['Eddard-Stark', 'Marq-Piper', 'Tywin-Lannister', 'Bronn'],
#   'Brynden-Tully': ['Eddard-Stark', 'Edmure-Tully', 'Brynden-Tully'],
#   'Catelyn-Stark': ['Eddard-Stark', 'Rickon-Stark', 'Catelyn-Stark'],
#   'Cayn': ['Eddard-Stark', 'Cayn'],
#   'Cersei-Lannister': ['Eddard-Stark', 'Janos-Slynt', 'Cersei-Lannister'],
#   'Chella': ['Eddard-Stark', 'Rickon-Stark', 'Tyrion-Lannister', 'Chella'],
#   'Chett': ['Eddard-Stark', 'Rodrik-Cassel', 'Jon-Snow', 'Chett'],
#   'Chiggen': ['Eddard-Stark', 'Rickon-Stark', 'Tyrion-Lannister', 'Chiggen'],
#   'Clement-Piper': ['Eddard-Stark',
#    'Marq-Piper',
#    'Karyl-Vance',
#    'Clement-Piper'],
#   'Clydas': ['Eddard-Stark',
#    'Edmure-Tully',
#    'Robb-Stark',
#    'Samwell-Tarly',
#    'Aemon-Targaryen-(Maester-Aemon)',
#    'Clydas'],
#   'Cohollo': ['Eddard-Stark', 'Daenerys-Targaryen', 'Cohollo'],
#   'Colemon': ['Eddard-Stark', 'Rickon-Stark', 'Catelyn-Stark', 'Colemon'],
#   'Conn': ['Eddard-Stark', 'Rickon-Stark', 'Tyrion-Lannister', 'Conn'],
#   'Coratt': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Tyrion-Lannister',
#    'Conn',
#    'Coratt'],
#   'Daenerys-Targaryen': ['Eddard-Stark', 'Daenerys-Targaryen'],
#   'Danwell-Frey': ['Eddard-Stark',
#    'Theon-Greyjoy',
#    'Walder-Frey',
#    'Danwell-Frey'],
#   'Dareon': ['Eddard-Stark', 'Rodrik-Cassel', 'Jon-Snow', 'Dareon'],
#   'Daryn-Hornwood': ['Eddard-Stark', 'Daryn-Hornwood'],
#   'Desmond': ['Eddard-Stark', 'Desmond'],
#   'Dolf': ['Eddard-Stark',
#    'Marq-Piper',
#    'Tywin-Lannister',
#    'Bronn',
#    'Shagga',
#    'Dolf'],
#   'Donal-Noye': ['Eddard-Stark', 'Rodrik-Cassel', 'Jon-Snow', 'Donal-Noye'],
#   'Donnel-Waynwood': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Catelyn-Stark',
#    'Donnel-Waynwood'],
#   'Doreah': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jorah-Mormont',
#    'Doreah'],
#   'Drogo': ['Eddard-Stark', 'Balon-Greyjoy', 'Robert-Baratheon', 'Drogo'],
#   'Dywen': ['Eddard-Stark', 'Rodrik-Cassel', 'Jon-Snow', 'Dywen'],
#   'Eddard-Stark': ['Eddard-Stark'],
#   'Edmure-Tully': ['Eddard-Stark', 'Edmure-Tully'],
#   'Eon-Hunter': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Catelyn-Stark',
#    'Eon-Hunter'],
#   'Eroeh': ['Eddard-Stark', 'Daenerys-Targaryen', 'Eroeh'],
#   'Fogo': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Drogo',
#    'Jommo',
#    'Ogo',
#    'Fogo'],
#   'Galbart-Glover': ['Eddard-Stark', 'Galbart-Glover'],
#   'Gared': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jeor-Mormont',
#    'Gared'],
#   'Gendry': ['Eddard-Stark', 'Gendry'],
#   'Gerold-Hightower': ['Eddard-Stark', 'Gerold-Hightower'],
#   'Gregor-Clegane': ['Eddard-Stark', 'Beric-Dondarrion', 'Gregor-Clegane'],
#   'Grenn': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jeor-Mormont',
#    'Grenn'],
#   'Gunthor-son-of-Gurn': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Tyrion-Lannister',
#    'Gunthor-son-of-Gurn'],
#   'Haggo': ['Eddard-Stark', 'Daenerys-Targaryen', 'Rakharo', 'Haggo'],
#   'Halder': ['Eddard-Stark',
#    'Edmure-Tully',
#    'Robb-Stark',
#    'Samwell-Tarly',
#    'Halder'],
#   'Hali': ['Eddard-Stark', 'Rickard-Karstark', 'Bran-Stark', 'Hali'],
#   'Hallis-Mollen': ['Eddard-Stark',
#    'Rickard-Karstark',
#    'Luwin',
#    'Hallis-Mollen'],
#   'Harwin': ['Eddard-Stark', 'Harwin'],
#   'Harys-Swyft': ['Eddard-Stark',
#    'Wyl-(guard)',
#    'Jaime-Lannister',
#    'Harys-Swyft'],
#   'Heward': ['Eddard-Stark', 'Wyl-(guard)', 'Heward'],
#   'High-Septon-(fat_one)': ['Eddard-Stark', 'High-Septon-(fat_one)'],
#   'Hobb': ['Eddard-Stark', 'Rodrik-Cassel', 'Jon-Snow', 'Hobb'],
#   'Hodor': ['Eddard-Stark', 'Edmure-Tully', 'Robb-Stark', 'Hodor'],
#   'Hosteen-Frey': ['Eddard-Stark',
#    'Theon-Greyjoy',
#    'Walder-Frey',
#    'Danwell-Frey',
#    'Hosteen-Frey'],
#   'Hoster-Tully': ['Eddard-Stark', 'Edmure-Tully', 'Hoster-Tully'],
#   'Howland-Reed': ['Eddard-Stark', 'Howland-Reed'],
#   'Hugh': ['Eddard-Stark',
#    'Gerold-Hightower',
#    'Aerys-II-Targaryen',
#    'Jon-Arryn',
#    'Hugh'],
#   'Hullen': ['Eddard-Stark', 'Harwin', 'Hullen'],
#   'Illyrio-Mopatis': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Illyrio-Mopatis'],
#   'Ilyn-Payne': ['Eddard-Stark', 'Ilyn-Payne'],
#   'Irri': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jorah-Mormont',
#    'Irri'],
#   'Jacks': ['Eddard-Stark', 'Jacks'],
#   'Jafer-Flowers': ['Eddard-Stark',
#    'Theon-Greyjoy',
#    'Benjen-Stark',
#    'Jaremy-Rykker',
#    'Jafer-Flowers'],
#   'Jaime-Lannister': ['Eddard-Stark', 'Wyl-(guard)', 'Jaime-Lannister'],
#   'Janos-Slynt': ['Eddard-Stark', 'Janos-Slynt'],
#   'Jared-Frey': ['Eddard-Stark',
#    'Theon-Greyjoy',
#    'Walder-Frey',
#    'Danwell-Frey',
#    'Jared-Frey'],
#   'Jaremy-Rykker': ['Eddard-Stark',
#    'Theon-Greyjoy',
#    'Benjen-Stark',
#    'Jaremy-Rykker'],
#   'Jeor-Mormont': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jeor-Mormont'],
#   'Jeyne-Poole': ['Eddard-Stark', 'Ilyn-Payne', 'Jeyne-Poole'],
#   'Jhiqui': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jorah-Mormont',
#    'Jhiqui'],
#   'Jhogo': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jorah-Mormont',
#    'Jhogo'],
#   'Joffrey-Baratheon': ['Eddard-Stark',
#    'High-Septon-(fat_one)',
#    'Joffrey-Baratheon'],
#   'Jommo': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Drogo',
#    'Jommo'],
#   'Jon-Arryn': ['Eddard-Stark',
#    'Gerold-Hightower',
#    'Aerys-II-Targaryen',
#    'Jon-Arryn'],
#   'Jon-Snow': ['Eddard-Stark', 'Rodrik-Cassel', 'Jon-Snow'],
#   'Jon-Umber-(Greatjon)': ['Eddard-Stark',
#    'Galbart-Glover',
#    'Jon-Umber-(Greatjon)'],
#   'Jonos-Bracken': ['Eddard-Stark',
#    'Edmure-Tully',
#    'Tytos-Blackwood',
#    'Jonos-Bracken'],
#   'Jorah-Mormont': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jorah-Mormont'],
#   'Jory-Cassel': ['Eddard-Stark', 'Theon-Greyjoy', 'Jory-Cassel'],
#   'Joseth': ['Eddard-Stark', 'Rickard-Karstark', 'Luwin', 'Joseth'],
#   'Joss': ['Eddard-Stark', 'Joss'],
#   'Jyck': ['Eddard-Stark', 'Rickon-Stark', 'Tyrion-Lannister', 'Jyck'],
#   'Karyl-Vance': ['Eddard-Stark', 'Marq-Piper', 'Karyl-Vance'],
#   'Kevan-Lannister': ['Eddard-Stark',
#    'Wyl-(guard)',
#    'Jaime-Lannister',
#    'Kevan-Lannister'],
#   'Kurleket': ['Eddard-Stark', 'Rickon-Stark', 'Tyrion-Lannister', 'Kurleket'],
#   'Lancel-Lannister': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Lancel-Lannister'],
#   'Leo-Lefford': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Tyrion-Lannister',
#    'Leo-Lefford'],
#   'Loras-Tyrell': ['Eddard-Stark', 'Beric-Dondarrion', 'Loras-Tyrell'],
#   'Luwin': ['Eddard-Stark', 'Rickard-Karstark', 'Luwin'],
#   'Lyanna-Stark': ['Eddard-Stark',
#    'Beric-Dondarrion',
#    'Sansa-Stark',
#    'Lyanna-Stark'],
#   'Lyn-Corbray': ['Eddard-Stark', 'Edmure-Tully', 'Lysa-Arryn', 'Lyn-Corbray'],
#   'Lysa-Arryn': ['Eddard-Stark', 'Edmure-Tully', 'Lysa-Arryn'],
#   'Mace-Tyrell': ['Eddard-Stark',
#    'Beric-Dondarrion',
#    'Loras-Tyrell',
#    'Mace-Tyrell'],
#   'Maege-Mormont': ['Eddard-Stark', 'Rickard-Karstark', 'Maege-Mormont'],
#   'Maegor-I-Targaryen': ['Eddard-Stark',
#    'Beric-Dondarrion',
#    'Sansa-Stark',
#    'Maegor-I-Targaryen'],
#   'Mance-Rayder': ['Eddard-Stark',
#    'Theon-Greyjoy',
#    'Benjen-Stark',
#    'Mance-Rayder'],
#   'Marillion': ['Eddard-Stark', 'Rodrik-Cassel', 'Marillion'],
#   'Marq-Piper': ['Eddard-Stark', 'Marq-Piper'],
#   'Masha-Heddle': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Catelyn-Stark',
#    'Masha-Heddle'],
#   'Matthar': ['Eddard-Stark', 'Rodrik-Cassel', 'Jon-Snow', 'Matthar'],
#   'Meryn-Trant': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Meryn-Trant'],
#   'Mirri-Maz-Duur': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jorah-Mormont',
#    'Mirri-Maz-Duur'],
#   'Mord': ['Eddard-Stark', 'Rickon-Stark', 'Tyrion-Lannister', 'Mord'],
#   'Mordane': ['Eddard-Stark', 'Edmure-Tully', 'Petyr-Baelish', 'Mordane'],
#   'Moreo-Tumitis': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Catelyn-Stark',
#    'Moreo-Tumitis'],
#   'Morrec': ['Eddard-Stark', 'Rickon-Stark', 'Tyrion-Lannister', 'Morrec'],
#   'Mya-Stone': ['Eddard-Stark', 'Rickon-Stark', 'Catelyn-Stark', 'Mya-Stone'],
#   'Mycah': ['Eddard-Stark', 'Mycah'],
#   'Mychel-Redfort': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Catelyn-Stark',
#    'Mychel-Redfort'],
#   'Myrcella-Baratheon': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Myrcella-Baratheon'],
#   'Nan': ['Eddard-Stark', 'Rickard-Karstark', 'Luwin', 'Nan'],
#   'Nestor-Royce': ['Eddard-Stark',
#    'Edmure-Tully',
#    'Brynden-Tully',
#    'Nestor-Royce'],
#   'Ogo': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Drogo',
#    'Jommo',
#    'Ogo'],
#   'Osha': ['Eddard-Stark', 'Edmure-Tully', 'Robb-Stark', 'Osha'],
#   'Oswell-Whent': ['Eddard-Stark', 'Gerold-Hightower', 'Oswell-Whent'],
#   'Othor': ['Eddard-Stark', 'Rodrik-Cassel', 'Jon-Snow', 'Othor'],
#   'Paxter-Redwyne': ['Eddard-Stark',
#    'Beric-Dondarrion',
#    'Loras-Tyrell',
#    'Mace-Tyrell',
#    'Paxter-Redwyne'],
#   'Petyr-Baelish': ['Eddard-Stark', 'Edmure-Tully', 'Petyr-Baelish'],
#   'Porther': ['Eddard-Stark', 'Porther'],
#   'Pycelle': ['Eddard-Stark', 'Janos-Slynt', 'Pycelle'],
#   'Pypar': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Tyrion-Lannister',
#    'Alliser-Thorne',
#    'Pypar'],
#   'Qotho': ['Eddard-Stark', 'Daenerys-Targaryen', 'Quaro', 'Qotho'],
#   'Quaro': ['Eddard-Stark', 'Daenerys-Targaryen', 'Quaro'],
#   'Rakharo': ['Eddard-Stark', 'Daenerys-Targaryen', 'Rakharo'],
#   'Randyll-Tarly': ['Eddard-Stark',
#    'Edmure-Tully',
#    'Robb-Stark',
#    'Samwell-Tarly',
#    'Randyll-Tarly'],
#   'Rast': ['Eddard-Stark',
#    'Edmure-Tully',
#    'Robb-Stark',
#    'Samwell-Tarly',
#    'Rast'],
#   'Raymun-Darry': ['Eddard-Stark', 'Raymun-Darry'],
#   'Renly-Baratheon': ['Eddard-Stark',
#    'Wyl-(guard)',
#    'Jaime-Lannister',
#    'Renly-Baratheon'],
#   'Rhaegar-Targaryen': ['Eddard-Stark',
#    'Daenerys-Targaryen',
#    'Rhaegar-Targaryen'],
#   'Rhaego': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Drogo',
#    'Rhaego'],
#   'Rickard-Karstark': ['Eddard-Stark', 'Rickard-Karstark'],
#   'Rickard-Stark': ['Eddard-Stark',
#    'Rickard-Karstark',
#    'Bran-Stark',
#    'Rickard-Stark'],
#   'Rickon-Stark': ['Eddard-Stark', 'Rickon-Stark'],
#   'Robb-Stark': ['Eddard-Stark', 'Edmure-Tully', 'Robb-Stark'],
#   'Robert-Arryn': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Catelyn-Stark',
#    'Robert-Arryn'],
#   'Robert-Baratheon': ['Eddard-Stark', 'Balon-Greyjoy', 'Robert-Baratheon'],
#   'Rodrik-Cassel': ['Eddard-Stark', 'Rodrik-Cassel'],
#   'Roose-Bolton': ['Eddard-Stark', 'Galbart-Glover', 'Roose-Bolton'],
#   'Samwell-Tarly': ['Eddard-Stark',
#    'Edmure-Tully',
#    'Robb-Stark',
#    'Samwell-Tarly'],
#   'Sandor-Clegane': ['Eddard-Stark', 'Mycah', 'Sandor-Clegane'],
#   'Sansa-Stark': ['Eddard-Stark', 'Beric-Dondarrion', 'Sansa-Stark'],
#   'Shae': ['Eddard-Stark', 'Marq-Piper', 'Tywin-Lannister', 'Bronn', 'Shae'],
#   'Shagga': ['Eddard-Stark',
#    'Marq-Piper',
#    'Tywin-Lannister',
#    'Bronn',
#    'Shagga'],
#   'Stannis-Baratheon': ['Eddard-Stark',
#    'Marq-Piper',
#    'Tywin-Lannister',
#    'Stannis-Baratheon'],
#   'Stevron-Frey': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Catelyn-Stark',
#    'Stevron-Frey'],
#   'Stiv': ['Eddard-Stark', 'Edmure-Tully', 'Robb-Stark', 'Stiv'],
#   'Syrio-Forel': ['Eddard-Stark', 'Syrio-Forel'],
#   'Theon-Greyjoy': ['Eddard-Stark', 'Theon-Greyjoy'],
#   'Thoros-of-Myr': ['Eddard-Stark', 'Beric-Dondarrion', 'Thoros-of-Myr'],
#   'Timett': ['Eddard-Stark', 'Rickon-Stark', 'Tyrion-Lannister', 'Timett'],
#   'Tobho-Mott': ['Eddard-Stark', 'Tobho-Mott'],
#   'Todder': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jeor-Mormont',
#    'Grenn',
#    'Todder'],
#   'Tomard': ['Eddard-Stark', 'Beric-Dondarrion', 'Sansa-Stark', 'Tomard'],
#   'Tommen-Baratheon': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Tommen-Baratheon'],
#   'Torrhen-Karstark': ['Eddard-Stark', 'Torrhen-Karstark'],
#   'Tregar': ['Eddard-Stark', 'Tregar'],
#   'Tyrion-Lannister': ['Eddard-Stark', 'Rickon-Stark', 'Tyrion-Lannister'],
#   'Tytos-Blackwood': ['Eddard-Stark', 'Edmure-Tully', 'Tytos-Blackwood'],
#   'Tywin-Lannister': ['Eddard-Stark', 'Marq-Piper', 'Tywin-Lannister'],
#   'Ulf-son-of-Umar': ['Eddard-Stark',
#    'Marq-Piper',
#    'Tywin-Lannister',
#    'Bronn',
#    'Shagga',
#    'Ulf-son-of-Umar'],
#   'Vardis-Egen': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Catelyn-Stark',
#    'Vardis-Egen'],
#   'Varly': ['Eddard-Stark', 'Varly'],
#   'Varys': ['Eddard-Stark', 'Wyl-(guard)', 'Jaime-Lannister', 'Varys'],
#   'Vayon-Poole': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Vayon-Poole'],
#   'Viserys-Targaryen': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Viserys-Targaryen'],
#   'Walder-Frey': ['Eddard-Stark', 'Theon-Greyjoy', 'Walder-Frey'],
#   'Waymar-Royce': ['Eddard-Stark',
#    'Theon-Greyjoy',
#    'Benjen-Stark',
#    'Waymar-Royce'],
#   'Wendel-Manderly': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Catelyn-Stark',
#    'Wendel-Manderly'],
#   'Will-(prologue)': ['Eddard-Stark',
#    'Balon-Greyjoy',
#    'Robert-Baratheon',
#    'Jeor-Mormont',
#    'Gared',
#    'Will-(prologue)'],
#   'Willis-Wode': ['Eddard-Stark',
#    'Rickon-Stark',
#    'Catelyn-Stark',
#    'Willis-Wode'],
#   'Wyl-(guard)': ['Eddard-Stark', 'Wyl-(guard)'],
#   'Wylla': ['Eddard-Stark', 'Wylla'],
#   'Yoren': ['Eddard-Stark', 'Desmond', 'Arya-Stark', 'Yoren']})

# %%
length['Jon-Snow'], path['Jon-Snow']
# Out:
# (10, ['Eddard-Stark', 'Rodrik-Cassel', 'Jon-Snow'])

# %%
G1['Eddard-Stark']['Jon-Snow']
# Out:
# {'weight': 38}

# %%
G1['Eddard-Stark']['Rodrik-Cassel'], G1['Rodrik-Cassel']['Jon-Snow']
# Out:
# ({'weight': 7}, {'weight': 3})

# %%
length['Robert-Baratheon'], path['Robert-Baratheon']
# Out:
# (7, ['Eddard-Stark', 'Balon-Greyjoy', 'Robert-Baratheon'])

# %%
yuksekler = sorted(nx.edge_betweenness_centrality(G1).items(), key=lambda x:x[1], reverse=True)[0:10]
yuksekler
# Out:
# [(('Robert-Baratheon', 'Drogo'), 0.06511341526150327),
#  (('Daenerys-Targaryen', 'Eddard-Stark'), 0.05119504936228878),
#  (('Eddard-Stark', 'Jon-Snow'), 0.036807751753701164),
#  (('Walder-Frey', 'Danwell-Frey'), 0.03174055545972054),
#  (('Eddard-Stark', 'Tyrion-Lannister'), 0.031239861844768377),
#  (('Jon-Snow', 'Robert-Baratheon'), 0.02960628095173083),
#  (('Tyrion-Lannister', 'Shagga'), 0.02858875402863673),
#  (('Daenerys-Targaryen', 'Robert-Baratheon'), 0.028067242464079788),
#  (('Robert-Baratheon', 'Tyrion-Lannister'), 0.02668635517231797),
#  (('Robert-Baratheon', 'Catelyn-Stark'), 0.023469615645975484)]

# %%
bag, deger = yuksekler[1]
bag
# Out:
# ('Daenerys-Targaryen', 'Eddard-Stark')

# %%
for bag, deger in yuksekler:
    n1, n2 = bag
    print(n1, "-->>", n2)
# Out:
# Robert-Baratheon -->> Drogo
# Daenerys-Targaryen -->> Eddard-Stark
# Eddard-Stark -->> Jon-Snow
# Walder-Frey -->> Danwell-Frey
# Eddard-Stark -->> Tyrion-Lannister
# Jon-Snow -->> Robert-Baratheon
# Tyrion-Lannister -->> Shagga
# Daenerys-Targaryen -->> Robert-Baratheon
# Robert-Baratheon -->> Tyrion-Lannister
# Robert-Baratheon -->> Catelyn-Stark

# %%
yuksekler = sorted(nx.edge_betweenness_centrality(G1).items(), key=lambda x:x[1], reverse=True)[0:50]
yuksekler
for bag, deger in yuksekler:
    n1, n2 = bag
    G1.remove_edge(n1, n2)

# %%
plt.figure(figsize=(24, 24))
pos2=nx.spring_layout(G1,scale=1) 
nx.draw(G1, pos=pos2, node_size=1000, node_color='lightblue', with_labels=True)
plt.title("Kitap 1 - Game of Thrones")
# Out:
# Text(0.5,1,'Kitap 1 - Game of Thrones')

# %% [markdown]
# ## Harry Potter Incelemesi icin
#  - https://github.com/cindyzhong/trt_data_lit_grp_python/blob/master/Lesson3/social_network_analysis_harry_potter.ipynb
#
#
# ## R ile Ag Bilimi
#  - http://inet-tr.org.tr/inetconf19/sunum/16.pdf
